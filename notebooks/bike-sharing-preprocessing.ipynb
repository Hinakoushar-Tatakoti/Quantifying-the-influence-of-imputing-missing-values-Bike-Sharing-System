# %% [markdown]
# ## CitiBike data is collected for 1 year 2018
# https://ride.citibikenyc.com/system-data
#
# Data Schema:
# Trip Duration (seconds)
#
# *   Start Time and Date
# *   Stop Time and Date
# *   Start Station Name
# *   End Station Name
# *   Station ID
# *   Station Lat/Long
# *   Bike ID
# *   User Type (Customer = 24-hour pass or 3-day pass user; Subscriber = Annual    Member)
# *   Gender (Zero=unknown; 1=male; 2=female)
# *   Year of Birth

# %%
import pandas as pd
import numpy as np
import haversine as hs
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import iglob

import warnings
warnings.filterwarnings("ignore")

# %%
#!pip install haversine

# %%
path = r'D:\Beuth Sems\Thesis\dataset\JC-2018*.csv'

all_rec = iglob(path, recursive=True)     
dataframes = (pd.read_csv(f) for f in all_rec)
tripdata = pd.concat(dataframes, ignore_index=True)

# %%
tripdata.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  3.538920e+05     353892.000000           353892.000000
# mean   6.733930e+02       3264.996606               40.722724
# std    7.004022e+03        138.429108                0.007251
# min    6.100000e+01       3183.000000               40.692640
# 25%    2.280000e+02       3192.000000               40.718211
# 50%    3.350000e+02       3205.000000               40.721525
# 75%    5.490000e+02       3272.000000               40.727224
# max    2.061932e+06       3694.000000               40.748716
#
#        start station longitude  end station id  end station latitude  \
# count            353892.000000   353892.000000         353892.000000
# mean                -74.046039     3258.408418             40.722326
# std                   0.010755      147.610023              0.007095
# min                 -74.096937      127.000000             40.679331
# 25%                 -74.050444     3186.000000             40.717732
# 50%                 -74.043845     3203.000000             40.721124
# 75%                 -74.038051     3272.000000             40.727224
# max                 -74.032108     3694.000000             40.814326
#
#        end station longitude         bikeid     birth year         gender
# count          353892.000000  353892.000000  353892.000000  353892.000000
# mean              -74.045505   29452.498808    1980.387875       1.152388
# std                 0.010759    2529.992371      10.268528       0.500198
# min               -74.096937   14697.000000    1887.000000       0.000000
# 25%               -74.049968   26315.000000    1974.000000       1.000000
# 50%               -74.043117   29493.000000    1983.000000       1.000000
# 75%               -74.037683   29679.000000    1988.000000       1.000000
# max               -73.947821   35009.000000    2002.000000       2.000000

# %%
tripdata.isnull().sum()
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# birth year                 0
# gender                     0
# dtype: int64

# %%
tripdata.shape
# Out:
# (353892, 15)

# %%
tripdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353892 entries, 0 to 353891
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             353892 non-null  int64
#  1   starttime                353892 non-null  object
#  2   stoptime                 353892 non-null  object
#  3   start station id         353892 non-null  int64
#  4   start station name       353892 non-null  object
#  5   start station latitude   353892 non-null  float64
#  6   start station longitude  353892 non-null  float64
#  7   end station id           353892 non-null  int64
#  8   end station name         353892 non-null  object
#  9   end station latitude     353892 non-null  float64
#  10  end station longitude    353892 non-null  float64
#  11  bikeid                   353892 non-null  int64
#  12  usertype                 353892 non-null  object
#  13  birth year               353892 non-null  int64
#  14  gender                   353892 non-null  int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 40.5+ MB

# %% [markdown]
# ### calculate travelled distances based on lat and lon

# %%
#!pip install haversine

# %%
from haversine import Unit
import haversine as hs

def find_distance(slat, slon, elat, elon):
    loc1=(slat,slon)
    loc2=(elat, elon)
    return round(hs.haversine(loc1,loc2,unit=Unit.MILES),1)

# %%
tripdata['dist'] = tripdata.apply(lambda r: find_distance(r['start station latitude'],r['start station longitude'],r['end station latitude'],r['end station longitude']) , axis=1)

# %%
tripdata.head(5)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# 1               -74.033459            3199     Newport Pkwy
# 2               -74.033459            3199     Newport Pkwy
# 3               -74.033459            3267     Morris Canal
# 4               -74.033459            3639       Harborside
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.728745             -74.032108   31929  Subscriber
# 1             40.728745             -74.032108   31845  Subscriber
# 2             40.728745             -74.032108   31708  Subscriber
# 3             40.712419             -74.038526   31697  Subscriber
# 4             40.719252             -74.034234   31861  Subscriber
#
#    birth year  gender  dist
# 0        1992       1   0.9
# 1        1969       2   0.9
# 2        1946       1   0.9
# 3        1994       1   0.4
# 4        1991       1   0.2

# %% [markdown]
# ## Explode the start and end date into different columns

# %%
tripdata['starttime'] = pd.to_datetime(tripdata['starttime'])
tripdata['stoptime'] = pd.to_datetime(tripdata['stoptime'])
tripdata['year'] = tripdata["starttime"].dt.year
tripdata["start_month"] = tripdata["starttime"].dt.month_name()
tripdata["end_month"] = tripdata["stoptime"].dt.month_name()
tripdata['start_day'] = tripdata["starttime"].dt.day_name()
tripdata['end_day'] = tripdata["starttime"].dt.day_name()
tripdata["start_hour"] = tripdata["starttime"].dt.hour
tripdata["end_hour"] = tripdata["stoptime"].dt.hour
tripdata["start_minute"] = tripdata["starttime"].dt.minute
tripdata["end_minute"] = tripdata["stoptime"].dt.minute

# %%
tripdata[tripdata["end_month"] != tripdata["start_month"]]
# Out:
#         tripduration               starttime                stoptime  \
# 29147         159351 2018-03-31 14:31:51.868 2018-04-02 10:47:43.781
# 32263         196050 2018-03-31 11:36:00.512 2018-04-02 18:03:31.456
# 36486         270188 2018-03-30 15:59:08.517 2018-04-02 19:02:16.778
# 42038         120931 2018-03-31 08:13:15.850 2018-04-01 17:48:47.152
# 59727         235117 2018-04-29 17:50:47.757 2018-05-02 11:09:25.359
# 63194         571578 2018-04-26 18:49:23.200 2018-05-03 09:35:41.241
# 68219            375 2018-04-30 23:55:57.124 2018-05-01 00:02:12.886
# 71072          32293 2018-05-31 21:18:25.283 2018-06-01 06:16:38.412
# 77331         917900 2018-05-26 18:29:16.344 2018-06-06 09:27:36.708
# 87404           1307 2018-05-31 23:57:44.904 2018-06-01 00:19:31.997
# 88764            592 2018-05-31 23:57:30.513 2018-06-01 00:07:23.221
# 97105         347049 2018-05-28 17:34:40.546 2018-06-01 17:58:50.545
# 100231          2475 2018-05-31 23:59:53.646 2018-06-01 00:41:09.052
# 101129       1193290 2018-05-25 17:58:30.228 2018-06-08 13:26:40.728
# 101986          1279 2018-05-31 23:57:56.538 2018-06-01 00:19:16.058
# 118583        111451 2018-06-29 21:13:57.200 2018-07-01 04:11:28.360
# 120671          1020 2018-06-30 23:51:22.828 2018-07-01 00:08:23.341
# 120672           944 2018-06-30 23:52:34.348 2018-07-01 00:08:18.920
# 127081         73561 2018-06-30 19:54:55.030 2018-07-01 16:20:56.185
# 127084         73487 2018-06-30 19:57:28.199 2018-07-01 16:22:16.052
# 146079        134192 2018-07-31 19:24:49.953 2018-08-02 08:41:22.626
# 174792         52292 2018-07-31 17:52:02.332 2018-08-01 08:23:34.924
# 195800          1226 2018-08-31 23:54:00.722 2018-09-01 00:14:26.760
# 213288          2585 2018-08-31 23:53:07.703 2018-09-01 00:36:13.649
# 221068        250427 2018-08-31 19:59:27.960 2018-09-03 17:33:15.711
# 224441       2061932 2018-08-08 20:28:55.026 2018-09-01 17:14:27.895
# 232753         52733 2018-09-30 19:05:21.586 2018-10-01 09:44:15.186
# 251991        395383 2018-09-27 03:31:49.927 2018-10-01 17:21:33.255
# 257877        108029 2018-09-30 02:13:07.054 2018-10-01 08:13:36.314
# 257892         83670 2018-09-30 20:05:28.854 2018-10-01 19:19:58.893
# 278372         35280 2018-10-31 22:07:13.370 2018-11-01 07:55:13.742
# 279314           862 2018-10-31 23:50:50.467 2018-11-01 00:05:12.915
# 301268          2778 2018-10-31 23:37:57.354 2018-11-01 00:24:15.681
# 301269          2697 2018-10-31 23:39:20.807 2018-11-01 00:24:18.403
# 307285         46285 2018-10-31 18:57:08.653 2018-11-01 07:48:34.002
# 317284        257638 2018-11-30 12:04:42.521 2018-12-03 11:38:40.833
# 343127        536309 2018-12-31 10:38:32.280 2019-01-06 15:37:01.448
#
#         start station id   start station name  start station latitude  \
# 29147               3184          Paulus Hook               40.714145
# 32263               3187            Warren St               40.721124
# 36486               3203        Hamilton Park               40.727596
# 42038               3273         Manila & 1st               40.721651
# 59727               3212      Christ Hospital               40.734786
# 63194               3270      Jersey & 6th St               40.725289
# 68219               3640       Journal Square               40.733670
# 71072               3184          Paulus Hook               40.714145
# 77331               3192   Liberty Light Rail               40.711242
# 87404               3209         Brunswick St               40.724176
# 88764               3211           Newark Ave               40.721525
# 97105               3276     Marin Light Rail               40.714584
# 100231              3638        Washington St               40.724294
# 101129              3639           Harborside               40.719252
# 101986              3677         Glenwood Ave               40.727551
# 118583              3199         Newport Pkwy               40.728745
# 120671              3202         Newport PATH               40.727224
# 120672              3202         Newport PATH               40.727224
# 127081              3211           Newark Ave               40.721525
# 127084              3211           Newark Ave               40.721525
# 146079              3183       Exchange Place               40.716247
# 174792              3270      Jersey & 6th St               40.725289
# 195800              3186        Grove St PATH               40.719586
# 213288              3213       Van Vorst Park               40.718489
# 221068              3275       Columbus Drive               40.718355
# 224441              3281  Leonard Gordon Park               40.745910
# 232753              3183       Exchange Place               40.716247
# 251991              3210       Pershing Field               40.742677
# 257877              3269      Brunswick & 6th               40.726012
# 257892              3269      Brunswick & 6th               40.726012
# 278372              3186        Grove St PATH               40.719586
# 279314              3187            Warren St               40.721124
# 301268              3276     Marin Light Rail               40.714584
# 301269              3276     Marin Light Rail               40.714584
# 307285              3640       Journal Square               40.733670
# 317284              3195              Sip Ave               40.730743
# 343127              3203        Hamilton Park               40.727596
#
#         start station longitude  end station id     end station name  \
# 29147                -74.033552            3183       Exchange Place
# 32263                -74.038051            3184          Paulus Hook
# 36486                -74.044247            3214     Essex Light Rail
# 42038                -74.042884            3186        Grove St PATH
# 59727                -74.050444            3677         Glenwood Ave
# 63194                -74.045572            3207          Oakland Ave
# 68219                -74.062500            3678        Fairmount Ave
# 71072                -74.033552            3268       Lafayette Park
# 77331                -74.055701            3426           JCBS Depot
# 87404                -74.050656            3186        Grove St PATH
# 88764                -74.046305            3192   Liberty Light Rail
# 97105                -74.042817            3281  Leonard Gordon Park
# 100231               -74.035483            3639           Harborside
# 101129               -74.034234            3681             Grand St
# 101986               -74.071061            3199         Newport Pkwy
# 118583               -74.032108            3275       Columbus Drive
# 120671               -74.033759            3184          Paulus Hook
# 120672               -74.033759            3184          Paulus Hook
# 127081               -74.046305            3639           Harborside
# 127084               -74.046305            3639           Harborside
# 146079               -74.033459            3199         Newport Pkwy
# 174792               -74.045572            3186        Grove St PATH
# 195800               -74.043117            3203        Hamilton Park
# 213288               -74.047727            3213       Van Vorst Park
# 221068               -74.038914            3639           Harborside
# 224441               -74.057271            3193         Lincoln Park
# 232753               -74.033459            3638        Washington St
# 251991               -74.051789            3196       Riverview Park
# 257877               -74.050389            3206              Hilltop
# 257892               -74.050389            3270      Jersey & 6th St
# 278372               -74.043117            3209         Brunswick St
# 279314               -74.038051            3280          Astor Place
# 301268               -74.042817            3275       Columbus Drive
# 301269               -74.042817            3275       Columbus Drive
# 307285               -74.062500            3196       Riverview Park
# 317284               -74.063784            3195              Sip Ave
# 343127               -74.044247            3211           Newark Ave
#
#         end station latitude  ...  dist  year start_month  end_month  \
# 29147              40.716247  ...   0.1  2018       March      April
# 32263              40.714145  ...   0.5  2018       March      April
# 36486              40.712774  ...   1.1  2018       March      April
# 42038              40.719586  ...   0.1  2018       March      April
# 59727              40.727551  ...   1.2  2018       April        May
# 63194              40.737604  ...   0.9  2018       April        May
# 68219              40.725726  ...   0.7  2018       April        May
# 71072              40.713464  ...   1.5  2018         May       June
# 77331              40.709651  ...   0.7  2018         May       June
# 87404              40.719586  ...   0.5  2018         May       June
# 88764              40.711242  ...   0.9  2018         May       June
# 97105              40.745910  ...   2.3  2018         May       June
# 100231             40.719252  ...   0.4  2018         May       June
# 101129             40.715178  ...   0.3  2018         May       June
# 101986             40.728745  ...   2.0  2018         May       June
# 118583             40.718355  ...   0.8  2018        June       July
# 120671             40.714145  ...   0.9  2018        June       July
# 120672             40.714145  ...   0.9  2018        June       July
# 127081             40.719252  ...   0.7  2018        June       July
# 127084             40.719252  ...   0.7  2018        June       July
# 146079             40.728745  ...   0.9  2018        July     August
# 174792             40.719586  ...   0.4  2018        July     August
# 195800             40.727596  ...   0.6  2018      August  September
# 213288             40.718489  ...   0.0  2018      August  September
# 221068             40.719252  ...   0.3  2018      August  September
# 224441             40.724605  ...   1.8  2018      August  September
# 232753             40.724294  ...   0.6  2018   September    October
# 251991             40.744319  ...   0.4  2018   September    October
# 257877             40.731169  ...   0.5  2018   September    October
# 257892             40.725289  ...   0.3  2018   September    October
# 278372             40.724176  ...   0.5  2018     October   November
# 279314             40.719282  ...   1.7  2018     October   November
# 301268             40.718355  ...   0.3  2018     October   November
# 301269             40.718355  ...   0.3  2018     October   November
# 307285             40.744319  ...   1.2  2018     October   November
# 317284             40.730743  ...   0.0  2018    November   December
# 343127             40.721525  ...   0.4  2018    December    January
#
#         start_day    end_day  start_hour end_hour start_minute end_minute
# 29147    Saturday   Saturday          14       10           31         47
# 32263    Saturday   Saturday          11       18           36          3
# 36486      Friday     Friday          15       19           59          2
# 42038    Saturday   Saturday           8       17           13         48
# 59727      Sunday     Sunday          17       11           50          9
# 63194    Thursday   Thursday          18        9           49         35
# 68219      Monday     Monday          23        0           55          2
# 71072    Thursday   Thursday          21        6           18         16
# 77331    Saturday   Saturday          18        9           29         27
# 87404    Thursday   Thursday          23        0           57         19
# 88764    Thursday   Thursday          23        0           57          7
# 97105      Monday     Monday          17       17           34         58
# 100231   Thursday   Thursday          23        0           59         41
# 101129     Friday     Friday          17       13           58         26
# 101986   Thursday   Thursday          23        0           57         19
# 118583     Friday     Friday          21        4           13         11
# 120671   Saturday   Saturday          23        0           51          8
# 120672   Saturday   Saturday          23        0           52          8
# 127081   Saturday   Saturday          19       16           54         20
# 127084   Saturday   Saturday          19       16           57         22
# 146079    Tuesday    Tuesday          19        8           24         41
# 174792    Tuesday    Tuesday          17        8           52         23
# 195800     Friday     Friday          23        0           54         14
# 213288     Friday     Friday          23        0           53         36
# 221068     Friday     Friday          19       17           59         33
# 224441  Wednesday  Wednesday          20       17           28         14
# 232753     Sunday     Sunday          19        9            5         44
# 251991   Thursday   Thursday           3       17           31         21
# 257877     Sunday     Sunday           2        8           13         13
# 257892     Sunday     Sunday          20       19            5         19
# 278372  Wednesday  Wednesday          22        7            7         55
# 279314  Wednesday  Wednesday          23        0           50          5
# 301268  Wednesday  Wednesday          23        0           37         24
# 301269  Wednesday  Wednesday          23        0           39         24
# 307285  Wednesday  Wednesday          18        7           57         48
# 317284     Friday     Friday          12       11            4         38
# 343127     Monday     Monday          10       15           38         37
#
# [37 rows x 25 columns]

# %%
tripdata[tripdata["start_day"] != tripdata["end_day"]]
# Out:
# Empty DataFrame
# Columns: [tripduration, starttime, stoptime, start station id, start station name, start station latitude, start station longitude, end station id, end station name, end station latitude, end station longitude, bikeid, usertype, birth year, gender, dist, year, start_month, end_month, start_day, end_day, start_hour, end_hour, start_minute, end_minute]
# Index: []
#
# [0 rows x 25 columns]

# %%
tripdata[tripdata["start_hour"] != tripdata["end_hour"]]
# Out:
#         tripduration               starttime                stoptime  \
# 8                318 2018-01-02 13:55:58.243 2018-01-02 14:01:16.881
# 9               1852 2018-01-02 16:55:29.639 2018-01-02 17:26:22.305
# 18               230 2018-01-02 17:58:24.636 2018-01-02 18:02:15.632
# 40              5045 2018-01-03 16:26:50.169 2018-01-03 17:50:55.973
# 49             12537 2018-01-03 17:29:09.311 2018-01-03 20:58:07.287
# ...              ...                     ...                     ...
# 353858           577 2018-12-09 10:56:42.298 2018-12-09 11:06:19.965
# 353868           640 2018-12-12 11:54:45.529 2018-12-12 12:05:25.763
# 353875           649 2018-12-16 11:55:07.882 2018-12-16 12:05:57.426
# 353887          1081 2018-12-22 11:51:46.060 2018-12-22 12:09:47.473
# 353889          1233 2018-12-29 12:55:45.969 2018-12-29 13:16:19.596
#
#         start station id start station name  start station latitude  \
# 8                   3183     Exchange Place               40.716247
# 9                   3183     Exchange Place               40.716247
# 18                  3183     Exchange Place               40.716247
# 40                  3183     Exchange Place               40.716247
# 49                  3183     Exchange Place               40.716247
# ...                  ...                ...                     ...
# 353858              3694     Jackson Square               40.711130
# 353868              3694     Jackson Square               40.711130
# 353875              3694     Jackson Square               40.711130
# 353887              3694     Jackson Square               40.711130
# 353889              3694     Jackson Square               40.711130
#
#         start station longitude  end station id     end station name  \
# 8                    -74.033459            3275       Columbus Drive
# 9                    -74.033459            3281  Leonard Gordon Park
# 18                   -74.033459            3267         Morris Canal
# 40                   -74.033459            3183       Exchange Place
# 49                   -74.033459            3214     Essex Light Rail
# ...                         ...             ...                  ...
# 353858               -74.078900            3195              Sip Ave
# 353868               -74.078900            3195              Sip Ave
# 353875               -74.078900            3195              Sip Ave
# 353887               -74.078900            3269      Brunswick & 6th
# 353889               -74.078900            3186        Grove St PATH
#
#         end station latitude  ...  dist  year start_month  end_month  \
# 8                  40.718355  ...   0.3  2018     January    January
# 9                  40.745910  ...   2.4  2018     January    January
# 18                 40.712419  ...   0.4  2018     January    January
# 40                 40.716247  ...   0.0  2018     January    January
# 49                 40.712774  ...   0.3  2018     January    January
# ...                      ...  ...   ...   ...         ...        ...
# 353858             40.730743  ...   1.6  2018    December   December
# 353868             40.730743  ...   1.6  2018    December   December
# 353875             40.730743  ...   1.6  2018    December   December
# 353887             40.726012  ...   1.8  2018    December   December
# 353889             40.719586  ...   2.0  2018    December   December
#
#         start_day    end_day  start_hour end_hour start_minute end_minute
# 8         Tuesday    Tuesday          13       14           55          1
# 9         Tuesday    Tuesday          16       17           55         26
# 18        Tuesday    Tuesday          17       18           58          2
# 40      Wednesday  Wednesday          16       17           26         50
# 49      Wednesday  Wednesday          17       20           29         58
# ...           ...        ...         ...      ...          ...        ...
# 353858     Sunday     Sunday          10       11           56          6
# 353868  Wednesday  Wednesday          11       12           54          5
# 353875     Sunday     Sunday          11       12           55          5
# 353887   Saturday   Saturday          11       12           51          9
# 353889   Saturday   Saturday          12       13           55         16
#
# [49062 rows x 25 columns]

# %%
#!pip install holidays

# %%
from datetime import date
import holidays

# Select country
us_holidays = holidays.US()
data=[]
for ptr in holidays.US(years = 2018).items():
    data.append([ptr[0],ptr[1]])
    
df_holiday = pd.DataFrame(data, columns=['date','holiday'])
  
# print dataframe.
df_holiday
# Out:
#           date                     holiday
# 0   2018-01-01              New Year's Day
# 1   2018-01-15  Martin Luther King Jr. Day
# 2   2018-02-19       Washington's Birthday
# 3   2018-05-28                Memorial Day
# 4   2018-07-04            Independence Day
# 5   2018-09-03                   Labor Day
# 6   2018-10-08                Columbus Day
# 7   2018-11-11                Veterans Day
# 8   2018-11-12     Veterans Day (Observed)
# 9   2018-11-22                Thanksgiving
# 10  2018-12-25               Christmas Day

# %% [markdown]
# ### Add holiday details to trip data

# %%
tripdata['date'] = tripdata['starttime'].dt.date

# %%
df = pd.merge(
    left=tripdata, 
    right=df_holiday, 
    on='date',
    how='left'
)

# %%
df['holiday'].fillna('No Holiday', inplace=True)

# %%
df.head(10)
# Out:
#    tripduration               starttime                stoptime  \
# 0           932 2018-01-01 02:06:17.541 2018-01-01 02:21:50.027
# 1           550 2018-01-01 12:06:18.039 2018-01-01 12:15:28.443
# 2           510 2018-01-01 12:06:56.978 2018-01-01 12:15:27.810
# 3           354 2018-01-01 14:53:10.186 2018-01-01 14:59:05.096
# 4           250 2018-01-01 17:34:30.192 2018-01-01 17:38:40.984
# 5           613 2018-01-01 22:05:05.874 2018-01-01 22:15:19.419
# 6           290 2018-01-02 12:13:51.794 2018-01-02 12:18:42.107
# 7           381 2018-01-02 12:50:03.343 2018-01-02 12:56:24.644
# 8           318 2018-01-02 13:55:58.243 2018-01-02 14:01:16.881
# 9          1852 2018-01-02 16:55:29.639 2018-01-02 17:26:22.305
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
# 5              3183     Exchange Place               40.716247
# 6              3183     Exchange Place               40.716247
# 7              3183     Exchange Place               40.716247
# 8              3183     Exchange Place               40.716247
# 9              3183     Exchange Place               40.716247
#
#    start station longitude  end station id     end station name  \
# 0               -74.033459            3199         Newport Pkwy
# 1               -74.033459            3199         Newport Pkwy
# 2               -74.033459            3199         Newport Pkwy
# 3               -74.033459            3267         Morris Canal
# 4               -74.033459            3639           Harborside
# 5               -74.033459            3203        Hamilton Park
# 6               -74.033459            3267         Morris Canal
# 7               -74.033459            3205    JC Medical Center
# 8               -74.033459            3275       Columbus Drive
# 9               -74.033459            3281  Leonard Gordon Park
#
#    end station latitude  ...  start_month  end_month start_day  end_day  \
# 0             40.728745  ...      January    January    Monday   Monday
# 1             40.728745  ...      January    January    Monday   Monday
# 2             40.728745  ...      January    January    Monday   Monday
# 3             40.712419  ...      January    January    Monday   Monday
# 4             40.719252  ...      January    January    Monday   Monday
# 5             40.727596  ...      January    January    Monday   Monday
# 6             40.712419  ...      January    January   Tuesday  Tuesday
# 7             40.716540  ...      January    January   Tuesday  Tuesday
# 8             40.718355  ...      January    January   Tuesday  Tuesday
# 9             40.745910  ...      January    January   Tuesday  Tuesday
#
#    start_hour  end_hour  start_minute end_minute        date         holiday
# 0           2         2             6         21  2018-01-01  New Year's Day
# 1          12        12             6         15  2018-01-01  New Year's Day
# 2          12        12             6         15  2018-01-01  New Year's Day
# 3          14        14            53         59  2018-01-01  New Year's Day
# 4          17        17            34         38  2018-01-01  New Year's Day
# 5          22        22             5         15  2018-01-01  New Year's Day
# 6          12        12            13         18  2018-01-02      No Holiday
# 7          12        12            50         56  2018-01-02      No Holiday
# 8          13        14            55          1  2018-01-02      No Holiday
# 9          16        17            55         26  2018-01-02      No Holiday
#
# [10 rows x 27 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353892 entries, 0 to 353891
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             353892 non-null  int64
#  1   starttime                353892 non-null  datetime64[ns]
#  2   stoptime                 353892 non-null  datetime64[ns]
#  3   start station id         353892 non-null  int64
#  4   start station name       353892 non-null  object
#  5   start station latitude   353892 non-null  float64
#  6   start station longitude  353892 non-null  float64
#  7   end station id           353892 non-null  int64
#  8   end station name         353892 non-null  object
#  9   end station latitude     353892 non-null  float64
#  10  end station longitude    353892 non-null  float64
#  11  bikeid                   353892 non-null  int64
#  12  usertype                 353892 non-null  object
#  13  birth year               353892 non-null  int64
#  14  gender                   353892 non-null  int64
#  15  dist                     353892 non-null  float64
#  16  year                     353892 non-null  int64
#  17  start_month              353892 non-null  object
#  18  end_month                353892 non-null  object
#  19  start_day                353892 non-null  object
#  20  end_day                  353892 non-null  object
#  21  start_hour               353892 non-null  int64
#  22  end_hour                 353892 non-null  int64
#  23  start_minute             353892 non-null  int64
#  24  end_minute               353892 non-null  int64
#  25  date                     353892 non-null  datetime64[ns]
#  26  holiday                  353892 non-null  object
# dtypes: datetime64[ns](3), float64(5), int64(11), object(8)
# memory usage: 75.6+ MB

# %% [markdown]
# ## Read a weather data

# %%
weather_data = pd.read_csv("../dataset/nyc_weather_data.csv")
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   datetime        365 non-null    object
#  1   tempmax         365 non-null    float64
#  2   tempmin         365 non-null    float64
#  3   temp            365 non-null    float64
#  4   dew             365 non-null    float64
#  5   humidity        365 non-null    float64
#  6   snow            365 non-null    float64
#  7   snowdepth       365 non-null    float64
#  8   windspeed       365 non-null    float64
#  9   visibility      365 non-null    float64
#  10  solarradiation  365 non-null    float64
#  11  cloudcover      365 non-null    float64
#  12  conditions      365 non-null    object
#  13  description     365 non-null    object
# dtypes: float64(11), object(3)
# memory usage: 40.0+ KB

# %%
weather_data.isnull().sum()
# Out:
# datetime          0
# tempmax           0
# tempmin           0
# temp              0
# dew               0
# humidity          0
# snow              0
# snowdepth         0
# windspeed         0
# visibility        0
# solarradiation    0
# cloudcover        0
# conditions        0
# description       0
# dtype: int64

# %%
weather_data['date'] = pd.to_datetime(weather_data['datetime'])
weather_data.dtypes
# Out:
# datetime                  object
# tempmax                  float64
# tempmin                  float64
# temp                     float64
# dew                      float64
# humidity                 float64
# snow                     float64
# snowdepth                float64
# windspeed                float64
# visibility               float64
# solarradiation           float64
# cloudcover               float64
# conditions                object
# description               object
# date              datetime64[ns]
# dtype: object

# %%
complete_df = pd.merge(
    left=df, 
    right=weather_data, 
    on='date',
    how='left'
)

# %%
complete_df.head()
# Out:
#    tripduration               starttime                stoptime  \
# 0           932 2018-01-01 02:06:17.541 2018-01-01 02:21:50.027
# 1           550 2018-01-01 12:06:18.039 2018-01-01 12:15:28.443
# 2           510 2018-01-01 12:06:56.978 2018-01-01 12:15:27.810
# 3           354 2018-01-01 14:53:10.186 2018-01-01 14:59:05.096
# 4           250 2018-01-01 17:34:30.192 2018-01-01 17:38:40.984
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# 1               -74.033459            3199     Newport Pkwy
# 2               -74.033459            3199     Newport Pkwy
# 3               -74.033459            3267     Morris Canal
# 4               -74.033459            3639       Harborside
#
#    end station latitude  ...   dew  humidity snow  snowdepth  windspeed  \
# 0             40.728745  ... -19.9      47.8  0.0        0.1       18.5
# 1             40.728745  ... -19.9      47.8  0.0        0.1       18.5
# 2             40.728745  ... -19.9      47.8  0.0        0.1       18.5
# 3             40.712419  ... -19.9      47.8  0.0        0.1       18.5
# 4             40.719252  ... -19.9      47.8  0.0        0.1       18.5
#
#    visibility  solarradiation cloudcover conditions  \
# 0        16.0           106.7        0.3      Clear
# 1        16.0           106.7        0.3      Clear
# 2        16.0           106.7        0.3      Clear
# 3        16.0           106.7        0.3      Clear
# 4        16.0           106.7        0.3      Clear
#
#                             description
# 0  Clear conditions throughout the day.
# 1  Clear conditions throughout the day.
# 2  Clear conditions throughout the day.
# 3  Clear conditions throughout the day.
# 4  Clear conditions throughout the day.
#
# [5 rows x 41 columns]

# %%
complete_df.isnull().sum()
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# birth year                 0
# gender                     0
# dist                       0
# year                       0
# start_month                0
# end_month                  0
# start_day                  0
# end_day                    0
# start_hour                 0
# end_hour                   0
# start_minute               0
# end_minute                 0
# date                       0
# holiday                    0
# datetime                   0
# tempmax                    0
# tempmin                    0
# temp                       0
# dew                        0
# humidity                   0
# snow                       0
# snowdepth                  0
# windspeed                  0
# visibility                 0
# solarradiation             0
# cloudcover                 0
# conditions                 0
# description                0
# dtype: int64

# %% [markdown]
# ## add seasonality data
# 1. spring (March-May)
# 2. summer (June-August)
# 3. autumn (September-November)
# 4. winter (December-February

# %%
def add_seasonality(month):
    if (month == 'March' or month == 'April' or month == 'May'):
        return 'spring'
    elif month == 'June' or month == 'July' or month == 'August':
        return 'summer'
    elif month == 'September' or month == 'October' or month == 'November':
        return 'autumn'
    elif month == 'December' or month == 'January' or month == 'February':
        return 'winter'

# %%
complete_df['seasons'] = complete_df.apply(lambda r: add_seasonality(r['start_month']) , axis=1)

# %%
complete_df
# Out:
#         tripduration               starttime                stoptime  \
# 0                932 2018-01-01 02:06:17.541 2018-01-01 02:21:50.027
# 1                550 2018-01-01 12:06:18.039 2018-01-01 12:15:28.443
# 2                510 2018-01-01 12:06:56.978 2018-01-01 12:15:27.810
# 3                354 2018-01-01 14:53:10.186 2018-01-01 14:59:05.096
# 4                250 2018-01-01 17:34:30.192 2018-01-01 17:38:40.984
# ...              ...                     ...                     ...
# 353887          1081 2018-12-22 11:51:46.060 2018-12-22 12:09:47.473
# 353888           344 2018-12-25 21:40:09.866 2018-12-25 21:45:54.267
# 353889          1233 2018-12-29 12:55:45.969 2018-12-29 13:16:19.596
# 353890          1057 2018-12-30 15:32:09.332 2018-12-30 15:49:46.351
# 353891           301 2018-12-31 16:34:11.934 2018-12-31 16:39:13.834
#
#         start station id start station name  start station latitude  \
# 0                   3183     Exchange Place               40.716247
# 1                   3183     Exchange Place               40.716247
# 2                   3183     Exchange Place               40.716247
# 3                   3183     Exchange Place               40.716247
# 4                   3183     Exchange Place               40.716247
# ...                  ...                ...                     ...
# 353887              3694     Jackson Square               40.711130
# 353888              3694     Jackson Square               40.711130
# 353889              3694     Jackson Square               40.711130
# 353890              3694     Jackson Square               40.711130
# 353891              3694     Jackson Square               40.711130
#
#         start station longitude  end station id         end station name  \
# 0                    -74.033459            3199             Newport Pkwy
# 1                    -74.033459            3199             Newport Pkwy
# 2                    -74.033459            3199             Newport Pkwy
# 3                    -74.033459            3267             Morris Canal
# 4                    -74.033459            3639               Harborside
# ...                         ...             ...                      ...
# 353887               -74.078900            3269          Brunswick & 6th
# 353888               -74.078900            3280              Astor Place
# 353889               -74.078900            3186            Grove St PATH
# 353890               -74.078900            3213           Van Vorst Park
# 353891               -74.078900            3277  Communipaw & Berry Lane
#
#         end station latitude  ...  humidity  snow snowdepth  windspeed  \
# 0                  40.728745  ...      47.8   0.0       0.1       18.5
# 1                  40.728745  ...      47.8   0.0       0.1       18.5
# 2                  40.728745  ...      47.8   0.0       0.1       18.5
# 3                  40.712419  ...      47.8   0.0       0.1       18.5
# 4                  40.719252  ...      47.8   0.0       0.1       18.5
# ...                      ...  ...       ...   ...       ...        ...
# 353887             40.726012  ...      67.4   0.0       0.0       45.4
# 353888             40.719282  ...      52.8   0.0       0.0       24.9
# 353889             40.719586  ...      63.9   0.0       0.0       39.2
# 353890             40.718489  ...      66.0   0.0       0.0       20.8
# 353891             40.714358  ...      78.2   0.0       0.0       21.7
#
#         visibility  solarradiation  cloudcover              conditions  \
# 0             16.0           106.7         0.3                   Clear
# 1             16.0           106.7         0.3                   Clear
# 2             16.0           106.7         0.3                   Clear
# 3             16.0           106.7         0.3                   Clear
# 4             16.0           106.7         0.3                   Clear
# ...            ...             ...         ...                     ...
# 353887        15.3            47.8        90.7          Rain, Overcast
# 353888        16.0            86.5        33.7        Partially cloudy
# 353889        15.8            94.2        64.6        Partially cloudy
# 353890        15.5            35.6        73.2        Partially cloudy
# 353891        12.4            34.8        74.0  Rain, Partially cloudy
#
#                                               description seasons
# 0                    Clear conditions throughout the day.  winter
# 1                    Clear conditions throughout the day.  winter
# 2                    Clear conditions throughout the day.  winter
# 3                    Clear conditions throughout the day.  winter
# 4                    Clear conditions throughout the day.  winter
# ...                                                   ...     ...
# 353887  Cloudy skies throughout the day with early mor...  winter
# 353888                  Partly cloudy throughout the day.  winter
# 353889                  Partly cloudy throughout the day.  winter
# 353890                  Partly cloudy throughout the day.  winter
# 353891        Partly cloudy throughout the day with rain.  winter
#
# [353892 rows x 42 columns]

# %%
complete_df['seasons'].unique()
# Out:
# array(['winter', 'spring', 'summer', 'autumn'], dtype=object)

# %%
complete_df.to_csv("../dataset/complete_bike_sharing.csv", index=False,)
