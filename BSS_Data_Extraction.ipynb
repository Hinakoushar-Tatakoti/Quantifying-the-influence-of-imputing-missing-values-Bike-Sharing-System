# %% [markdown]
# <a href="https://colab.research.google.com/github/Hinakoushar-Tatakoti/Quantifying-the-influence-of-imputing-missing-values-Bike-Sharing-System/blob/main/BSS_Data_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Initial analysis of Bike sharing data
# Data is been imported from Google big cloud open data
# bigquery-public-data.new_york_citibike which contains
# 1. citibike_stations informations
# 2. citibike_trips information

# %%
## Mount the google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/dataset/bike-sharing_2018-04-01.csv"
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    tripduration                starttime                 stoptime  \
# 0           875  2018-04-13 07:17:16.322  2018-04-13 07:31:52.213
# 1          1630  2018-05-03 06:07:45.841  2018-05-03 06:34:56.596
# 2           908  2018-04-22 09:18:35.645  2018-04-22 09:33:44.229
# 3          1100  2018-04-11 17:01:19.363  2018-04-11 17:19:40.353
# 4           837  2018-05-15 11:27:08.220  2018-05-15 11:41:05.509
#
#    start_station_id start_station_name  start_station_latitude  \
# 0               332          Cherry St               40.712199
# 1               332          Cherry St               40.712199
# 2               332          Cherry St               40.712199
# 3               332          Cherry St               40.712199
# 4               332          Cherry St               40.712199
#
#    start_station_longitude  end_station_id             end_station_name  \
# 0               -73.979481             417       Barclay St & Church St
# ...

# %%
data.describe()
# Out:
#        tripduration  start_station_id  start_station_latitude  \
# count  2.624910e+06      2.624910e+06            2.624910e+06
# mean   1.072139e+03      1.544330e+03            4.073686e+01
# std    2.283764e+04      1.420908e+03            3.120878e-02
# min    6.100000e+01      7.200000e+01            4.065540e+01
# 25%    3.650000e+02      3.720000e+02            4.071723e+01
# 50%    6.310000e+02      4.960000e+02            4.073650e+01
# 75%    1.118000e+03      3.177000e+03            4.075971e+01
# max    1.028368e+07      3.686000e+03            4.081439e+01
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count             2.624910e+06    2.624910e+06          2.624910e+06
# mean             -7.398245e+01    1.583527e+03          4.073664e+01
# std               1.936090e-02    1.434049e+03          3.082768e-02
# min              -7.402535e+01    7.200000e+01          4.065540e+01
# ...

# %%
data.count()
# Out:
# tripduration                 2624910
# starttime                    2624910
# stoptime                     2624910
# start_station_id             2624910
# start_station_name           2624910
# start_station_latitude       2624910
# start_station_longitude      2624910
# end_station_id               2624910
# end_station_name             2624910
# end_station_latitude         2624910
# end_station_longitude        2624910
# bikeid                       2624910
# usertype                     2624910
# birth_year                   2624910
# gender                       2624910
# customer_plan                      0
# station_id                   2624910
# region_id                    2624910
# rental_methods               2624910
# capacity                     2624910
# eightd_has_key_dispenser     2624910
# eightd_has_available_keys    2624910
# num_bikes_available          2624910
# num_docks_available          2624910
# num_bikes_disabled           2624910
# ...
