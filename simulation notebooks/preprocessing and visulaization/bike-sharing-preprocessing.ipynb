# %% [markdown]
# ## CitiBike data is collected for 1 year 2018
# https://ride.citibikenyc.com/system-data
#
# Data Schema:
# Trip Duration (seconds)
#
# *   Start Time and Date
# *   Stop Time and Date
# *   Start Station Name
# *   End Station Name
# *   Station ID
# *   Station Lat/Long
# *   Bike ID
# *   User Type (Customer = 24-hour pass or 3-day pass user; Subscriber = Annual    Member)
# *   Gender (Zero=unknown; 1=male; 2=female)
# *   Year of Birth

# %%
import pandas as pd
import numpy as np
import haversine as hs
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import iglob

import warnings
warnings.filterwarnings("ignore")

# %%
#!pip install haversine

# %%
path = r'D:\Beuth Sems\Thesis\dataset\JC-2018*.csv'

all_rec = iglob(path, recursive=True)     
dataframes = (pd.read_csv(f) for f in all_rec)
tripdata = pd.concat(dataframes, ignore_index=True)

# %%
tripdata.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  3.538920e+05     353892.000000           353892.000000
# mean   6.733930e+02       3264.996606               40.722724
# std    7.004022e+03        138.429108                0.007251
# min    6.100000e+01       3183.000000               40.692640
# 25%    2.280000e+02       3192.000000               40.718211
# 50%    3.350000e+02       3205.000000               40.721525
# 75%    5.490000e+02       3272.000000               40.727224
# max    2.061932e+06       3694.000000               40.748716
#
#        start station longitude  end station id  end station latitude  \
# count            353892.000000   353892.000000         353892.000000
# mean                -74.046039     3258.408418             40.722326
# std                   0.010755      147.610023              0.007095
# min                 -74.096937      127.000000             40.679331
# 25%                 -74.050444     3186.000000             40.717732
# 50%                 -74.043845     3203.000000             40.721124
# 75%                 -74.038051     3272.000000             40.727224
# max                 -74.032108     3694.000000             40.814326
#
#        end station longitude         bikeid     birth year         gender
# count          353892.000000  353892.000000  353892.000000  353892.000000
# mean              -74.045505   29452.498808    1980.387875       1.152388
# std                 0.010759    2529.992371      10.268528       0.500198
# min               -74.096937   14697.000000    1887.000000       0.000000
# 25%               -74.049968   26315.000000    1974.000000       1.000000
# 50%               -74.043117   29493.000000    1983.000000       1.000000
# 75%               -74.037683   29679.000000    1988.000000       1.000000
# max               -73.947821   35009.000000    2002.000000       2.000000

# %%
tripdata.isnull().sum()
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# birth year                 0
# gender                     0
# dtype: int64

# %%
tripdata.shape
# Out:
# (353892, 15)

# %%
tripdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353892 entries, 0 to 353891
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             353892 non-null  int64
#  1   starttime                353892 non-null  object
#  2   stoptime                 353892 non-null  object
#  3   start station id         353892 non-null  int64
#  4   start station name       353892 non-null  object
#  5   start station latitude   353892 non-null  float64
#  6   start station longitude  353892 non-null  float64
#  7   end station id           353892 non-null  int64
#  8   end station name         353892 non-null  object
#  9   end station latitude     353892 non-null  float64
#  10  end station longitude    353892 non-null  float64
#  11  bikeid                   353892 non-null  int64
#  12  usertype                 353892 non-null  object
#  13  birth year               353892 non-null  int64
#  14  gender                   353892 non-null  int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 40.5+ MB

# %% [markdown]
# ### Explode the start and end date into different columns

# %%
tripdata['starttime'] = pd.to_datetime(tripdata['starttime'])
tripdata['stoptime'] = pd.to_datetime(tripdata['stoptime'])
tripdata['date'] = tripdata['starttime'].dt.date
tripdata["month"] = tripdata["starttime"].dt.month
# tripdata['day'] = tripdata["starttime"].dt.day_name()
# tripdata["month"] = tripdata["starttime"].dt.month
tripdata['day'] = tripdata["starttime"].dt.day
tripdata["hour"] = tripdata["starttime"].dt.hour
tripdata["min"] = tripdata["starttime"].dt.minute
tripdata["year"] =tripdata['starttime'].dt.year

# %%
## Convert seconds tripduration into miles
tripdata['tripduration'] = np.round(tripdata['tripduration']/60,2)

# %% [markdown]
# ## https://www.visualcrossing.com/weather/weather-data-services
#
# temp ---	C
# dew	 --- DC
# feelslike --- C
# precip --- mm
# precipprob----%
# snow----cm
# snowdepth---cm
# windspeed---kph
# winddir---degrees
# visibility---km
# cloudcover---%
# humidity---%
# pressure----mb
# solarradiation---W/m2
# solarenergy---MJ/m2

# %%
data1 = pd.read_csv("../../dataset/weather/jan2018.csv")

# %%
data2 = pd.read_csv("../../dataset/weather/dec2018.csv")

# %%
data1.isnull().sum()
# Out:
# name                  0
# datetime              0
# temp                  0
# feelslike             0
# dew                   0
# humidity              0
# precip                0
# precipprob            0
# preciptype          638
# snow                  0
# snowdepth             0
# windgust            383
# windspeed             0
# winddir               0
# sealevelpressure      0
# cloudcover            0
# visibility            0
# solarradiation        0
# solarenergy         353
# uvindex               0
# severerisk          744
# conditions            0
# icon                  0
# stations              0
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# name                   0
# datetime               0
# temp                   0
# feelslike              0
# dew                    0
# humidity               0
# precip                 0
# precipprob             0
# preciptype          6715
# snow                   0
# snowdepth              0
# windgust            5709
# windspeed              0
# winddir                0
# sealevelpressure       0
# cloudcover             0
# visibility             0
# solarradiation         0
# solarenergy         3334
# uvindex                0
# severerisk          8016
# conditions             0
# icon                   0
# stations               0
# dtype: int64

# %%
data1.drop(['preciptype', 'windgust','solarenergy','severerisk'], axis=1, inplace=True)
data2.drop(['preciptype', 'windgust','solarenergy','severerisk'], axis=1, inplace=True)

# %%
d_con = [data1, data2]
weather_data = pd.concat(d_con)

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8760 entries, 0 to 8015
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              8760 non-null   object
#  1   datetime          8760 non-null   object
#  2   temp              8760 non-null   float64
#  3   feelslike         8760 non-null   float64
#  4   dew               8760 non-null   float64
#  5   humidity          8760 non-null   float64
#  6   precip            8760 non-null   float64
#  7   precipprob        8760 non-null   int64
#  8   snow              8760 non-null   float64
#  9   snowdepth         8760 non-null   float64
#  10  windspeed         8760 non-null   float64
#  11  winddir           8760 non-null   float64
#  12  sealevelpressure  8760 non-null   float64
#  13  cloudcover        8760 non-null   float64
#  14  visibility        8760 non-null   float64
#  15  solarradiation    8760 non-null   float64
#  16  uvindex           8760 non-null   int64
#  17  conditions        8760 non-null   object
#  18  icon              8760 non-null   object
#  19  stations          8760 non-null   object
# dtypes: float64(13), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
weather_data['datetime'] = pd.to_datetime(weather_data['datetime'])
weather_data['date'] = weather_data['datetime'].dt.date
# data["month"] = data["datetime"].dt.month_name()
weather_data['day'] = weather_data["datetime"].dt.day
weather_data["month"] = weather_data["datetime"].dt.month
# data['day'] = data["datetime"].dt.day_name()
weather_data["hour"] = weather_data["datetime"].dt.hour
weather_data["min"] = weather_data["datetime"].dt.minute
weather_data["year"] = weather_data['datetime'].dt.year

# %%
## Convert windspeed from kph to mph
weather_data['windspeed'] = np.round(weather_data['windspeed']/1.609344)

# %%
## Convert visibility km to miles
##1 km is equals to 0.62137119 miles
weather_data['visibility'] = np.round(weather_data['visibility']*0.62137119)

# %%
tripdata.drop(["stoptime","year","date"], axis=1, inplace=True)

# %%
weather_data.drop(["name","datetime","year","stations", "icon", "min"], axis=1, inplace=True)

# %%
result = pd.merge(tripdata, weather_data, on=["month", "day", "hour"], how="left")

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353897 entries, 0 to 353896
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             353897 non-null  float64
#  1   starttime                353897 non-null  datetime64[ns]
#  2   start station id         353897 non-null  int64
#  3   start station name       353897 non-null  object
#  4   start station latitude   353897 non-null  float64
#  5   start station longitude  353897 non-null  float64
#  6   end station id           353897 non-null  int64
#  7   end station name         353897 non-null  object
#  8   end station latitude     353897 non-null  float64
#  9   end station longitude    353897 non-null  float64
#  10  bikeid                   353897 non-null  int64
#  11  usertype                 353897 non-null  object
#  12  birth year               353897 non-null  int64
#  13  gender                   353897 non-null  int64
#  14  month                    353897 non-null  int64
#  15  day                      353897 non-null  int64
#  16  hour                     353897 non-null  int64
#  17  min                      353897 non-null  int64
#  18  temp                     353897 non-null  float64
#  19  feelslike                353897 non-null  float64
#  20  dew                      353897 non-null  float64
#  21  humidity                 353897 non-null  float64
#  22  precip                   353897 non-null  float64
#  23  precipprob               353897 non-null  int64
#  24  snow                     353897 non-null  float64
#  25  snowdepth                353897 non-null  float64
#  26  windspeed                353897 non-null  float64
#  27  winddir                  353897 non-null  float64
#  28  sealevelpressure         353897 non-null  float64
#  29  cloudcover               353897 non-null  float64
#  30  visibility               353897 non-null  float64
#  31  solarradiation           353897 non-null  float64
#  32  uvindex                  353897 non-null  int64
#  33  conditions               353897 non-null  object
#  34  date                     353897 non-null  object
# dtypes: datetime64[ns](1), float64(18), int64(11), object(5)
# memory usage: 97.2+ MB

# %%
result.head(3)
# Out:
#    tripduration               starttime  start station id start station name  \
# 0         15.53 2018-01-01 02:06:17.541              3183     Exchange Place
# 1          9.17 2018-01-01 12:06:18.039              3183     Exchange Place
# 2          8.50 2018-01-01 12:06:56.978              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3199
# 1               40.716247               -74.033459            3199
# 2               40.716247               -74.033459            3199
#
#   end station name  end station latitude  end station longitude  ...  \
# 0     Newport Pkwy             40.728745             -74.032108  ...
# 1     Newport Pkwy             40.728745             -74.032108  ...
# 2     Newport Pkwy             40.728745             -74.032108  ...
#
#    snowdepth windspeed  winddir  sealevelpressure  cloudcover  visibility  \
# 0        0.0       3.0    295.0            1026.8         0.0         6.0
# 1        0.0       4.0    302.0            1028.0         0.2         6.0
# 2        0.0       4.0    302.0            1028.0         0.2         6.0
#
#    solarradiation  uvindex  conditions        date
# 0             0.0        0       Clear  2018-01-01
# 1           493.0        5       Clear  2018-01-01
# 2           493.0        5       Clear  2018-01-01
#
# [3 rows x 35 columns]

# %% [markdown]
# manhatten distnace calculated using :
# https://medium.com/@simplyjk/why-manhattan-distance-formula-doesnt-apply-to-manhattan-7db0ebb1c5f6

# %%
def haversine(lat1, lon1, lat2, lon2):     
    R = 3958.76 # Earth radius in miles          
    dLat, dLon, lat1, lat2 = np.radians(lat2 - lat1), np.radians(lon2 - lon1),  np.radians(lat1), np.radians(lat2)     
    
    a =  np.sin(dLat/2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dLon/2) ** 2     
    c = 2 * np.arcsin(np.sqrt(a))          
    return R * c

# %%
def manhattan_dist(lat1, lon1, lat2, lon2):
    
    # Pickup coordinates
    p = np.stack([lat1, lon1], axis = 1)
    
    # Dropoff coordinates
    d = np.stack([lat2, lon2], axis = 1)
    
    theta1 = np.radians(-28.904)
    theta2 = np.radians(28.904)
    
    ## Rotation matrix
    R1 = np.array([[np.cos(theta1), np.sin(theta1)], 
                   [-np.sin(theta1), np.cos(theta1)]]
                 )
    R2 = np.array([[np.cos(theta2), np.sin(theta2)], 
                   [-np.sin(theta2), np.cos(theta2)]]
                 )
    
    # Rotate Pickup and Dropoff coordinates by -29 degress in World2
    pT = R1 @ p.T  
    dT = R1 @ d.T  
    
    # Coordinates of Hinge point in the rotated world 
    vT = np.stack((pT[0,:], dT[1,:]))
    # Coordinates of Hinge point in the real world 
    v = R2 @ vT
    """ Finally,
    
    Manhattan distance 
            = 
    Haversine dist between Pickup & Hingept
            +
    Haversine dist between Hinge pt & Dropoff location 
    """
    
    return (haversine(p.T[0], p.T[1], v[0], v[1]) + 
            haversine(v[0], v[1], d.T[0], d.T[1])
           )

# %%
result["dist"] = manhattan_dist(
    result["start station latitude"], result["start station longitude"],
    result["end station latitude"], result["end station longitude"]
)

# %%
result["dist"]
# Out:
# 0         1.084267
# 1         1.084267
# 2         1.084267
# 3         0.415696
# 4         0.240932
#             ...
# 353892    1.872980
# 353893    0.828647
# 353894    2.657139
# 353895    2.315132
# 353896    0.902881
# Name: dist, Length: 353897, dtype: float64

# %%
result.head(5)
# Out:
#    tripduration               starttime  start station id start station name  \
# 0         15.53 2018-01-01 02:06:17.541              3183     Exchange Place
# 1          9.17 2018-01-01 12:06:18.039              3183     Exchange Place
# 2          8.50 2018-01-01 12:06:56.978              3183     Exchange Place
# 3          5.90 2018-01-01 14:53:10.186              3183     Exchange Place
# 4          4.17 2018-01-01 17:34:30.192              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3199
# 1               40.716247               -74.033459            3199
# 2               40.716247               -74.033459            3199
# 3               40.716247               -74.033459            3267
# 4               40.716247               -74.033459            3639
#
#   end station name  end station latitude  end station longitude  ...  \
# 0     Newport Pkwy             40.728745             -74.032108  ...
# 1     Newport Pkwy             40.728745             -74.032108  ...
# 2     Newport Pkwy             40.728745             -74.032108  ...
# 3     Morris Canal             40.712419             -74.038526  ...
# 4       Harborside             40.719252             -74.034234  ...
#
#    windspeed winddir  sealevelpressure  cloudcover  visibility  \
# 0        3.0   295.0            1026.8         0.0         6.0
# 1        4.0   302.0            1028.0         0.2         6.0
# 2        4.0   302.0            1028.0         0.2         6.0
# 3        0.0   354.0            1027.0         0.2         6.0
# 4        4.0   300.0            1027.1         0.2         6.0
#
#    solarradiation  uvindex  conditions        date      dist
# 0             0.0        0       Clear  2018-01-01  1.084267
# 1           493.0        5       Clear  2018-01-01  1.084267
# 2           493.0        5       Clear  2018-01-01  1.084267
# 3           392.0        4       Clear  2018-01-01  0.415696
# 4            10.0        0       Clear  2018-01-01  0.240932
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Explode the start and end date into different columns

# %%
result.columns
# Out:
# Index(['tripduration', 'starttime', 'start station id', 'start station name',
#        'start station latitude', 'start station longitude', 'end station id',
#        'end station name', 'end station latitude', 'end station longitude',
#        'bikeid', 'usertype', 'birth year', 'gender', 'month', 'day', 'hour',
#        'min', 'temp', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'snow', 'snowdepth', 'windspeed', 'winddir', 'sealevelpressure',
#        'cloudcover', 'visibility', 'solarradiation', 'uvindex', 'conditions',
#        'date', 'dist'],
#       dtype='object')

# %%
result['birthyear'] = pd.to_numeric(result['birth year'], downcast='integer')
result['years_old'] = 2018 - result['birthyear'] 
Age_Groups = ["<20", "20-29", "30-39", "40-49", "50-59", "60-64","65+"]
Age_Groups_Limits = [0, 20, 30, 40, 50, 60, 65, np.inf]
Age_Min = 0
Age_Max = 100
result["age_group"] = pd.cut(result["years_old"], Age_Groups_Limits, labels=Age_Groups)

# %%
#!pip install holidays

# %%
from datetime import date
import holidays

# Select country
Germany_holidays = holidays.NYSE()
data=[]
for ptr in holidays.NYSE(years = 2018).items():
    data.append([ptr[0],ptr[1]])
    
df_holiday = pd.DataFrame(data, columns=['date','holiday'])
  
# print dataframe.
df_holiday
# Out:
#          date                     holiday
# 0  2018-01-01              New Year's Day
# 1  2018-01-15  Martin Luther King Jr. Day
# 2  2018-02-19       Washington's Birthday
# 3  2018-03-30                 Good Friday
# 4  2018-05-28                Memorial Day
# 5  2018-07-04            Independence Day
# 6  2018-09-03                   Labor Day
# 7  2018-11-22            Thanksgiving Day
# 8  2018-12-25               Christmas Day

# %% [markdown]
# ### Add holiday details to trip data

# %%
df = pd.merge(
    left=result, 
    right=df_holiday, 
    on='date',
    how='left'
)

# %%
df['holiday'].fillna('No Holiday', inplace=True)

# %%
df.head(3)
# Out:
#    tripduration               starttime  start station id start station name  \
# 0         15.53 2018-01-01 02:06:17.541              3183     Exchange Place
# 1          9.17 2018-01-01 12:06:18.039              3183     Exchange Place
# 2          8.50 2018-01-01 12:06:56.978              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3199
# 1               40.716247               -74.033459            3199
# 2               40.716247               -74.033459            3199
#
#   end station name  end station latitude  end station longitude  ...  \
# 0     Newport Pkwy             40.728745             -74.032108  ...
# 1     Newport Pkwy             40.728745             -74.032108  ...
# 2     Newport Pkwy             40.728745             -74.032108  ...
#
#    visibility solarradiation  uvindex  conditions        date      dist  \
# 0         6.0            0.0        0       Clear  2018-01-01  1.084267
# 1         6.0          493.0        5       Clear  2018-01-01  1.084267
# 2         6.0          493.0        5       Clear  2018-01-01  1.084267
#
#    birthyear  years_old  age_group         holiday
# 0       1992         26      20-29  New Year's Day
# 1       1969         49      40-49  New Year's Day
# 2       1946         72        65+  New Year's Day
#
# [3 rows x 40 columns]

# %%
df.drop(['day','month'], axis=1, inplace=True)

# %%
df['starttime'] = pd.to_datetime(df['starttime'])
df['day'] = df["starttime"].dt.day_name()
df["month"] = df["starttime"].dt.month_name()

# %% [markdown]
# ## add seasonality data
# 1. spring (March-May)
# 2. summer (June-August)
# 3. autumn (September-November)
# 4. winter (December-February

# %%
def add_seasonality(month):
    if (month == 'March' or month == 'April' or month == 'May'):
        return 'spring'
    elif month == 'June' or month == 'July' or month == 'August':
        return 'summer'
    elif month == 'September' or month == 'October' or month == 'November':
        return 'autumn'
    elif month == 'December' or month == 'January' or month == 'February':
        return 'winter'

# %%
df['month'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
df['seasons'] = df.apply(lambda r: add_seasonality(r['month']) , axis=1)

# %%
df.head(5)
# Out:
#    tripduration               starttime  start station id start station name  \
# 0         15.53 2018-01-01 02:06:17.541              3183     Exchange Place
# 1          9.17 2018-01-01 12:06:18.039              3183     Exchange Place
# 2          8.50 2018-01-01 12:06:56.978              3183     Exchange Place
# 3          5.90 2018-01-01 14:53:10.186              3183     Exchange Place
# 4          4.17 2018-01-01 17:34:30.192              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3199
# 1               40.716247               -74.033459            3199
# 2               40.716247               -74.033459            3199
# 3               40.716247               -74.033459            3267
# 4               40.716247               -74.033459            3639
#
#   end station name  end station latitude  end station longitude  ...  \
# 0     Newport Pkwy             40.728745             -74.032108  ...
# 1     Newport Pkwy             40.728745             -74.032108  ...
# 2     Newport Pkwy             40.728745             -74.032108  ...
# 3     Morris Canal             40.712419             -74.038526  ...
# 4       Harborside             40.719252             -74.034234  ...
#
#    conditions        date      dist  birthyear  years_old  age_group  \
# 0       Clear  2018-01-01  1.084267       1992         26      20-29
# 1       Clear  2018-01-01  1.084267       1969         49      40-49
# 2       Clear  2018-01-01  1.084267       1946         72        65+
# 3       Clear  2018-01-01  0.415696       1994         24      20-29
# 4       Clear  2018-01-01  0.240932       1991         27      20-29
#
#           holiday     day    month  seasons
# 0  New Year's Day  Monday  January   winter
# 1  New Year's Day  Monday  January   winter
# 2  New Year's Day  Monday  January   winter
# 3  New Year's Day  Monday  January   winter
# 4  New Year's Day  Monday  January   winter
#
# [5 rows x 41 columns]

# %%
df['seasons'].unique()
# Out:
# array(['winter', 'spring', 'summer', 'autumn'], dtype=object)

# %%
## Convert gender into categorical value
##Gender (Zero=unknown; 1=male; 2=female)
def add_gender_cat_values(gender):
    if (gender == 0):
        return 'unknown'
    elif gender == 1:
        return 'male'
    elif gender == 2:
        return 'female'

# %%
df['gender_cat'] = df.apply(lambda r: add_gender_cat_values(r['gender']) , axis=1)

# %%
df['gender_cat'].unique()
# Out:
# array(['male', 'female', 'unknown'], dtype=object)

# %%
df.tail(2)
# Out:
#         tripduration               starttime  start station id  \
# 353895         17.62 2018-12-30 15:32:09.332              3694
# 353896          5.02 2018-12-31 16:34:11.934              3694
#
#        start station name  start station latitude  start station longitude  \
# 353895     Jackson Square                40.71113                 -74.0789
# 353896     Jackson Square                40.71113                 -74.0789
#
#         end station id         end station name  end station latitude  \
# 353895            3213           Van Vorst Park             40.718489
# 353896            3277  Communipaw & Berry Lane             40.714358
#
#         end station longitude  ...        date      dist  birthyear  \
# 353895             -74.047727  ...  2018-12-30  2.315132       1991
# 353896             -74.066611  ...  2018-12-31  0.902881       1991
#
#         years_old  age_group     holiday     day     month  seasons  \
# 353895         27      20-29  No Holiday  Sunday  December   winter
# 353896         27      20-29  No Holiday  Monday  December   winter
#
#         gender_cat
# 353895      female
# 353896        male
#
# [2 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['tripduration', 'starttime', 'start station id', 'start station name',
#        'start station latitude', 'start station longitude', 'end station id',
#        'end station name', 'end station latitude', 'end station longitude',
#        'bikeid', 'usertype', 'birth year', 'gender', 'hour', 'min', 'temp',
#        'feelslike', 'dew', 'humidity', 'precip', 'precipprob', 'snow',
#        'snowdepth', 'windspeed', 'winddir', 'sealevelpressure', 'cloudcover',
#        'visibility', 'solarradiation', 'uvindex', 'conditions', 'date', 'dist',
#        'birthyear', 'years_old', 'age_group', 'holiday', 'day', 'month',
#        'seasons', 'gender_cat'],
#       dtype='object')

# %%
df.drop(['gender','starttime'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['tripduration', 'start station id', 'start station name',
#        'start station latitude', 'start station longitude', 'end station id',
#        'end station name', 'end station latitude', 'end station longitude',
#        'bikeid', 'usertype', 'birth year', 'hour', 'min', 'temp', 'feelslike',
#        'dew', 'humidity', 'precip', 'precipprob', 'snow', 'snowdepth',
#        'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'uvindex', 'conditions', 'date', 'dist', 'birthyear',
#        'years_old', 'age_group', 'holiday', 'day', 'month', 'seasons',
#        'gender_cat'],
#       dtype='object')

# %%
df.rename(columns={"start station id": "start_station_id", "start station name": "start_station_name", "start station latitude": "start_lat",
                  "start station longitude":"start_lon","end station id":"end_station_id","end station name":"end_station_name","end station latitude":"end_station_name",
                  "end station longitude":"end_lon","end station latitude":"end_lat", "gender_cat": "gender"},inplace=True)

# %%
df.drop(['birth year'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['tripduration', 'start_station_id', 'start_station_name', 'start_lat',
#        'start_lon', 'end_station_id', 'end_station_name', 'end_lat', 'end_lon',
#        'bikeid', 'usertype', 'hour', 'min', 'temp', 'feelslike', 'dew',
#        'humidity', 'precip', 'precipprob', 'snow', 'snowdepth', 'windspeed',
#        'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'uvindex', 'conditions', 'date', 'dist', 'birthyear',
#        'years_old', 'age_group', 'holiday', 'day', 'month', 'seasons',
#        'gender'],
#       dtype='object')

# %% [markdown]
# ### convert start_station_id, end_station_id and bikeidas categorical values

# %%
def convert_to_categorical_end_station_id(x):
    val = "es_"+ str(x)
    return val
    
df['end_station_id'] = df['end_station_id'].apply(convert_to_categorical)

# %%
def convert_to_categorical_start_station_id(x):
    val = "ss_"+ str(x)
    return val
    
df['start_station_id'] = df['start_station_id'].apply(convert_to_categorical_start_station_id)

# %%
def convert_to_categorical_bikeid(x):
    val = "b_"+ str(x)
    return val
    
df['bikeid'] = df['bikeid'].apply(convert_to_categorical_bikeid)

# %%
df.columns
# Out:
# Index(['tripduration', 'start_station_id', 'start_station_name', 'start_lat',
#        'start_lon', 'end_station_id', 'end_station_name', 'end_lat', 'end_lon',
#        'bikeid', 'usertype', 'hour', 'min', 'temp', 'feelslike', 'dew',
#        'humidity', 'precip', 'precipprob', 'snow', 'snowdepth', 'windspeed',
#        'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'uvindex', 'conditions', 'date', 'dist', 'birthyear',
#        'years_old', 'age_group', 'holiday', 'day', 'month', 'seasons',
#        'gender'],
#       dtype='object')

# %%
df.head()
# Out:
#    tripduration start_station_id start_station_name  start_lat  start_lon  \
# 0         15.53          ss_3183     Exchange Place  40.716247 -74.033459
# 1          9.17          ss_3183     Exchange Place  40.716247 -74.033459
# 2          8.50          ss_3183     Exchange Place  40.716247 -74.033459
# 3          5.90          ss_3183     Exchange Place  40.716247 -74.033459
# 4          4.17          ss_3183     Exchange Place  40.716247 -74.033459
#
#   end_station_id end_station_name    end_lat    end_lon   bikeid  ...  \
# 0        es_3199     Newport Pkwy  40.728745 -74.032108  b_31929  ...
# 1        es_3199     Newport Pkwy  40.728745 -74.032108  b_31845  ...
# 2        es_3199     Newport Pkwy  40.728745 -74.032108  b_31708  ...
# 3        es_3267     Morris Canal  40.712419 -74.038526  b_31697  ...
# 4        es_3639       Harborside  40.719252 -74.034234  b_31861  ...
#
#          date      dist  birthyear  years_old  age_group         holiday  \
# 0  2018-01-01  1.084267       1992         26      20-29  New Year's Day
# 1  2018-01-01  1.084267       1969         49      40-49  New Year's Day
# 2  2018-01-01  1.084267       1946         72        65+  New Year's Day
# 3  2018-01-01  0.415696       1994         24      20-29  New Year's Day
# 4  2018-01-01  0.240932       1991         27      20-29  New Year's Day
#
#       day    month  seasons  gender
# 0  Monday  January   winter    male
# 1  Monday  January   winter  female
# 2  Monday  January   winter    male
# 3  Monday  January   winter    male
# 4  Monday  January   winter    male
#
# [5 rows x 39 columns]

# %%
df.to_csv("../../dataset/complete_bike_sharing.csv", index=False,)
