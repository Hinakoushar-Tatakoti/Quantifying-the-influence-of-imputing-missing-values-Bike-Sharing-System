# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2 variables at time 20%

# %%
dp1 = {('dist', 'birthyear'): {'rmse': 3.098769223159783, 'r2': 0.09199817104876917},
 ('start_lat', 'start_lon'): {'rmse': 2.2528651467200573,
  'r2': 0.5200691713809582},
 ('start_station_id', 'end_station_id'): {'rmse': 2.2512236729037522,
  'r2': 0.5207682872515258},
 ('end_lat', 'end_lon'): {'rmse': 2.252034918526058, 'r2': 0.5204228354133376},
 ('hour', 'temp'): {'rmse': 2.257686518948044, 'r2': 0.518012766721823},
 ('feelslike', 'dew'): {'rmse': 2.250324837151243, 'r2': 0.521150892152523},
 ('snowdepth', 'winddir'): {'rmse': 2.2506684343208447,
  'r2': 0.5210046521463156},
 ('sealevelpressure', 'visibility'): {'rmse': 2.2500748177575765,
  'r2': 0.5212572900475039},
 ('solarradiation', 'dist'): {'rmse': 3.101060893185836,
  'r2': 0.09065466344325668}
      }
d1 = pd.DataFrame(dp1)

# %% [markdown]
# ### 3 variable at a time

# %%
dp2 = {('dist', 'birthyear', 'start_lat'): {'rmse': 3.113225567402877,
  'r2': 0.08350640893056327},
 ('start_lat', 'start_lon', 'start_station_id'): {'rmse': 2.2527805863225643,
  'r2': 0.5201051987304516},
 ('start_station_id', 'end_station_id', 'end_lat'): {'rmse': 2.251751934637163,
  'r2': 0.5205433522697378},
 ('end_lat', 'end_lon', 'hour'): {'rmse': 2.262660131990683,
  'r2': 0.5158868218947277},
 ('hour', 'temp', 'feelslike'): {'rmse': 2.2582062724699905,
  'r2': 0.517790819701239},
 ('feelslike', 'dew', 'snowdepth'): {'rmse': 2.2507241274329552,
  'r2': 0.5209809462363187},
 ('snowdepth', 'winddir', 'sealevelpressure'): {'rmse': 2.2505919854258956,
  'r2': 0.521037191851013},
 ('sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.252220177164952, 'r2': 0.5203439294724248},
 ('solarradiation', 'dist', 'birthyear'): {'rmse': 3.099776081621531,
  'r2': 0.09140801554795697}}
d2 = pd.DataFrame(dp2)

# %%
dp3 = {('dist', 'birthyear', 'start_lat', 'start_lon'): {'rmse': 3.1376437361231817,
  'r2': 0.06907323769224438},
 ('start_lat',
  'start_lon',
  'start_station_id',
  'end_station_id'): {'rmse': 2.254135831289235, 'r2': 0.5195276274865513},
 ('start_station_id',
  'end_station_id',
  'end_lat',
  'end_lon'): {'rmse': 2.2530127510751363, 'r2': 0.5200062806205364},
 ('end_lat', 'end_lon', 'hour', 'temp'): {'rmse': 2.262366038688086,
  'r2': 0.5160126606706714},
 ('hour', 'temp', 'feelslike', 'dew'): {'rmse': 2.2624591439016624,
  'r2': 0.515972823905922},
 ('feelslike', 'dew', 'snowdepth', 'winddir'): {'rmse': 2.250776062162701,
  'r2': 0.5209588395624536},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.250512308168256, 'r2': 0.5210711044995813},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 3.098770593490556, 'r2': 0.09199736797952873},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 3.115456249009046, 'r2': 0.082192570419383}}
d3 = pd.DataFrame(dp3)

# %%
dp4 = {('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'start_station_id'): {'rmse': 3.137817333103265, 'r2': 0.06897022373730821},
 ('start_lat',
  'start_lon',
  'start_station_id',
  'end_station_id',
  'end_lat'): {'rmse': 2.2544639564364197, 'r2': 0.5193877365888017},
 ('start_station_id',
  'end_station_id',
  'end_lat',
  'end_lon',
  'hour'): {'rmse': 2.2642127740089077, 'r2': 0.5152221950294841},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike'): {'rmse': 2.2629704828846164, 'r2': 0.5157540089641319},
 ('hour', 'temp', 'feelslike', 'dew', 'snowdepth'): {'rmse': 2.261682819874818,
  'r2': 0.5163049381536707},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.2508391393135527, 'r2': 0.5209319892902714},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2529533524875105, 'r2': 0.5200315894636884},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 3.0997106638889336, 'r2': 0.09144636502787018},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 3.139192608668282, 'r2': 0.06815392185344582}}
d4 = pd.DataFrame(dp4)

# %%
dp5 = {('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'start_station_id',
  'end_station_id'): {'rmse': 3.1384332500247005, 'r2': 0.06860468730725211},
 ('start_lat',
  'start_lon',
  'start_station_id',
  'end_station_id',
  'end_lat',
  'end_lon'): {'rmse': 2.25414543011149, 'r2': 0.5195235354716357},
 ('start_station_id',
  'end_station_id',
  'end_lat',
  'end_lon',
  'hour',
  'temp'): {'rmse': 2.263530420388447, 'r2': 0.5155143407588543},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew'): {'rmse': 2.267158881263063, 'r2': 0.5139598255306719},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir'): {'rmse': 2.2620083927574357, 'r2': 0.516165670764968},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.2507627125188545, 'r2': 0.5209645220557252},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 3.0995558814974826, 'r2': 0.09153709904051599},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 3.1148664182838464, 'r2': 0.08254006352032295},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'start_station_id'): {'rmse': 3.1397912269808264, 'r2': 0.06779849714253461}}
d5 = pd.DataFrame(dp5)

# %%
dp6 = {('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'start_station_id',
  'end_station_id',
  'end_lat'): {'rmse': 3.1386694303506837, 'r2': 0.06846449918907149},
 ('start_lat',
  'start_lon',
  'start_station_id',
  'end_station_id',
  'end_lat',
  'end_lon',
  'hour'): {'rmse': 2.2650842429085243, 'r2': 0.5148489526498436},
 ('start_station_id',
  'end_station_id',
  'end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike'): {'rmse': 2.263993549463119, 'r2': 0.5153160643428804},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth'): {'rmse': 2.266290083702662, 'r2': 0.5143322648971577},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.26179058557378, 'r2': 0.5162588424077756},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2538005395275835, 'r2': 0.5196705527217249},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 3.100283900426716, 'r2': 0.09111029217821665},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 3.138814558018636, 'r2': 0.0683783514099684},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'start_station_id',
  'end_station_id'): {'rmse': 3.1408085795649527, 'r2': 0.06719429693586088}}
d6 = pd.DataFrame(dp6)

# %%
count = 2
for df in [d1,d2,d3, d4,d5,d6]:
    data = df.T
    data['features'] = data.index
    rmse = data['rmse'].values
    r2 = data['r2'].values
    var = data['features'].values
    features = []
    for i in var:
        j = str(i)
        features.append(j)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
    fig.suptitle(f'RMSE and R2 plot for {count} variable')
    ax1.scatter(rmse, features, color = "red", label='RMSE')
    ax1.set_title('RMSE')
    ax1.legend()
    ax2.scatter(r2, features, color = "black" , label='R2')
    ax2.set_title('R2')
    ax2.legend()
    count = count+1
