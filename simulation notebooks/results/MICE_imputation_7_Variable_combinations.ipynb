# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
dp1 = {'method': 'multi_reg',"col": 2, 'percent': '1%',('dist', 'birthyear'): {'rmse': 2.8728345362278267,
  'r2': 0.21957803947552057},
 ('start_lat', 'start_lon'): {'rmse': 2.237934336107128,
  'r2': 0.52640955165571},
 ('end_lat', 'end_lon'): {'rmse': 2.237639728672211, 'r2': 0.5265342327791334},
 ('hour', 'temp'): {'rmse': 2.2400652783313553, 'r2': 0.5255072245945135},
 ('feelslike', 'dew'): {'rmse': 2.2361214870766584, 'r2': 0.5271765091449416},
 ('snowdepth', 'winddir'): {'rmse': 2.236083884463664,
  'r2': 0.5271924110083737},
 ('sealevelpressure', 'visibility'): {'rmse': 2.235965497169731,
  'r2': 0.5272424743621189},
 ('solarradiation', 'dist'): {'rmse': 2.879925773245274,
  'r2': 0.21572053413210102}}

# %%
dp2 = {'method': 'multi_reg',"col": 3, 'percent': '1%',('dist', 'birthyear', 'start_lat'): {'rmse': 2.871918501085032,
  'r2': 0.22007565251734806},
 ('start_lat', 'start_lon', 'end_lat'): {'rmse': 2.2379551660815666,
  'r2': 0.5264007355589337},
 ('end_lat', 'end_lon', 'hour'): {'rmse': 2.24230021720317,
  'r2': 0.5245599384808917},
 ('hour', 'temp', 'feelslike'): {'rmse': 2.24095831947017,
  'r2': 0.5251288195198087},
 ('feelslike', 'dew', 'snowdepth'): {'rmse': 2.2361236220856413,
  'r2': 0.5271756062576092},
 ('snowdepth', 'winddir', 'sealevelpressure'): {'rmse': 2.2362103270347684,
  'r2': 0.527138938329765},
 ('sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.236770638140198, 'r2': 0.526901945866047},
 ('solarradiation', 'dist', 'birthyear'): {'rmse': 2.8681492392778574,
  'r2': 0.22212153920789957}}

# %%
dp3 = {'method': 'multi_reg',"col": 4, 'percent': '1%',('dist', 'birthyear', 'start_lat', 'start_lon'): {'rmse': 2.858656749344346,
  'r2': 0.22726198603494752},
 ('start_lat', 'start_lon', 'end_lat', 'end_lon'): {'rmse': 2.2387774442725217,
  'r2': 0.5260526482555672},
 ('end_lat', 'end_lon', 'hour', 'temp'): {'rmse': 2.2425408743659236,
  'r2': 0.5244578788232203},
 ('hour', 'temp', 'feelslike', 'dew'): {'rmse': 2.2420122052168514,
  'r2': 0.5246820663220324},
 ('feelslike', 'dew', 'snowdepth', 'winddir'): {'rmse': 2.236229462142929,
  'r2': 0.5271308458116657},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.2362442703611176, 'r2': 0.5271245831513144},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 2.883954473186113, 'r2': 0.2135247576628001},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 2.860446549456913, 'r2': 0.22629406321857592}}

# %%
dp4 = {'method': 'multi_reg',"col": 5, 'percent': '1%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse': 2.8254982199443606, 'r2': 0.24508451898508277},
 ('start_lat',
  'start_lon',
  'end_lat',
  'end_lon',
  'hour'): {'rmse': 2.2420682108127896, 'r2': 0.5246583190858984},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike'): {'rmse': 2.2435580727162483, 'r2': 0.5240263768848739},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth'): {'rmse': 2.2410026762981254, 'r2': 0.5251100204305661},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.236321526922017, 'r2': 0.5270919092972276},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.236987550920448, 'r2': 0.526810183225404},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 2.8653767373336874, 'r2': 0.22362468774772104},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 2.858957058027856, 'r2': 0.22709962157831998}}

# %%
dp5 = {'method': 'multi_reg',"col": 6, 'percent': '1%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lon'): {'rmse': 2.752411691378843, 'r2': 0.28363387129343054},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew'): {'rmse': 2.2448394183115483, 'r2': 0.5234825435223556},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir'): {'rmse': 2.2415073445440856, 'r2': 0.5248961082552881},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.236394681893628, 'r2': 0.5270609690738456},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 2.864364925303264, 'r2': 0.22417289292869436},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 2.8752119652498918, 'r2': 0.2182858205767204},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse': 2.8368018589505852, 'r2': 0.23903223334771195}}

# %%
dp6 = {'method': 'multi_reg',"col": 7,'percent': '1%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lat',
  'end_lon'): {'rmse': 2.7555484953920373, 'r2': 0.2820001181629037},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth'): {'rmse': 2.2449417288047115, 'r2': 0.5234391071441902},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.241939308859636, 'r2': 0.524712974612825},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.237358057216768, 'r2': 0.5266534239039014},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 2.8672796145955775, 'r2': 0.222593174189897},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 2.8601096438803566, 'r2': 0.22647630783632966},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lat'): {'rmse': 2.845437541029881, 'r2': 0.2343921644615211}}

# %%
dp7 = {'method': 'multi_reg',"col": 1,'percent': '1%',('start_lat','start_lon','end_lat',
                     'end_lon','hour','temp', 'feelslike', 'dew','snowdepth',
                     'winddir','sealevelpressure','visibility','solarradiation','dist','birthyear'):
       {'rmse': 2.757731871676201, 'r2': 0.2808618438840308}
      }

# %%
d2 = pd.DataFrame(dp1)
d3 = pd.DataFrame(dp2)
d4 = pd.DataFrame(dp3)
d5 = pd.DataFrame(dp4)
d6 = pd.DataFrame(dp5)
d7 = pd.DataFrame(dp6)
d1 = pd.DataFrame(dp7)

# %%
dp11 = {'method': 'multi_reg',"col": 2, 'percent': '5%',('dist', 'birthyear'): {'rmse': 3.054976052081298, 'r2': 0.11748138289105103},
 ('start_lat', 'start_lon'): {'rmse': 2.23846244303506,
  'r2': 0.5261860098808282},
 ('end_lat', 'end_lon'): {'rmse': 2.2386243442891107,
  'r2': 0.5261174683213605},
 ('hour', 'temp'): {'rmse': 2.241471057860043, 'r2': 0.5249114905874535},
 ('feelslike', 'dew'): {'rmse': 2.2361006393607465, 'r2': 0.5271853255209036},
 ('snowdepth', 'winddir'): {'rmse': 2.2362378861591186,
  'r2': 0.5271272831496217},
 ('sealevelpressure', 'visibility'): {'rmse': 2.235943415215413,
  'r2': 0.5272518120362011},
 ('solarradiation', 'dist'): {'rmse': 3.0553909183322245,
  'r2': 0.11724167426887044}}

# %%
dp21 = {'method': 'multi_reg',"col": 3, 'percent': '5%',('dist', 'birthyear', 'start_lat'): {'rmse': 3.0676455402971845,
  'r2': 0.11014630472699471},
 ('start_lat', 'start_lon', 'end_lat'): {'rmse': 2.239232322553954,
  'r2': 0.5258600339703094},
 ('end_lat', 'end_lon', 'hour'): {'rmse': 2.245603567053232,
  'r2': 0.523158072927989},
 ('hour', 'temp', 'feelslike'): {'rmse': 2.2437890999769063,
  'r2': 0.5239283463990414},
 ('feelslike', 'dew', 'snowdepth'): {'rmse': 2.236406396548184,
  'r2': 0.527056014374276},
 ('snowdepth', 'winddir', 'sealevelpressure'): {'rmse': 2.236342616978617,
  'r2': 0.5270829895553133},
 ('sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.237328352979867, 'r2': 0.5266659925720687},
 ('solarradiation', 'dist', 'birthyear'): {'rmse': 3.05436861408761,
  'r2': 0.11783230023613012}}

# %%
dp31 = {'method': 'multi_reg',"col": 4, 'percent': '5%',('dist', 'birthyear', 'start_lat', 'start_lon'): {'rmse': 3.079584743473147,
  'r2': 0.10320624702972125},
 ('start_lat', 'start_lon', 'end_lat', 'end_lon'): {'rmse': 2.2397990411964517,
  'r2': 0.5256200071023354},
 ('end_lat', 'end_lon', 'hour', 'temp'): {'rmse': 2.2461494986432013,
  'r2': 0.5229261934288916},
 ('hour', 'temp', 'feelslike', 'dew'): {'rmse': 2.244279965314503,
  'r2': 0.5237200267896891},
 ('feelslike', 'dew', 'snowdepth', 'winddir'): {'rmse': 2.236440002225727,
  'r2': 0.5270418007478839},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.2363015476985484, 'r2': 0.5271003591503503},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 3.0525646451792308, 'r2': 0.11887404296381332},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 3.0656494381495083, 'r2': 0.11130397496881095}}

# %%
dp41 = {'method': 'multi_reg',"col": 5, 'percent': '5%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse': 3.068401840550476, 'r2': 0.10970747988436269},
 ('start_lat',
  'start_lon',
  'end_lat',
  'end_lon',
  'hour'): {'rmse': 2.2455944091879374, 'r2': 0.5231619621676524},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike'): {'rmse': 2.249005217803238, 'r2': 0.5217123340033657},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth'): {'rmse': 2.244070324019518, 'r2': 0.5238090025756292},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.2364786712321494, 'r2': 0.527025445306435},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.237654259913374, 'r2': 0.5265280833820725},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 3.0541433355135297, 'r2': 0.1179624260838581},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 3.082456754080198, 'r2': 0.10153277324406162}}

# %%
dp51 = {'method': 'multi_reg',"col": 6, 'percent': '5%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lon'): {'rmse': 2.9805951064830047, 'r2': 0.15993242199345126},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew'): {'rmse': 2.249158996925762, 'r2': 0.5216469244866804},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir'): {'rmse': 2.2444509647468984, 'r2': 0.5236474451964177},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.2363554546073456, 'r2': 0.5270775600201616},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 3.053860334999093, 'r2': 0.1181258797890995},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 3.0695919930971423, 'r2': 0.10901670373602179},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse': 3.0684759678671254, 'r2': 0.10966446348941761}}

# %%
dp61 = {'method': 'multi_reg',"col": 7, 'percent': '5%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lat',
  'end_lon'): {'rmse': 2.976810370580599, 'r2': 0.16206448971784226},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth'): {'rmse': 2.249909520721311, 'r2': 0.5213276271258355},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.2444056700286916, 'r2': 0.5236666713121702},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2379909336324855, 'r2': 0.5263855970776736},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 3.0568151318608274, 'r2': 0.11641851978405882},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 3.082098433884245, 'r2': 0.10174164575487599},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lat'): {'rmse': 3.070262750475538, 'r2': 0.1086272715783736}}

# %%
dp71 = {'method': 'multi_reg',"col": 1, 'percent': '5%',('start_lat','start_lon','end_lat',
                     'end_lon','hour','temp', 'feelslike', 'dew','snowdepth',
                     'winddir','sealevelpressure','visibility','solarradiation','dist','birthyear'):
       {'rmse': 2.9820866047956875, 'r2': 0.15909146720248546}
      }

# %%
d21 = pd.DataFrame(dp11)
d31 = pd.DataFrame(dp21)
d41 = pd.DataFrame(dp31)
d51 = pd.DataFrame(dp41)
d61 = pd.DataFrame(dp51)
d71 = pd.DataFrame(dp61)
d11 = pd.DataFrame(dp71)

# %%
dp12 = {'method': 'multi_reg',"col": 2, 'percent': '10%',('dist', 'birthyear'): {'rmse': 3.0830516978832354,
  'r2': 0.10118591413985945},
 ('start_lat', 'start_lon'): {'rmse': 2.2384371056673764,
  'r2': 0.5261967361106782},
 ('end_lat', 'end_lon'): {'rmse': 2.238904671115169, 'r2': 0.5259987790881337},
 ('hour', 'temp'): {'rmse': 2.241703727814988, 'r2': 0.5248128548644653},
 ('feelslike', 'dew'): {'rmse': 2.2361084491082757, 'r2': 0.5271820228344153},
 ('snowdepth', 'winddir'): {'rmse': 2.2362877305062345,
  'r2': 0.5271062028390993},
 ('sealevelpressure', 'visibility'): {'rmse': 2.2359443483613655,
  'r2': 0.5272514174437914},
 ('solarradiation', 'dist'): {'rmse': 3.0824122931866986,
  'r2': 0.10155869176994936}}

# %%
dp22 = {'method': 'multi_reg',"col": 3, 'percent': '10%',('dist', 'birthyear', 'start_lat'): {'rmse': 3.099527130226214,
  'r2': 0.09155395264352251},
 ('start_lat', 'start_lon', 'end_lat'): {'rmse': 2.239250602773203,
  'r2': 0.5258522925512303},
 ('end_lat', 'end_lon', 'hour'): {'rmse': 2.2460192195997104,
  'r2': 0.522981533393369},
 ('hour', 'temp', 'feelslike'): {'rmse': 2.2440655963175455,
  'r2': 0.5238110090071766},
 ('feelslike', 'dew', 'snowdepth'): {'rmse': 2.236401179899966,
  'r2': 0.5270582207528002},
 ('snowdepth', 'winddir', 'sealevelpressure'): {'rmse': 2.236407126881743,
  'r2': 0.5270557054796841},
 ('sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2373095199407946, 'r2': 0.5266739612551863},
 ('solarradiation', 'dist', 'birthyear'): {'rmse': 3.0840296245716394,
  'r2': 0.10061562614505648}}

# %%
dp32 = {'method': 'multi_reg',"col": 4, 'percent': '10%',('dist', 'birthyear', 'start_lat', 'start_lon'): {'rmse': 3.117604407108891,
  'r2': 0.08092644755968459},
 ('start_lat', 'start_lon', 'end_lat', 'end_lon'): {'rmse': 2.2399308065722843,
  'r2': 0.5255641907585354},
 ('end_lat', 'end_lon', 'hour', 'temp'): {'rmse': 2.246730742399366,
  'r2': 0.5226792534545897},
 ('hour', 'temp', 'feelslike', 'dew'): {'rmse': 2.244602441543207,
  'r2': 0.5235831454679358},
 ('feelslike', 'dew', 'snowdepth', 'winddir'): {'rmse': 2.236475376641569,
  'r2': 0.5270268387973591},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.2362735879977413, 'r2': 0.5271121840760429},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 3.0843162213422732, 'r2': 0.1004484600245934},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 3.097348492572279, 'r2': 0.0928305855669439}}

# %%
dp42 = {'method': 'multi_reg',"col": 5, 'percent': '10%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse':  3.1117132396635636, 'r2': 0.08439661235403806},
 ('start_lat',
  'start_lon',
  'end_lat',
  'end_lon',
  'hour'): {'rmse': 2.2463066768704496, 'r2': 0.5228594229500314},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike'): {'rmse': 2.250012198661049, 'r2': 0.5212839362892936},
 ('hour', 'temp', 'feelslike', 'dew', 'snowdepth'): {'rmse': 2.2449007343255274,'r2': 0.5234565117716481},
('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.2365370897757493, 'r2': 0.5270007360651933},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2376937687366327, 'r2': 0.5265113636557508},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 3.0844950322888436, 'r2': 0.10034415533377816},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 3.1170416769216525, 'r2': 0.08125820469629863}}

# %%
dp52 = {'method': 'multi_reg',"col": 6, 'percent': '10%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lon'): {'rmse': 3.0509802318593597, 'r2': 0.11978849068579767},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew'): {'rmse': 2.2507673335528726, 'r2': 0.5209625550411665},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir'): {'rmse': 2.245144999022262, 'r2': 0.5233528019891457},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.236578277425693, 'r2': 0.5269833145723135},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 3.0839945409952536, 'r2': 0.10063608862093776},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 3.1003081435294484, 'r2': 0.09109607774275397},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse': 3.1130625091997195, 'r2': 0.08360241089466758}}

# %%
dp62 = {'method': 'multi_reg',"col": 7, 'percent': '10%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lat',
  'end_lon'): {'rmse': 3.0487864581426574, 'r2': 0.1210538483747251},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth'): {'rmse': 2.250768083511871, 'r2': 0.5209622358091456},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.2451251346715497, 'r2': 0.5233612364067226},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.237951122943272, 'r2': 0.5264024467867741},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 3.0852027376729154, 'r2': 0.09993127457402895},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 3.1199323610137046, 'r2': 0.07955336784587574},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lat'): {'rmse': 3.1127746717314886, 'r2': 0.08377186548592808}}

# %%
dp72 = {'method': 'multi_reg',"col": 1, 'percent': '10%',('start_lat','start_lon','end_lat',
                     'end_lon','hour','temp', 'feelslike', 'dew','snowdepth',
                     'winddir','sealevelpressure','visibility','solarradiation','dist','birthyear'):
       {'rmse': 3.0560953587680664, 'r2': 0.11683457588950075}
      }

# %%
d22 = pd.DataFrame(dp12)
d32 = pd.DataFrame(dp22)
d42 = pd.DataFrame(dp32)
d52 = pd.DataFrame(dp42)
d62 = pd.DataFrame(dp52)
d72 = pd.DataFrame(dp62)
d12 = pd.DataFrame(dp72)

# %%
dp13 = {'method': 'multi_reg',"col": 2, 'percent': '20%',('dist', 'birthyear'): {'rmse': 3.096983115701843, 'r2': 0.09304460034263395},
 ('start_lat', 'start_lon'): {'rmse': 2.238624202573561,
  'r2': 0.5261175283193869},
 ('end_lat', 'end_lon'): {'rmse': 2.2388995514852534,
  'r2': 0.5260009468517615},
 ('hour', 'temp'): {'rmse': 2.241816070535067, 'r2': 0.5247652257746525},
 ('feelslike', 'dew'): {'rmse': 2.236158064234106, 'r2': 0.5271610406824124},
 ('snowdepth', 'winddir'): {'rmse': 2.236302716020267,
  'r2': 0.5270998650317766},
 ('sealevelpressure', 'visibility'): {'rmse': 2.23599012781975,
  'r2': 0.5272320588263626},
 ('solarradiation', 'dist'): {'rmse': 3.099188137962204,
  'r2': 0.09175265349623496}}

# %%
dp23 = {'method': 'multi_reg',"col": 3, 'percent': '20%',('dist', 'birthyear', 'start_lat'): {'rmse': 3.1149938407421627,
  'r2': 0.08246499937568252},
 ('start_lat', 'start_lon', 'end_lat'): {'rmse': 2.2393280473829966,
  'r2': 0.5258194951330875},
 ('end_lat', 'end_lon', 'hour'): {'rmse': 2.2464847661738,
  'r2': 0.5227837636447044},
 ('hour', 'temp', 'feelslike'): {'rmse': 2.244297604830626,
  'r2': 0.5237125398616653},
 ('feelslike', 'dew', 'snowdepth'): {'rmse': 2.2364505751986923,
  'r2': 0.5270373288317406},
 ('snowdepth', 'winddir', 'sealevelpressure'): {'rmse': 2.236376552955188,
  'r2': 0.5270686366361912},
 ('sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2373793987758828, 'r2': 0.5266443936084751},
 ('solarradiation', 'dist', 'birthyear'): {'rmse': 3.099022432871225,
  'r2': 0.09184977388973203}}

# %%
dp33 = {'method': 'multi_reg',"col": 4, 'percent': '20%',('dist', 'birthyear', 'start_lat', 'start_lon'): {'rmse': 3.1377533936227695,
  'r2': 0.06900816664308129},
 ('start_lat', 'start_lon', 'end_lat', 'end_lon'): {'rmse': 2.2402332775783376,
  'r2': 0.525436050402468},
 ('end_lat', 'end_lon', 'hour', 'temp'): {'rmse': 2.2470386527500525,
  'r2': 0.5225484126138897},
 ('hour', 'temp', 'feelslike', 'dew'): {'rmse': 2.2450401147561734,
  'r2': 0.523397335080626},
 ('feelslike', 'dew', 'snowdepth', 'winddir'): {'rmse': 2.2365159329857196,
  'r2': 0.5270096848090573},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.2363076425573363, 'r2': 0.5270977814474797},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 3.1002631509276117, 'r2': 0.09112245812409414},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 3.1163109859482407, 'r2': 0.08168889361351528}}

# %%
dp43 = {'method': 'multi_reg',"col": 5, 'percent': '20%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse':3.135852289754209, 'r2': 0.0701359646414037},
 ('start_lat',
  'start_lon',
  'end_lat',
  'end_lon',
  'hour'): {'rmse': 2.2472971487271343, 'r2': 0.522438555657556},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike'): {'rmse': 2.250655456027134, 'r2': 0.5210101763046431},
 ('hour', 'temp', 'feelslike', 'dew', 'snowdepth'): {'rmse': 2.2451240774526906,
  'r2': 0.5233616853005177},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.2365499399021296, 'r2': 0.526995300771669},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2377574042382107, 'r2': 0.5264844331474621},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 3.101096935392109, 'r2': 0.09063352551415038},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 3.1396471744544163, 'r2': 0.06788403333994708}}

# %%
dp53 = {'method': 'multi_reg',"col": 6, 'percent': '20%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lon'): {'rmse': 3.105471984800699, 'r2': 0.08806583427220627},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew'): {'rmse': 2.2515234375457576, 'r2': 0.5206406532994327},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir'): {'rmse': 2.245298074327244, 'r2': 0.5232878036014572},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.236520393322277, 'r2': 0.5270077982156585},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 3.101444262864672, 'r2': 0.09042981330939315},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 3.1166038496359816, 'r2': 0.08151628400202249},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse': 3.1378650452881294, 'r2': 0.06894190991415694}}

# %%
dp63 = {'method': 'multi_reg',"col": 7, 'percent': '20%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lat',
  'end_lon'): {'rmse': 3.106222611791403, 'r2': 0.08762493180699926},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth'): {'rmse': 2.2515473398313213, 'r2': 0.520630475439749},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.2453475444830606, 'r2': 0.5232667967812894},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2381030588305126, 'r2': 0.5263381389417195},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 3.1014923834843917, 'r2': 0.09040158812338117},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 3.138370167665142, 'r2': 0.06864212893423183},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lat'): {'rmse': 3.1385002259401173, 'r2': 0.06856493389251561}}

# %%
dp73 = {'method': 'multi_reg',"col": 1, 'percent': '20%',('start_lat','start_lon','end_lat',
                     'end_lon','hour','temp', 'feelslike', 'dew','snowdepth',
                     'winddir','sealevelpressure','visibility','solarradiation','dist','birthyear'):
       {'rmse': 3.113171337718016, 'r2': 0.08353833769683394}
      }

# %%
d23 = pd.DataFrame(dp13)
d33 = pd.DataFrame(dp23)
d43 = pd.DataFrame(dp33)
d53 = pd.DataFrame(dp43)
d63 = pd.DataFrame(dp53)
d73 = pd.DataFrame(dp63)
d13 = pd.DataFrame(dp73)

# %%
dp14 = {'method': 'multi_reg',"col": 2, 'percent': '30%',('dist', 'birthyear'): {'rmse': 3.1024979251248874,
  'r2': 0.08981168672448547},
 ('start_lat', 'start_lon'): {'rmse': 2.238659439217259,
  'r2': 0.5261026100859414},
 ('end_lat', 'end_lon'): {'rmse': 2.2388820308009376,
  'r2': 0.5260083654563843},
 ('hour', 'temp'): {'rmse': 2.2418961498022365, 'r2': 0.5247312737188569},
 ('feelslike', 'dew'): {'rmse': 2.236134752033177, 'r2': 0.5271708994303654},
 ('snowdepth', 'winddir'): {'rmse': 2.2363081651187424,
  'r2': 0.5270975604398933},
 ('sealevelpressure', 'visibility'): {'rmse': 2.2359733441197664,
  'r2': 0.5272391561434822},
 ('solarradiation', 'dist'): {'rmse': 3.1049432711024396,
  'r2': 0.0883763255881439}}

# %%
dp24 = {'method': 'multi_reg',"col": 3, 'percent': '30%',('dist', 'birthyear', 'start_lat'): {'rmse': 3.1193234571704345,
  'r2': 0.07991261204438238},
 ('start_lat', 'start_lon', 'end_lat'): {'rmse': 2.239387292154596,
  'r2': 0.5257944044927432},
 ('end_lat', 'end_lon', 'hour'): {'rmse': 2.2463454419231126,
  'r2': 0.5228429545493578},
 ('hour', 'temp', 'feelslike'): {'rmse': 2.2443819440718378,
  'r2': 0.5236767420444095},
 ('feelslike', 'dew', 'snowdepth'): {'rmse': 2.236423099535157,
  'r2': 0.5270489498204072},
 ('snowdepth', 'winddir', 'sealevelpressure'): {'rmse': 2.23636632030017,
  'r2': 0.5270729644694541},
 ('sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2373429834051297, 'r2': 0.5266598020632387},
 ('solarradiation', 'dist', 'birthyear'): {'rmse': 3.105519645555142,
  'r2': 0.08803784251824553}}

# %%
dp34 = {'method': 'multi_reg',"col": 4, 'percent': '30%',('dist', 'birthyear', 'start_lat', 'start_lon'): {'rmse': 3.1427257900856023,
  'r2': 0.06605514394722867},
 ('start_lat', 'start_lon', 'end_lat', 'end_lon'): {'rmse': 2.2404121399613137,
  'r2': 0.525360268091523},
 ('end_lat', 'end_lon', 'hour', 'temp'): {'rmse': 2.2471885536093072,
  'r2': 0.5224847085112838},
 ('hour', 'temp', 'feelslike', 'dew'): {'rmse': 2.2451624930616707,
  'r2': 0.5233453739456508},
 ('feelslike', 'dew', 'snowdepth', 'winddir'): {'rmse': 2.2365238613383864,
  'r2': 0.5270063313425173},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.2363479197668665, 'r2': 0.5270807468025972},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 3.1043750942649466, 'r2': 0.0887099330133051},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 3.1213601803443263, 'r2': 0.07871070071891362}}

# %%
dp44 = {'method': 'multi_reg',"col": 5, 'percent': '30%',('dist',
  'birthyear',
  'start_lat', 
  'start_lon',
  'end_lat'): {'rmse': 3.143298351526474, 'r2':0.06571480911726924},
 ('start_lat',
  'start_lon',
  'end_lat',
  'end_lon', 
  'hour'): {'rmse': 2.2479764349781615, 'r2': 0.5221498088388521},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike'): {'rmse': 2.2510997805974866, 'r2': 0.5208210332217222},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth'): {'rmse': 2.245439811301031, 'r2': 0.5232276157114819},
('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.236620541547537, 'r2': 0.5269654374213837},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2378689431816867, 'r2': 0.5264372280820568},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 3.1051577912356545, 'r2': 0.0882503533106076},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 3.1441643559161903, 'r2': 0.06519993178638384}}

# %%
dp54 = {'method': 'multi_reg',"col": 6, 'percent': '30%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lon'): {'rmse': 3.1334594566465443, 'r2': 0.07155450119206519},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew'): {'rmse': 2.2515699280659627, 'r2': 0.5206208570182975},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir'): {'rmse': 2.2454535055850617, 'r2': 0.5232218003016675},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.236529376844049, 'r2': 0.5270039984342755},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 3.1042751702304954, 'r2': 0.08876859751856736},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 3.121058259408548, 'r2': 0.07888891986609148},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse': 3.1463922172852814, 'r2': 0.0638747193865612}}

# %%
dp64 = {'method': 'multi_reg',"col": 7, 'percent': '30%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lat',
  'end_lon'): {'rmse': 3.1320271012903405, 'r2': 0.0724031223089715},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth'): {'rmse': 2.251972860325396, 'r2': 0.5204492659856204},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.24551175967209, 'r2': 0.5231970617453401},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2381668397026675, 'r2': 0.5263111419748445},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 3.1051697340974385, 'r2': 0.08824333986930488},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 3.144418125536409, 'r2': 0.06504902782287525},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lat'): {'rmse': 3.1456525383561296, 'r2': 0.06431481121623328}}

# %%
dp74 = {'method': 'multi_reg',"col": 1, 'percent': '30%',('start_lat','start_lon','end_lat',
                     'end_lon','hour','temp', 'feelslike', 'dew','snowdepth',
                     'winddir','sealevelpressure','visibility','solarradiation','dist','birthyear'):
       {'rmse': 3.1391584332611084, 'r2': 0.0681742111760607}
      }

# %%
d24 = pd.DataFrame(dp14)
d34 = pd.DataFrame(dp24)
d44 = pd.DataFrame(dp34)
d54 = pd.DataFrame(dp44)
d64 = pd.DataFrame(dp54)
d74 = pd.DataFrame(dp64)
d14 = pd.DataFrame(dp74)

# %%
dp15 = {'method': 'multi_reg',"col": 2, 'percent': '40%',('dist', 'birthyear'): {'rmse': 3.104780141742423, 'r2': 0.08847211392759047},
 ('start_lat', 'start_lon'): {'rmse': 2.238689016167072,
  'r2': 0.5260900878311809},
 ('end_lat', 'end_lon'): {'rmse': 2.2389429349585415, 'r2': 0.525982577180393},
 ('hour', 'temp'): {'rmse': 2.241956432137498, 'r2': 0.5247057143780387},
 ('feelslike', 'dew'): {'rmse': 2.2361590730388405, 'r2': 0.5271606140557835},
 ('snowdepth', 'winddir'): {'rmse': 2.2363388498783827,
  'r2': 0.5270845828033845},
 ('sealevelpressure', 'visibility'): {'rmse': 2.2360037178133485,
  'r2': 0.5272263119916705},
 ('solarradiation', 'dist'): {'rmse': 3.106421531315147,
  'r2': 0.08750807281270201}}

# %%
dp25 = {'method': 'multi_reg',"col": 3, 'percent': '40%',('dist', 'birthyear', 'start_lat'): {'rmse': 3.1214951194137353,
  'r2': 0.07863104274885979},
 ('start_lat', 'start_lon', 'end_lat'): {'rmse': 2.239411645991521,
  'r2': 0.5257840902531474},
 ('end_lat', 'end_lon', 'hour'): {'rmse': 2.246449453390866,
  'r2': 0.5227987663735656},
 ('hour', 'temp', 'feelslike'): {'rmse': 2.2444440529695178,
  'r2': 0.52365037904331},
 ('feelslike', 'dew', 'snowdepth'): {'rmse': 2.2364377702455385,
  'r2': 0.527042744777505},
 ('snowdepth', 'winddir', 'sealevelpressure'): {'rmse': 2.2363683010163635,
  'r2': 0.5270721267402824},
 ('sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.23736944773578, 'r2': 0.5266486042221508},
 ('solarradiation', 'dist', 'birthyear'): {'rmse': 3.107134363167712,
  'r2': 0.08708924495289794}}

# %%
dp35 = {'method': 'multi_reg',"col": 4, 'percent': '40%',('dist', 'birthyear', 'start_lat', 'start_lon'): {'rmse': 3.1457468198241103,
  'r2': 0.06425872168051905},
 ('start_lat', 'start_lon', 'end_lat', 'end_lon'): {'rmse': 2.240507698286032,
  'r2': 0.5253197784476069},
 ('end_lat', 'end_lon', 'hour', 'temp'): {'rmse': 2.247225816951828,
  'r2': 0.5224688718665418},
 ('hour', 'temp', 'feelslike', 'dew'): {'rmse': 2.245151824764825,
  'r2': 0.5233499037567249},
 ('feelslike', 'dew', 'snowdepth', 'winddir'): {'rmse': 2.236503770911068,
  'r2': 0.5270148289958678},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.2363268435417383, 'r2': 0.5270896607158498},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 3.1067226429001193, 'r2': 0.08733116494343396},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 3.123340244557492, 'r2': 0.07754147290215097}}

# %%
dp45 = {'method': 'multi_reg',"col": 5, 'percent': '40%',('dist',
  'birthyear',
  'start_lat',
  'start_lon', 
  'end_lat'): {'rmse':  3.147655985967893, 'r2': 0.06312256687669826},
 ('start_lat',
  'start_lon',
  'end_lat',
  'end_lon', 
  'hour'): {'rmse': 2.2480816202577127, 'r2': 0.5221050895249977},
 ('end_lat',
  'end_lon',
  'hour', 
  'temp',
  'feelslike'): {'rmse': 2.250992579892193, 'r2': 0.5208666705591032}, 
 ('hour', 'temp', 'feelslike', 'dew', 'snowdepth'): {'rmse': 2.245282595893913,
  'r2': 0.5232943762098792},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.2365234701825076, 'r2': 0.5270064967905513},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2377650851061714, 'r2': 0.5264811825566864},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 3.1071258510875905, 'r2': 0.08709424683433498},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 3.146924302510196, 'r2': 0.06355807701478866}}

# %%
dp55 = {'method': 'multi_reg',"col": 6, 'percent': '40%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lon'): {'rmse': 3.15007472453001, 'r2': 0.06168217298668899},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew'): {'rmse': 2.2517308344519336, 'r2': 0.520552337785879},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir'): {'rmse': 2.2454157901732783, 'r2': 0.5232378164294309},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.236526745693729, 'r2': 0.5270051113397098},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist'): {'rmse': 3.1070574464221754, 'r2': 0.08713444239009649},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat'): {'rmse': 3.1230120047430487, 'r2': 0.07773534976582674},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse': 3.1492405771975407, 'r2': 0.06217904480786862}}

# %%
dp65 = {'method': 'multi_reg',"col": 7, 'percent': '40%',('dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lat',
  'end_lon'): {'rmse': 3.1489876409096627, 'r2': 0.06232968393459026},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth'): {'rmse': 2.251880483164914, 'r2': 0.5204886080463531},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.2454494642681455, 'r2': 0.5232235164895692},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2381236778722884, 'r2': 0.5263294114627501},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear'): {'rmse': 3.10738721754858, 'r2': 0.08694065602867918},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 3.145978860778087, 'r2': 0.06412066968875552},
 ('solarradiation',
  'dist',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'end_lat'): {'rmse': 3.1493794916871463, 'r2': 0.062096307532372164}}

# %%
dp75 = {'method': 'multi_reg',"col": 1, 'percent': '40%',('start_lat','start_lon','end_lat',
                     'end_lon','hour','temp', 'feelslike', 'dew','snowdepth',
                     'winddir','sealevelpressure','visibility','solarradiation','dist','birthyear'):
       {'rmse': 3.1539811311630106, 'r2': 0.0593535147380273}
      }

# %%
d25 = pd.DataFrame(dp15)
d35 = pd.DataFrame(dp25)
d45 = pd.DataFrame(dp35)
d55 = pd.DataFrame(dp45)
d65 = pd.DataFrame(dp55)
d75 = pd.DataFrame(dp65)
d15 = pd.DataFrame(dp75)

# %% [markdown]
# ## merge respective combination variables

# %%
data2 = [d1, d11, d12, d13, d14, d15]
df1= pd.concat(data2, ignore_index=False, sort=False)

data2 = [d2, d21, d22, d23, d24, d25]
df2 = pd.concat(data2, ignore_index=False, sort=False)

data3 = [d3,d31,d32,d33,d34,d35]
df3 = pd.concat(data3, ignore_index=False, sort=False)

data4 = [d4,d41,d42,d43,d44,d45]
df4 = pd.concat(data4, ignore_index=False, sort=False)

data5 = [d5,d51,d52,d53,d54,d55]
df5 = pd.concat(data5, ignore_index=False, sort=False)

data6 = [d6,d61,d62,d63,d64,d65]
df6 = pd.concat(data6, ignore_index=False, sort=False)

data7 = [d7,d71,d72,d73,d74,d75]
df7 = pd.concat(data7, ignore_index=False, sort=False)

# %% [markdown]
# ## Manupulate the dataframes

# %%
df2 = df2.rename_axis('estimates').reset_index()
df3 = df3.rename_axis('estimates').reset_index()
df4 = df4.rename_axis('estimates').reset_index()
df5 = df5.rename_axis('estimates').reset_index()
df6 = df6.rename_axis('estimates').reset_index()
df7 = df7.rename_axis('estimates').reset_index()
df1 = df1.rename_axis('estimates').reset_index()

# %%
from matplotlib.backends.backend_pdf import PdfPages
def legend_without_duplicate_labels(figure):
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    figure.legend(by_label.values(), by_label.keys(),  bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ### Visulaization for 2 variables

# %%
columns = [('dist', 'birthyear') ,('start_lat', 'start_lon'), ('end_lat', 'end_lon'),
             ('hour', 'temp'),  ('feelslike', 'dew'), ('snowdepth', 'winddir'), ('sealevelpressure', 'visibility'),
              ('solarradiation', 'dist')]
    
colors = [ "teal", "yellow", "crimson","deepskyblue", "deeppink",]

with PdfPages('MICE_Estimates_Plots.pdf') as pdf:
    for var in columns:
        sns.set_style("whitegrid")
        sns.set_palette(sns.color_palette(colors))
        sns.set_context("notebook", 
                        font_scale=1.3, 
                        rc={"lines.linewidth": 1.0})
        plt.figure(figsize=(12,3))
        plt.subplot(1,2,1)
        r2 = sns.pointplot(hue= 'col' , y=var, x='percent', data=df2[df2['estimates'] == 'r2'])
        _, xlabels = plt.xticks()
        r2.set_xticklabels(xlabels, size=10)
        plt.title(f"R2 plot of {var}", fontsize=12)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.ylabel("R2 score", fontsize=10)
        # add labels here
        plt.gca().get_legend().remove()
        
        ## Plot for R2
        plt.subplot(1,2,2)
        rmse = sns.pointplot(hue='col',y=var, x='percent', data=df2[df2['estimates']=='rmse'])
        _, xlabels = plt.xticks()
        rmse.set_xticklabels(xlabels, size=10)
        plt.title(f"RMSE plot of {var}", fontsize=12)
        plt.ylabel('RMSE error', fontsize=10)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.gca().get_legend().remove()

#         handles, labels = plt.gca().get_legend_handles_labels()

#         l = plt.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        legend_without_duplicate_labels(plt)
        plt.tight_layout()    
        pdf.savefig()  # saves the current figure into a pdf page
        plt.close()

# %% [markdown]
# ### Visulaization for 3 variables

# %%
columns = [('dist', 'birthyear', 'start_lat'),
                      ('start_lat', 'start_lon', 'end_lat'),
                             ('end_lat', 'end_lon', 'hour'),
                              ('hour', 'temp', 'feelslike'),
                          ('feelslike', 'dew', 'snowdepth'),
               ('snowdepth', 'winddir', 'sealevelpressure'),
       ('sealevelpressure', 'visibility', 'solarradiation'),
                    ('solarradiation', 'dist', 'birthyear')]
    
colors = [ "teal", "yellow", "crimson","deepskyblue", "deeppink",]

with PdfPages('MICE_Estimates_Plots.pdf') as pdf:
    for var in columns:
        sns.set_style("whitegrid")
        sns.set_palette(sns.color_palette("Set2"))
        sns.set_context("notebook", 
                        font_scale=1.3, 
                        rc={"lines.linewidth": 1.0})
        plt.figure(figsize=(12,3))
        plt.subplot(1,2,1)
        r2 = sns.pointplot(hue= 'col' , y=var, x='percent', data=df3[df3['estimates'] == 'r2'])
       # sns.scatterplot(y=df_full['start_lat'], x='percent', data=df_full[df_full['estimates'] == 'R2'])
        
#         rmse.set_yticklabels(ylabels, size=10)
        _, xlabels = plt.xticks()
        r2.set_xticklabels(xlabels, size=10)
        plt.title(f"R2 plot of {var}", fontsize=12)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.ylabel("R2 score", fontsize=10)
        # add labels here
        plt.gca().get_legend().remove()
        
        ## Plot for R2
        plt.subplot(1,2,2)
        rmse = sns.pointplot(hue='col',y=var, x='percent', data=df3[df3['estimates']=='rmse'])
    #    sns.scatterplot(y=df_full['start_lat'], x='percent', data=df_full[df_full['estimates'] == 'RMSE'])
#         _, ylabels = plt.yticks()
#         r2.set_yticklabels(ylabels, size=10)
        _, xlabels = plt.xticks()
        rmse.set_xticklabels(xlabels, size=10)
        plt.title(f"RMSE plot of {var}", fontsize=12)
        plt.ylabel('RMSE error', fontsize=10)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.gca().get_legend().remove()

#         handles, labels = plt.gca().get_legend_handles_labels()

#         l = plt.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        legend_without_duplicate_labels(plt)
        plt.tight_layout()    
        pdf.savefig()  # saves the current figure into a pdf page
        plt.close()

# %% [markdown]
# ### Visualization for 4 variables

# %%
columns = [('dist', 'birthyear', 'start_lat', 'start_lon'),
                   ('start_lat', 'start_lon', 'end_lat', 'end_lon'),
                             ('end_lat', 'end_lon', 'hour', 'temp'),
                               ('hour', 'temp', 'feelslike', 'dew'),
                       ('feelslike', 'dew', 'snowdepth', 'winddir'),
         ('snowdepth', 'winddir', 'sealevelpressure', 'visibility'),
       ('sealevelpressure', 'visibility', 'solarradiation', 'dist'),
               ('solarradiation', 'dist', 'birthyear', 'start_lat')]
    
colors = [ "teal", "yellow", "crimson","deepskyblue", "deeppink",]

with PdfPages('MICE_Estimates_Plots.pdf') as pdf:
    for var in columns:
        sns.set_style("whitegrid")
        sns.set_palette(sns.color_palette(colors))
        sns.set_context("notebook", 
                        font_scale=1.3, 
                        rc={"lines.linewidth": 1.0})
        plt.figure(figsize=(12,3))
        plt.subplot(1,2,1)
        r2 = sns.pointplot(hue= 'col' , y=var, x='percent', data=df4[df4['estimates'] == 'r2'])
        #sns.scatterplot(y=df_full['start_lat'], x='percent', data=df_full[df_full['estimates'] == 'R2'])
        
#         rmse.set_yticklabels(ylabels, size=10)
        _, xlabels = plt.xticks()
        r2.set_xticklabels(xlabels, size=10)
        plt.title(f"R2 plot of {var}", fontsize=12)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.ylabel("R2 score", fontsize=10)
        # add labels here
        plt.gca().get_legend().remove()
        
        ## Plot for R2
        plt.subplot(1,2,2)
        rmse = sns.pointplot(hue='col',y=var, x='percent', 
                    data=df4[df4['estimates']=='rmse'])
      #  sns.scatterplot(y=df_full['start_lat'], x='percent', data=df_full[df_full['estimates'] == 'RMSE'])
#         _, ylabels = plt.yticks()
#         r2.set_yticklabels(ylabels, size=10)
        _, xlabels = plt.xticks()
        rmse.set_xticklabels(xlabels, size=10)
        plt.title(f"RMSE plot of {var}", fontsize=12)
        plt.ylabel('RMSE error', fontsize=10)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.gca().get_legend().remove()

#         handles, labels = plt.gca().get_legend_handles_labels()

#         l = plt.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        legend_without_duplicate_labels(plt)
        plt.tight_layout()    
        pdf.savefig()  # saves the current figure into a pdf page
        plt.close()

# %% [markdown]
# ### Visaulization for 5 variables

# %%
columns = [('dist', 'birthyear', 'start_lat', 'start_lon', 'end_lat'),
                           ('start_lat', 'start_lon', 'end_lat', 'end_lon', 'hour'),
                                ('end_lat', 'end_lon', 'hour', 'temp', 'feelslike'),
                                  ('hour', 'temp', 'feelslike', 'dew', 'snowdepth'),
                   ('feelslike', 'dew', 'snowdepth', 'winddir', 'sealevelpressure'),
       ('snowdepth', 'winddir', 'sealevelpressure', 'visibility', 'solarradiation'),
          ('sealevelpressure', 'visibility', 'solarradiation', 'dist', 'birthyear'),
                  ('solarradiation', 'dist', 'birthyear', 'start_lat', 'start_lon')]
    
colors = [ "teal", "yellow", "crimson","deepskyblue", "deeppink",]

with PdfPages('Multiple_Regression_Estimates_Plots.pdf') as pdf:
    for var in columns:
        sns.set_style("whitegrid")
        sns.set_palette(sns.color_palette(colors))
        sns.set_context("notebook", 
                        font_scale=1.3, 
                        rc={"lines.linewidth": 1.0})
        plt.figure(figsize=(12,3))
        plt.subplot(1,2,1)
        r2 = sns.pointplot(hue= 'col' , y=var, x='percent', data=df5[df5['estimates'] == 'r2'])
        
#         rmse.set_yticklabels(ylabels, size=10)
        _, xlabels = plt.xticks()
        r2.set_xticklabels(xlabels, size=10)
        plt.title(f"R2 plot of {var}", fontsize=12)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.ylabel("R2 score", fontsize=10)
        # add labels here
        plt.gca().get_legend().remove()
        
        ## Plot for R2
        plt.subplot(1,2,2)
        rmse = sns.pointplot(hue='col',y=var, x='percent', 
                    data=df5[df5['estimates']=='rmse'])
#         _, ylabels = plt.yticks()
#         r2.set_yticklabels(ylabels, size=10)
        _, xlabels = plt.xticks()
        rmse.set_xticklabels(xlabels, size=10)
        plt.title(f"RMSE plot of {var}", fontsize=12)
        plt.ylabel('RMSE error', fontsize=10)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.gca().get_legend().remove()

#         handles, labels = plt.gca().get_legend_handles_labels()

#         l = plt.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        legend_without_duplicate_labels(plt)
        plt.tight_layout()    
        pdf.savefig()  # saves the current figure into a pdf page
        plt.close()

# %% [markdown]
# ## Visualization for 6 variables

# %%
columns = [('dist', 'birthyear', 'start_lat', 'start_lon', 'end_lat', 'end_lon'),
                                   ('end_lat', 'end_lon', 'hour', 'temp', 'feelslike', 'dew'),
                                 ('hour', 'temp', 'feelslike', 'dew', 'snowdepth', 'winddir'),
               ('feelslike', 'dew', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility'),
         ('snowdepth', 'winddir', 'sealevelpressure', 'visibility', 'solarradiation', 'dist'),
       ('sealevelpressure', 'visibility', 'solarradiation', 'dist', 'birthyear', 'start_lat'),
                 ('solarradiation', 'dist', 'birthyear', 'start_lat', 'start_lon', 'end_lat')]
    
colors = [ "teal", "yellow", "crimson","deepskyblue", "deeppink",]

with PdfPages('Multiple_Regression_Estimates_Plots.pdf') as pdf:
    for var in columns:
        sns.set_style("whitegrid")
        sns.set_palette(sns.color_palette(colors))
        sns.set_context("notebook", 
                        font_scale=1.3, 
                        rc={"lines.linewidth": 1.0})
        plt.figure(figsize=(12,3))
        plt.subplot(1,2,1)
        r2 = sns.pointplot(hue= 'col' , y=var, x='percent', data=df6[df6['estimates'] == 'r2'])
        
#         rmse.set_yticklabels(ylabels, size=10)
        _, xlabels = plt.xticks()
        r2.set_xticklabels(xlabels, size=10)
        plt.title(f"R2 plot of {var}", fontsize=12)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.ylabel("R2 score", fontsize=10)
        # add labels here
        plt.gca().get_legend().remove()
        
        ## Plot for R2
        plt.subplot(1,2,2)
        rmse = sns.pointplot(hue='col',y=var, x='percent', 
                    data=df6[df6['estimates']=='rmse'])
#         _, ylabels = plt.yticks()
#         r2.set_yticklabels(ylabels, size=10)
        _, xlabels = plt.xticks()
        rmse.set_xticklabels(xlabels, size=10)
        plt.title(f"RMSE plot of {var}", fontsize=12)
        plt.ylabel('RMSE error', fontsize=10)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.gca().get_legend().remove()

#         handles, labels = plt.gca().get_legend_handles_labels()

#         l = plt.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        legend_without_duplicate_labels(plt)
        plt.tight_layout()    
        pdf.savefig()  # saves the current figure into a pdf page
        plt.close()

# %% [markdown]
# ### Visulization for 7 vriables

# %%
columns = [('dist', 'birthyear', 'start_lat', 'start_lon', 'end_lat', 'end_lat', 'end_lon'),
                                   ('end_lat', 'end_lon', 'hour', 'temp', 'feelslike', 'dew', 'snowdepth'),
                          ('hour', 'temp', 'feelslike', 'dew', 'snowdepth', 'winddir', 'sealevelpressure'),
          ('feelslike', 'dew', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility', 'solarradiation'),
         ('snowdepth', 'winddir', 'sealevelpressure', 'visibility', 'solarradiation', 'dist', 'birthyear'),
       ('sealevelpressure', 'visibility', 'solarradiation', 'dist', 'birthyear', 'start_lat', 'start_lon'),
                   ('solarradiation', 'dist', 'birthyear', 'start_lat', 'start_lon', 'end_lat', 'end_lat')]
    
colors = [ "teal", "yellow", "crimson","deepskyblue", "deeppink",]

with PdfPages('Multiple_Regression_Estimates_Plots.pdf') as pdf:
    for var in columns:
        sns.set_style("whitegrid")
        sns.set_palette(sns.color_palette(colors))
        sns.set_context("notebook", 
                        font_scale=1.3, 
                        rc={"lines.linewidth": 1.0})
        plt.figure(figsize=(12,3))
        plt.subplot(1,2,1)
        r2 = sns.pointplot(hue= 'col' , y=var, x='percent', data=df7[df7['estimates'] == 'r2'])
        
#         rmse.set_yticklabels(ylabels, size=10)
        _, xlabels = plt.xticks()
        r2.set_xticklabels(xlabels, size=10)
        plt.title(f"R2 plot of {var}", fontsize=12)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.ylabel("R2 score", fontsize=10)
        # add labels here
        plt.gca().get_legend().remove()
        
        ## Plot for R2
        plt.subplot(1,2,2)
        rmse = sns.pointplot(hue='col',y=var, x='percent', 
                    data=df7[df7['estimates']=='rmse'])
#         _, ylabels = plt.yticks()
#         r2.set_yticklabels(ylabels, size=10)
        _, xlabels = plt.xticks()
        rmse.set_xticklabels(xlabels, size=10)
        plt.title(f"RMSE plot of {var}", fontsize=12)
        plt.ylabel('RMSE error', fontsize=10)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.gca().get_legend().remove()

#         handles, labels = plt.gca().get_legend_handles_labels()

#         l = plt.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        legend_without_duplicate_labels(plt)
        plt.tight_layout()    
        pdf.savefig()  # saves the current figure into a pdf page
        plt.close()

# %% [markdown]
# ### Test for all columns at one graph

# %%
colors = [ "teal","yellow", "crimson","deepskyblue", "deeppink",]

columns3 = [('dist', 'birthyear', 'start_lat'),
                      ('start_lat', 'start_lon', 'end_lat'),
                             ('end_lat', 'end_lon', 'hour'),
                              ('hour', 'temp', 'feelslike'),
                          ('feelslike', 'dew', 'snowdepth'),
               ('snowdepth', 'winddir', 'sealevelpressure'),
       ('sealevelpressure', 'visibility', 'solarradiation'),
                    ('solarradiation', 'dist', 'birthyear')]
    

columns2 =[('dist', 'birthyear'),         ('start_lat', 'start_lon'),
                   ('end_lat', 'end_lon'),                   ('hour', 'temp'),
                     ('feelslike', 'dew'),           ('snowdepth', 'winddir'),
       ('sealevelpressure', 'visibility'),         ('solarradiation', 'dist')]

columns4 =[('dist', 'birthyear', 'start_lat', 'start_lon'),
                   ('start_lat', 'start_lon', 'end_lat', 'end_lon'),
                             ('end_lat', 'end_lon', 'hour', 'temp'),
                               ('hour', 'temp', 'feelslike', 'dew'),
                       ('feelslike', 'dew', 'snowdepth', 'winddir'),
         ('snowdepth', 'winddir', 'sealevelpressure', 'visibility'),
       ('sealevelpressure', 'visibility', 'solarradiation', 'dist'),
               ('solarradiation', 'dist', 'birthyear', 'start_lat')]

columns5 =[('dist', 'birthyear', 'start_lat', 'start_lon', 'end_lat'),
                           ('start_lat', 'start_lon', 'end_lat', 'end_lon', 'hour'),
                                ('end_lat', 'end_lon', 'hour', 'temp', 'feelslike'),
                                  ('hour', 'temp', 'feelslike', 'dew', 'snowdepth'),
                   ('feelslike', 'dew', 'snowdepth', 'winddir', 'sealevelpressure'),
       ('snowdepth', 'winddir', 'sealevelpressure', 'visibility', 'solarradiation'),
          ('sealevelpressure', 'visibility', 'solarradiation', 'dist', 'birthyear'),
                  ('solarradiation', 'dist', 'birthyear', 'start_lat', 'start_lon')]

columns6 =[('dist', 'birthyear', 'start_lat', 'start_lon', 'end_lat', 'end_lon'),
                                   ('end_lat', 'end_lon', 'hour', 'temp', 'feelslike', 'dew'),
                                 ('hour', 'temp', 'feelslike', 'dew', 'snowdepth', 'winddir'),
               ('feelslike', 'dew', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility'),
         ('snowdepth', 'winddir', 'sealevelpressure', 'visibility', 'solarradiation', 'dist'),
       ('sealevelpressure', 'visibility', 'solarradiation', 'dist', 'birthyear', 'start_lat'),
                 ('solarradiation', 'dist', 'birthyear', 'start_lat', 'start_lon', 'end_lat')]
columns7 =[('dist', 'birthyear', 'start_lat', 'start_lon', 'end_lat', 'end_lat', 'end_lon'),
                                   ('end_lat', 'end_lon', 'hour', 'temp', 'feelslike', 'dew', 'snowdepth'),
                          ('hour', 'temp', 'feelslike', 'dew', 'snowdepth', 'winddir', 'sealevelpressure'),
          ('feelslike', 'dew', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility', 'solarradiation'),
         ('snowdepth', 'winddir', 'sealevelpressure', 'visibility', 'solarradiation', 'dist', 'birthyear'),
       ('sealevelpressure', 'visibility', 'solarradiation', 'dist', 'birthyear', 'start_lat', 'start_lon'),
                   ('solarradiation', 'dist', 'birthyear', 'start_lat', 'start_lon', 'end_lat', 'end_lat')]

with PdfPages('MICE_Estimates_Plots.pdf') as pdf:
    for var in columns2:
        i =0
        sns.set_style("whitegrid")
        sns.set_palette(sns.color_palette(colors))
        sns.set_context("notebook", 
                        font_scale=1.3, 
                        rc={"lines.linewidth": 1.0})
        plt.figure(figsize=(12,3))
        plt.subplot(1,2,1)
        r2 = sns.pointplot(hue= 'col' , y=var, x='percent', data=df2[df2['estimates'] == 'r2'], 
                      markers=['o'],  linestyles=["-"], palette="cividis_r")
        sns.pointplot(hue= df3['col'] , y=df3[columns3[i]], x='percent', data=df3[df3['estimates'] == 'r2'], 
                      markers=['s'],  linestyles=["--"], palette="spring_r")
        sns.pointplot(hue= df4['col'] , y=df4[columns4[i]], x='percent', data=df4[df4['estimates'] == 'r2'], 
                      markers=['v'],  linestyles=[':'], palette="YlGn_r")
        sns.pointplot(hue= df5['col'] , y=df5[columns5[i]], x='percent', data=df5[df5['estimates'] == 'r2'], 
                      markers=['p'],  linestyles=["-."], palette="Blues_r")
        sns.pointplot(hue= df6['col'] , y=df6[columns6[i]], x='percent', data=df6[df6['estimates'] == 'r2'], 
                      markers=['x'],  linestyles=['-'], palette="Dark2_r")
        sns.pointplot(hue= df7['col'] , y=df7[columns7[i]], x='percent', data=df7[df7['estimates'] == 'r2'], 
                      markers=['d'],  linestyles=['--'], palette="twilight")
       
        
#         rmse.set_yticklabels(ylabels, size=10)
        _, xlabels = plt.xticks()
        r2.set_xticklabels(xlabels, size=10)
        plt.title(f"R2 plot of {var}", fontsize=12)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.ylabel("R2 score", fontsize=10)
        # add labels here
        plt.gca().get_legend().remove()
        
        ## Plot for R2
        plt.subplot(1,2,2)
        rmse = sns.pointplot(hue='col',y=var, x='percent', data=df2[df2['estimates']=='rmse'], 
                      markers=['o'],  linestyles=["-"],palette="cividis_r")
#         sns.scatterplot(y=df_full['start_lat'], x='percent', data=df_full[df_full['estimates'] == 'RMSE'], 
#                         markers=['d'],  linestyles=['--'])
        sns.pointplot(hue= df3['col'] , y=df3[columns3[i]], x='percent', data=df3[df3['estimates'] == 'rmse'], 
                      markers=['s'],  linestyles=["--"], palette="spring_r")
        sns.pointplot(hue= df4['col'] , y=df4[columns4[i]], x='percent', data=df4[df4['estimates'] == 'rmse'], 
                      markers=['v'],  linestyles=[':'],palette="YlGn_r")
        sns.pointplot(hue= df5['col'] , y=df5[columns5[i]], x='percent', data=df5[df5['estimates'] == 'rmse'], 
                      markers=['p'],  linestyles=["-."],  palette="Blues_r")
        sns.pointplot(hue= df6['col'] , y=df6[columns6[i]], x='percent', data=df6[df6['estimates'] == 'rmse'], 
                      markers=['x'],  linestyles=['-'], palette="Dark2_r")
        sns.pointplot(hue= df7['col'] , y=df7[columns7[i]], x='percent', data=df7[df7['estimates'] == 'rmse'], 
                      markers=['d'],  linestyles=['--'], palette="twilight")
       
 #         _, ylabels = plt.yticks()
#         r2.set_yticklabels(ylabels, size=10)
        _, xlabels = plt.xticks()
        rmse.set_xticklabels(xlabels, size=10)
        plt.title(f"RMSE plot of {var}", fontsize=12)
        plt.ylabel('RMSE error', fontsize=10)
        plt.xlabel('Percent Missing', fontsize=10)
        plt.gca().get_legend().remove()

#         handles, labels = plt.gca().get_legend_handles_labels()

#         l = plt.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        legend_without_duplicate_labels(plt)
        plt.tight_layout()    
        pdf.savefig()  # saves the current figure into a pdf page
        plt.close() 
        i = i+1
