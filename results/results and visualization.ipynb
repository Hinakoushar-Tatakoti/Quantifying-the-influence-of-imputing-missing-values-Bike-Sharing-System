# %%
import datetime
import os
import random
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy
import statsmodels.api as sm
import pylab as py

import numpy as np

# %%
cols = ['tripduration','gender','dist','hour','birthyear','usertype']

# %%
dp1 = {'method': 'drop','percent': '10%','gender_female': {'MAE': 279.2542248801155,
  'MSE': 432806.1392976349,
  'RMSE': 657.880034122966,
  'R2': 0.16721358241898143,
  'intercept': 4330.683499886296,
  'Mu_train': 0.21332945170719425,
  'sigma_train': 0.40965919611487306,
  'Mu_test': 0.21078886493461532,
  'sigma_test': 0.40787196183577956},
 'gender_male': {'MAE': 279.2542248801155,
  'MSE': 432806.1392976349,
  'RMSE': 657.880034122966,
  'R2': 0.16721358241898143,
  'intercept': 4330.683499886296,
  'Mu_train': 0.7267899082965824,
  'sigma_train': 0.44560870578778683,
  'Mu_test': 0.7302154310982423,
  'sigma_test': 0.44385127623356097},
 'gender_unknown': {'MAE': 279.2542248801155,
  'MSE': 432806.1392976349,
  'RMSE': 657.880034122966,
  'R2': 0.16721358241898143,
  'intercept': 4330.683499886296,
  'Mu_train': 0.059880639996223284,
  'sigma_train': 0.23726603300852148,
  'Mu_test': 0.05899570396714243,
  'sigma_test': 0.2356185147712141},
 'dist': {'MAE': 279.2542248801155,
  'MSE': 432806.1392976349,
  'RMSE': 657.880034122966,
  'R2': 0.16721358241898143,
  'intercept': 4330.683499886296,
  'Mu_train': 0.7846721331162541,
  'sigma_train': 0.5429889265774022,
  'Mu_test': 0.782316118029587,
  'sigma_test': 0.5400844246046014},
 'hour': {'MAE': 279.2542248801155,
  'MSE': 432806.1392976349,
  'RMSE': 657.880034122966,
  'R2': 0.16721358241898143,
  'intercept': 4330.683499886296,
  'Mu_train': 13.636136890266691,
  'sigma_train': 5.155795928773315,
  'Mu_test': 13.620910507183659,
  'sigma_test': 5.161691344412102},
 'birthyear': {'MAE': 279.2542248801155,
  'MSE': 432806.1392976349,
  'RMSE': 657.880034122966,
  'R2': 0.16721358241898143,
  'intercept': 4330.683499886296,
  'Mu_train': 1980.4473836397326,
  'sigma_train': 10.104827199980448,
  'Mu_test': 1980.3931420838119,
  'sigma_test': 10.055824988748098},
 'usertype_Customer': {'MAE': 279.2542248801155,
  'MSE': 432806.1392976349,
  'RMSE': 657.880034122966,
  'R2': 0.16721358241898143,
  'intercept': 4330.683499886296,
  'Mu_train': 0.062091593263280474,
  'sigma_train': 0.2413223081611356,
  'Mu_test': 0.06086833367428832,
  'sigma_test': 0.23909052509260498},
 'usertype_Subscriber': {'MAE': 279.2542248801155,
  'MSE': 432806.1392976349,
  'RMSE': 657.880034122966,
  'R2': 0.16721358241898143,
  'intercept': 4330.683499886296,
  'Mu_train': 0.9379084067367195,
  'sigma_train': 0.2413223081611356,
  'Mu_test': 0.9391316663257117,
  'sigma_test': 0.239090525092605}}

# %%
dp2 = {'method': 'mode','percent': '10%','gender_female': {'MAE': 278.68373476735826,
  'MSE': 429063.44288055133,
  'RMSE': 655.0293450529917,
  'R2': 0.16758965468078135,
  'intercept': 4407.742348775691,
  'Mu_train': 0.19199665760253795,
  'sigma_train': 0.3938711595850177,
  'Mu_test': 0.1897093813732155,
  'sigma_test': 0.39207385670261174},
 'gender_male': {'MAE': 278.68373476735826,
  'MSE': 429063.44288055133,
  'RMSE': 655.0293450529917,
  'R2': 0.16758965468078135,
  'intercept': 4407.742348775691,
  'Mu_train': 0.7541107239972807,
  'sigma_train': 0.43061397619134123,
  'Mu_test': 0.7571946521640607,
  'sigma_test': 0.42878143005567},
 'gender_unknown': {'MAE': 278.68373476735826,
  'MSE': 429063.44288055133,
  'RMSE': 655.0293450529917,
  'R2': 0.16758965468078135,
  'intercept': 4407.742348775691,
  'Mu_train': 0.05389261840018128,
  'sigma_train': 0.22580607745467474,
  'Mu_test': 0.05309596646272377,
  'sigma_test': 0.22422644106633338},
 'dist': {'MAE': 283.2296212487276,
  'MSE': 430551.94962635095,
  'RMSE': 656.1645751077629,
  'R2': 0.16470185700227824,
  'intercept': 4111.855820672355,
  'Mu_train': 0.7721098420873885,
  'sigma_train': 0.5165014016892983,
  'Mu_test': 0.7699889903902088,
  'sigma_test': 0.5137007171323418},
 'hour': {'MAE': 278.7603679873668,
  'MSE': 429053.8033245243,
  'RMSE': 655.0219869016034,
  'R2': 0.1676083560320485,
  'intercept': 4251.533427259707,
  'Mu_train': 13.072527192386131,
  'sigma_train': 5.175224975410671,
  'Mu_test': 13.058803535010197,
  'sigma_test': 5.1790218757925235},
 'birthyear': {'MAE': 278.69358293844994,
  'MSE': 429070.9915071109,
  'RMSE': 655.0351070798503,
  'R2': 0.16757500986555574,
  'intercept': 3954.4623684338007,
  'Mu_train': 1979.302653382053,
  'sigma_train': 10.182858952140826,
  'Mu_test': 1979.2537956038975,
  'sigma_test': 10.133608258003052},
 'usertype_Customer': {'MAE': 281.37174548463054,
  'MSE': 434650.0532401177,
  'RMSE': 659.279950582541,
  'R2': 0.15675127556521273,
  'intercept': 4000.1784635185445,
  'Mu_train': 0.055882477906186265,
  'sigma_train': 0.22969504429703688,
  'Mu_test': 0.054781327894856104,
  'sigma_test': 0.2275545371305804},
 'usertype_Subscriber': {'MAE': 281.37174548463054,
  'MSE': 434650.0532401177,
  'RMSE': 659.279950582541,
  'R2': 0.15675127556521273,
  'intercept': 4000.1784635185445,
  'Mu_train': 0.9441175220938137,
  'sigma_train': 0.22969504429703688,
  'Mu_test': 0.9452186721051439,
  'sigma_test': 0.2275545371305804}}

# %%
dp3 = {'method': 'mean','percent': '10%','dist': {'MAE': 282.7806168658308,
  'MSE': 430535.91508764157,
  'RMSE': 656.1523566121222,
  'R2': 0.1647329650263376,
  'intercept': 4115.940493290295,
  'Mu_train': 0.7846721331167078,
  'sigma_train': 0.5151246269979137,
  'Mu_test': 0.7823161180295614,
  'sigma_test': 0.512367863719376},
 'hour': {'MAE': 278.6932198006469,
  'MSE': 429028.8170143051,
  'RMSE': 655.0029137448971,
  'R2': 0.16765683106170426,
  'intercept': 4257.934127420233,
  'Mu_train': 13.636136890269404,
  'sigma_train': 4.891218447910462,
  'Mu_test': 13.620910507182153,
  'sigma_test': 4.896798809282101},
 'birthyear': {'MAE': 278.6530299877195,
  'MSE': 429000.3044984794,
  'RMSE': 654.9811482008314,
  'R2': 0.16771214715431992,
  'intercept': 4313.150255488631,
  'Mu_train': 1980.4473836399623,
  'sigma_train': 9.58628267998128,
  'Mu_test': 1980.3931420840102,
  'sigma_test': 9.539770696393475}}

# %%
dp4 = {'method': 'sample','percent': '10%','gender_female': {'MAE': 278.76076998898355,
  'MSE': 429156.02409157454,
  'RMSE': 655.100010755285,
  'R2': 0.16741004124804404,
  'intercept': 4517.511059910166,
  'Mu_train': 0.2130813788805801,
  'sigma_train': 0.4094854070041289,
  'Mu_test': 0.21116587355540448,
  'sigma_test': 0.408138709980046},
 'gender_male': {'MAE': 278.76076998898355,
  'MSE': 429156.02409157454,
  'RMSE': 655.100010755285,
  'R2': 0.16741004124804404,
  'intercept': 4517.511059910166,
  'Mu_train': 0.7269077158395649,
  'sigma_train': 0.44554864085151974,
  'Mu_test': 0.7298889644232948,
  'sigma_test': 0.44402010795404767},
 'gender_unknown': {'MAE': 278.76076998898355,
  'MSE': 429156.02409157454,
  'RMSE': 655.100010755285,
  'R2': 0.16741004124804404,
  'intercept': 4517.511059910166,
  'Mu_train': 0.060010905279854976,
  'sigma_train': 0.23750746568501435,
  'Mu_test': 0.0589451620213007,
  'sigma_test': 0.23552370479563514},
 'dist': {'MAE': 286.45448848217734,
  'MSE': 432069.9376809045,
  'RMSE': 657.320270249522,
  'R2': 0.1617568637113136,
  'intercept': 4001.055412114822,
  'Mu_train': 0.7846422274582016,
  'sigma_train': 0.5432903957779815,
  'Mu_test': 0.7824346834659238,
  'sigma_test': 0.5403040746875721},
 'hour': {'MAE': 278.83236431806034,
  'MSE': 429111.9555126809,
  'RMSE': 655.0663748908815,
  'R2': 0.1674955370915685,
  'intercept': 4247.846498959255,
  'Mu_train': 13.630934171765238,
  'sigma_train': 5.15449225875592,
  'Mu_test': 13.621161907999094,
  'sigma_test': 5.161991919524151},
 'birthyear': {'MAE': 278.6698739214603,
  'MSE': 429046.1796312413,
  'RMSE': 655.0161674579043,
  'R2': 0.16762314648148813,
  'intercept': 3928.5412817428382,
  'Mu_train': 1980.4457497733968,
  'sigma_train': 10.106526510898506,
  'Mu_test': 1980.391173804668,
  'sigma_test': 10.055897549394137},
 'usertype_Customer': {'MAE': 282.97614847484635,
  'MSE': 438765.0675647037,
  'RMSE': 662.3934386485903,
  'R2': 0.14876788627451576,
  'intercept': 3714.3964141924653,
  'Mu_train': 0.062103444368910035,
  'sigma_train': 0.24134376478268046,
  'Mu_test': 0.06054554724677091,
  'sigma_test': 0.23849651892249615},
 'usertype_Subscriber': {'MAE': 282.97614847484635,
  'MSE': 438765.0675647037,
  'RMSE': 662.3934386485903,
  'R2': 0.14876788627451576,
  'intercept': 3714.3964141924653,
  'Mu_train': 0.93789655563109,
  'sigma_train': 0.24134376478268046,
  'Mu_test': 0.9394544527532291,
  'sigma_test': 0.23849651892249613}}

# %%
d1 = pd.DataFrame(dp1)
d2 = pd.DataFrame(dp2)
d3 = pd.DataFrame(dp3)
d4 = pd.DataFrame(dp4)

# %%
data1 = [d1, d2,d3,d4]
df1 = pd.concat(data1, ignore_index=False, sort=False)

# %%
df1
# Out:
#              method percent  gender_female    gender_male  gender_unknown  \
# MAE            drop     10%     279.254225     279.254225      279.254225
# MSE            drop     10%  432806.139298  432806.139298   432806.139298
# RMSE           drop     10%     657.880034     657.880034      657.880034
# R2             drop     10%       0.167214       0.167214        0.167214
# intercept      drop     10%    4330.683500    4330.683500     4330.683500
# Mu_train       drop     10%       0.213329       0.726790        0.059881
# sigma_train    drop     10%       0.409659       0.445609        0.237266
# Mu_test        drop     10%       0.210789       0.730215        0.058996
# sigma_test     drop     10%       0.407872       0.443851        0.235619
# MAE            mode     10%     278.683735     278.683735      278.683735
# MSE            mode     10%  429063.442881  429063.442881   429063.442881
# RMSE           mode     10%     655.029345     655.029345      655.029345
# ...

# %%
dq1 = {'method': 'drop','percent': '20%','gender_female': {'MAE': 278.73865762235374,
  'MSE': 422975.10446836834,
  'RMSE': 650.3653622913572,
  'R2': 0.16997851844153733,
  'intercept': 4267.144804996973,
  'Mu_train': 0.2129004275357829,
  'sigma_train': 0.40935873894239,
  'Mu_test': 0.20999893778989484,
  'sigma_test': 0.4073110862339015},
 'gender_male': {'MAE': 278.73865762235374,
  'MSE': 422975.10446836834,
  'RMSE': 650.3653622913572,
  'R2': 0.16997851844153733,
  'intercept': 4267.144804996973,
  'Mu_train': 0.7271294911173466,
  'sigma_train': 0.4454358229964737,
  'Mu_test': 0.7307474418439968,
  'sigma_test': 0.4435753615875751},
 'gender_unknown': {'MAE': 278.73865762235374,
  'MSE': 422975.10446836834,
  'RMSE': 650.3653622913572,
  'R2': 0.16997851844153733,
  'intercept': 4267.144804996973,
  'Mu_train': 0.05997008134687049,
  'sigma_train': 0.23743192749051348,
  'Mu_test': 0.059253620366108414,
  'sigma_test': 0.23610085916153653},
 'dist': {'MAE': 278.73865762235374,
  'MSE': 422975.10446836834,
  'RMSE': 650.3653622913572,
  'R2': 0.16997851844153733,
  'intercept': 4267.144804996973,
  'Mu_train': 0.7841921337561862,
  'sigma_train': 0.5423111331460886,
  'Mu_test': 0.782068133606212,
  'sigma_test': 0.5395611725931245},
 'hour': {'MAE': 278.73865762235374,
  'MSE': 422975.10446836834,
  'RMSE': 650.3653622913572,
  'R2': 0.16997851844153733,
  'intercept': 4267.144804996973,
  'Mu_train': 13.641184176750198,
  'sigma_train': 5.154544364033436,
  'Mu_test': 13.603990369295046,
  'sigma_test': 5.165492883680779},
 'birthyear': {'MAE': 278.73865762235374,
  'MSE': 422975.10446836834,
  'RMSE': 650.3653622913572,
  'R2': 0.16997851844153733,
  'intercept': 4267.144804996973,
  'Mu_train': 1980.4455091039451,
  'sigma_train': 10.108843492651083,
  'Mu_test': 1980.3877597988883,
  'sigma_test': 10.049076615209367},
 'usertype_Customer': {'MAE': 278.73865762235374,
  'MSE': 422975.10446836834,
  'RMSE': 650.3653622913572,
  'R2': 0.16997851844153733,
  'intercept': 4267.144804996973,
  'Mu_train': 0.06216087029644251,
  'sigma_train': 0.2414480368818346,
  'Mu_test': 0.06123641256240484,
  'sigma_test': 0.2397655773240115},
 'usertype_Subscriber': {'MAE': 278.73865762235374,
  'MSE': 422975.10446836834,
  'RMSE': 650.3653622913572,
  'R2': 0.16997851844153733,
  'intercept': 4267.144804996973,
  'Mu_train': 0.9378391297035575,
  'sigma_train': 0.24144803688183458,
  'Mu_test': 0.9387635874375951,
  'sigma_test': 0.2397655773240115}}

# %%
dq2 = {'method': 'mode','percent': '20%','gender_female': {'MAE': 278.7321056006803,
  'MSE': 429275.83119951247,
  'RMSE': 655.1914462197385,
  'R2': 0.16717760784514024,
  'intercept': 4526.713198285251,
  'Mu_train': 0.17032064355313845,
  'sigma_train': 0.37591491360780954,
  'Mu_test': 0.1679979605710401,
  'sigma_test': 0.3738671226914444},
 'gender_male': {'MAE': 278.7321056006803,
  'MSE': 429275.83119951247,
  'RMSE': 655.1914462197385,
  'R2': 0.16717760784514024,
  'intercept': 4526.713198285251,
  'Mu_train': 0.7817032064355314,
  'sigma_train': 0.4130906773077862,
  'Mu_test': 0.7845994788125992,
  'sigma_test': 0.41110282197329623},
 'gender_unknown': {'MAE': 278.7321056006803,
  'MSE': 429275.83119951247,
  'RMSE': 655.1914462197385,
  'R2': 0.16717760784514024,
  'intercept': 4526.713198285251,
  'Mu_train': 0.04797615001133016,
  'sigma_train': 0.213716168691913,
  'Mu_test': 0.04740256061636075,
  'sigma_test': 0.21249987622843455},
 'dist': {'MAE': 287.7887012385004,
  'MSE': 432003.53220551024,
  'RMSE': 657.2697560404786,
  'R2': 0.16188569455351487,
  'intercept': 3985.0390717951336,
  'Mu_train': 0.759163550890677,
  'sigma_train': 0.4876341366894877,
  'Mu_test': 0.7574634766169788,
  'sigma_test': 0.4850979678381624},
 'hour': {'MAE': 278.87003565167066,
  'MSE': 429190.7940687901,
  'RMSE': 655.1265481330993,
  'R2': 0.16734258528268275,
  'intercept': 4237.822911722738,
  'Mu_train': 12.512955330840699,
  'sigma_train': 5.132947039263315,
  'Mu_test': 12.483160548379788,
  'sigma_test': 5.1352271465681385},
 'birthyear': {'MAE': 278.71103269721345,
  'MSE': 429104.1670860413,
  'RMSE': 655.0604301024764,
  'R2': 0.16751064713418828,
  'intercept': 3569.7323147814336,
  'Mu_train': 1978.1564234930886,
  'sigma_train': 10.134641446441634,
  'Mu_test': 1978.1101433265353,
  'sigma_test': 10.076507375930033},
 'usertype_Customer': {'MAE': 283.68266088672016,
  'MSE': 440405.1961433106,
  'RMSE': 663.6303158712014,
  'R2': 0.14558593260509967,
  'intercept': 3725.5643932418284,
  'Mu_train': 0.049728784273736684,
  'sigma_train': 0.21738445116093827,
  'Mu_test': 0.048988783140720596,
  'sigma_test': 0.21584610744896857},
 'usertype_Subscriber': {'MAE': 283.68266088672016,
  'MSE': 440405.1961433106,
  'RMSE': 663.6303158712014,
  'R2': 0.14558593260509967,
  'intercept': 3725.5643932418284,
  'Mu_train': 0.9502712157262633,
  'sigma_train': 0.21738445116093827,
  'Mu_test': 0.9510112168592794,
  'sigma_test': 0.21584610744896857}}

# %%
dq3 = {'method': 'mean','percent': '20%','dist': {'MAE': 286.9939434102655,
  'MSE': 431890.3373680253,
  'RMSE': 657.1836405206883,
  'R2': 0.16210529973154308,
  'intercept': 3991.716784147813,
  'Mu_train': 0.9502712157262633,
  'sigma_train': 0.21738445116093827,
  'Mu_test': 0.9510112168592794,
  'sigma_test': 0.21584610744896857},
 'hour': {'MAE': 278.7067605557872,
  'MSE': 429076.69065292994,
  'RMSE': 655.0394573252286,
  'R2': 0.16756395316049721,
  'intercept': 4246.936417347307,
  'Mu_train': 0.9502712157262633,
  'sigma_train': 0.21738445116093827,
  'Mu_test': 0.9510112168592794,
  'sigma_test': 0.21584610744896857},
 'birthyear': {'MAE': 278.6542757636625,
  'MSE': 429039.20644985803,
  'RMSE': 655.0108445284384,
  'R2': 0.16763667489650347,
  'intercept': 4209.050052248725,
  'Mu_train': 0.9502712157262633,
  'sigma_train': 0.21738445116093827,
  'Mu_test': 0.9510112168592794,
  'sigma_test': 0.21584610744896857}}

# %%
dq4 = {'method': 'sample','percent': '20%','gender_female': {'MAE': 278.85396456035403,
  'MSE': 429384.3174478811,
  'RMSE': 655.2742307216736,
  'R2': 0.16696713762921922,
  'intercept': 4617.134205985364,
  'Mu_train': 0.21318405846363017,
  'sigma_train': 0.40955733369529207,
  'Mu_test': 0.20952300022660322,
  'sigma_test': 0.4069710779730033},
 'gender_male': {'MAE': 278.85396456035403,
  'MSE': 429384.3174478811,
  'RMSE': 655.2742307216736,
  'R2': 0.16696713762921922,
  'intercept': 4617.134205985364,
  'Mu_train': 0.7270387208248357,
  'sigma_train': 0.4454818985187002,
  'Mu_test': 0.7313193972354407,
  'sigma_test': 0.44327657207449467},
 'gender_unknown': {'MAE': 278.85396456035403,
  'MSE': 429384.3174478811,
  'RMSE': 655.2742307216736,
  'R2': 0.16696713762921922,
  'intercept': 4617.134205985364,
  'Mu_train': 0.0597772207115341,
  'sigma_train': 0.23707404665213513,
  'Mu_test': 0.05915760253795604,
  'sigma_test': 0.2359211073185802},
 'dist': {'MAE': 293.05216275275444,
  'MSE': 433936.9979399276,
  'RMSE': 658.7389452126902,
  'R2': 0.1581346481608319,
  'intercept': 3801.7326533840337,
  'Mu_train': 0.7844930004201232,
  'sigma_train': 0.5426091861326015,
  'Mu_test': 0.7812153635646467,
  'sigma_test': 0.5392997882341904},
 'hour': {'MAE': 278.8690825041156,
  'MSE': 429235.89405194425,
  'RMSE': 655.1609680467421,
  'R2': 0.16725508844934922,
  'intercept': 4232.620613782851,
  'Mu_train': 13.649189893496487,
  'sigma_train': 5.155164592950688,
  'Mu_test': 13.595966462723771,
  'sigma_test': 5.172227080329929},
 'birthyear': {'MAE': 278.6818707301921,
  'MSE': 429114.7975713067,
  'RMSE': 655.0685441778644,
  'R2': 0.16749002331722718,
  'intercept': 3702.7458214167964,
  'Mu_train': 1980.4555645252663,
  'sigma_train': 10.102287520414611,
  'Mu_test': 1980.391669499207,
  'sigma_test': 10.040044300442505},
 'usertype_Customer': {'MAE': 287.1207844125547,
  'MSE': 447741.4789664978,
  'RMSE': 669.1348735243873,
  'R2': 0.1313530777218911,
  'intercept': 3349.387813713847,
  'Mu_train': 0.06182019034670292,
  'sigma_train': 0.24082910905166993,
  'Mu_test': 0.06131033310673011,
  'sigma_test': 0.23990037777284742},
 'usertype_Subscriber': {'MAE': 287.1207844125547,
  'MSE': 447741.4789664978,
  'RMSE': 669.1348735243873,
  'R2': 0.1313530777218911,
  'intercept': 3349.387813713847,
  'Mu_train': 0.9381798096532971,
  'sigma_train': 0.24082910905166993,
  'Mu_test': 0.9386896668932699,
  'sigma_test': 0.23990037777284742}}

# %%
da1 = pd.DataFrame(dq1)
da2 = pd.DataFrame(dq2)
da3 = pd.DataFrame(dq3)
da4 = pd.DataFrame(dq4)

# %%
data2 = [da1, da2,da3,da4]
df2 = pd.concat(data2, ignore_index=False, sort=False)

# %%
df2
# Out:
#              method percent  gender_female    gender_male  gender_unknown  \
# MAE            drop     20%     278.738658     278.738658      278.738658
# MSE            drop     20%  422975.104468  422975.104468   422975.104468
# RMSE           drop     20%     650.365362     650.365362      650.365362
# R2             drop     20%       0.169979       0.169979        0.169979
# intercept      drop     20%    4267.144805    4267.144805     4267.144805
# Mu_train       drop     20%       0.212900       0.727129        0.059970
# sigma_train    drop     20%       0.409359       0.445436        0.237432
# Mu_test        drop     20%       0.209999       0.730747        0.059254
# sigma_test     drop     20%       0.407311       0.443575        0.236101
# MAE            mode     20%     278.732106     278.732106      278.732106
# MSE            mode     20%  429275.831200  429275.831200   429275.831200
# RMSE           mode     20%     655.191446     655.191446      655.191446
# ...

# %%
ds1= {'method': 'drop','percent': '30%','gender_female': {'MAE': 279.21711401617745,
  'MSE': 420130.14623705694,
  'RMSE': 648.1744720652433,
  'R2': 0.17175428879313015,
  'intercept': 4139.21243948069,
  'Mu_train': 0.21241565588613165,
  'sigma_train': 0.4090184485129352,
  'Mu_test': 0.21213531339780684,
  'sigma_test': 0.40882429450055874},
 'gender_male': {'MAE': 279.21711401617745,
  'MSE': 420130.14623705694,
  'RMSE': 648.1744720652433,
  'R2': 0.17175428879313015,
  'intercept': 4139.21243948069,
  'Mu_train': 0.7274787306147636,
  'sigma_train': 0.44525771179413776,
  'Mu_test': 0.7282604297333387,
  'sigma_test': 0.44486085488313537},
 'gender_unknown': {'MAE': 279.21711401617745,
  'MSE': 420130.14623705694,
  'RMSE': 648.1744720652433,
  'R2': 0.17175428879313015,
  'intercept': 4139.21243948069,
  'Mu_train': 0.06010561349910471,
  'sigma_train': 0.23768301259099936,
  'Mu_test': 0.05960425686885445,
  'sigma_test': 0.23675456385379678},
 'dist': {'MAE': 279.21711401617745,
  'MSE': 420130.14623705694,
  'RMSE': 648.1744720652433,
  'R2': 0.17175428879313015,
  'intercept': 4139.21243948069,
  'Mu_train': 0.7838262897723453,
  'sigma_train': 0.5424145362330546,
  'Mu_test': 0.7807552009991885,
  'sigma_test': 0.5387213259505671},
 'hour': {'MAE': 279.21711401617745,
  'MSE': 420130.14623705694,
  'RMSE': 648.1744720652433,
  'R2': 0.17175428879313015,
  'intercept': 4139.21243948069,
  'Mu_train': 13.640924219279523,
  'sigma_train': 5.154885144916811,
  'Mu_test': 13.611115607170316,
  'sigma_test': 5.155739916216756},
 'birthyear': {'MAE': 279.21711401617745,
  'MSE': 420130.14623705694,
  'RMSE': 648.1744720652433,
  'R2': 0.17175428879313015,
  'intercept': 4139.21243948069,
  'Mu_train': 1980.4443556463768,
  'sigma_train': 10.116586692568342,
  'Mu_test': 1980.3531137458017,
  'sigma_test': 10.050681992468522},
 'usertype_Customer': {'MAE': 279.21711401617745,
  'MSE': 420130.14623705694,
  'RMSE': 648.1744720652433,
  'R2': 0.17175428879313015,
  'intercept': 4139.21243948069,
  'Mu_train': 0.06231095284822612,
  'sigma_train': 0.24172007269169787,
  'Mu_test': 0.06142516084651803,
  'sigma_test': 0.24011096792515732},
 'usertype_Subscriber': {'MAE': 279.21711401617745,
  'MSE': 420130.14623705694,
  'RMSE': 648.1744720652433,
  'R2': 0.17175428879313015,
  'intercept': 4139.21243948069,
  'Mu_train': 0.9376890471517739,
  'sigma_train': 0.24172007269169787,
  'Mu_test': 0.9385748391534819,
  'sigma_test': 0.24011096792515732}}

# %%
ds2= {'method': 'mode','percent': '30%','gender_female': {'MAE': 278.8692481491538,
  'MSE': 429416.4352502737,
  'RMSE': 655.2987374093389,
  'R2': 0.16690482705155496,
  'intercept': 4572.206099409003,
  'Mu_train': 0.14869065828234762,
  'sigma_train': 0.3557839156122109,
  'Mu_test': 0.1484959211420802,
  'sigma_test': 0.3555934101929993},
 'gender_male': {'MAE': 278.8692481491538,
  'MSE': 429416.4352502737,
  'RMSE': 655.2987374093389,
  'R2': 0.16690482705155496,
  'intercept': 4572.206099409003,
  'Mu_train': 0.809235497394063,
  'sigma_train': 0.3929045096960431,
  'Mu_test': 0.8097807613868117,
  'sigma_test': 0.3924768292136893},
 'gender_unknown': {'MAE': 278.8692481491538,
  'MSE': 429416.4352502737,
  'RMSE': 655.2987374093389,
  'R2': 0.16690482705155496,
  'intercept': 4572.206099409003,
  'Mu_train': 0.0420738443235894,
  'sigma_train': 0.2007580101764719,
  'Mu_test': 0.04172331747110809,
  'sigma_test': 0.19995761680485905},
 'dist': {'MAE': 292.20408652186177,
  'MSE': 433809.2918253957,
  'RMSE': 658.6420058160546,
  'R2': 0.15838240613849397,
  'intercept': 3832.7347042238366,
  'Mu_train': 0.746392726093809,
  'sigma_train': 0.4574039403497704,
  'Mu_test': 0.744243830152232,
  'sigma_test': 0.4541646467942445},
 'hour': {'MAE': 278.99526629176444,
  'MSE': 429299.2136667761,
  'RMSE': 655.2092899728881,
  'R2': 0.16713224437273955,
  'intercept': 4224.941879433071,
  'Mu_train': 11.948638964423294,
  'sigma_train': 5.028237255309031,
  'Mu_test': 11.927812712440517,
  'sigma_test': 5.021851018853225},
 'birthyear': {'MAE': 278.7658751913494,
  'MSE': 429191.94603280694,
  'RMSE': 655.1274273244916,
  'R2': 0.16734035039928508,
  'intercept': 3029.374191661406,
  'Mu_train': 1977.011032744165,
  'sigma_train': 9.957210168037474,
  'Mu_test': 1976.947243938364,
  'sigma_test': 9.888334063994956},
 'usertype_Customer': {'MAE': 285.5160656798232,
  'MSE': 444611.5109534899,
  'RMSE': 666.7919547756181,
  'R2': 0.13742541457038693,
  'intercept': 3520.3459952665444,
  'Mu_train': 0.04361757874461818,
  'sigma_train': 0.2042430739809072,
  'Mu_test': 0.042997960571040106,
  'sigma_test': 0.20285393451678185},
 'usertype_Subscriber': {'MAE': 285.5160656798232,
  'MSE': 444611.5109534899,
  'RMSE': 666.7919547756181,
  'R2': 0.13742541457038693,
  'intercept': 3520.3459952665444,
  'Mu_train': 0.9563824212553819,
  'sigma_train': 0.2042430739809072,
  'Mu_test': 0.9570020394289599,
  'sigma_test': 0.20285393451678185}}

# %%
ds3= {'method': 'mean','percent': '30%','dist': {'MAE': 291.1887971476297,
  'MSE': 433644.9919233972,
  'RMSE': 658.5172677488398,
  'R2': 0.1587011583893042,
  'intercept': 3837.1015651514567,
  'Mu_train': 0.9563824212553819,
  'sigma_train': 0.2042430739809072,
  'Mu_test': 0.9570020394289599,
  'sigma_test': 0.20285393451678185},
 'hour': {'MAE': 278.8191117599752,
  'MSE': 429153.65113467735,
  'RMSE': 655.0981996118425,
  'R2': 0.1674146449352213,
  'intercept': 4229.5175783072755,
  'Mu_train': 0.9563824212553819,
  'sigma_train': 0.2042430739809072,
  'Mu_test': 0.9570020394289599,
  'sigma_test': 0.20285393451678185},
 'birthyear': {'MAE': 278.747867226137,
  'MSE': 429141.59773600876,
  'RMSE': 655.0889998588045,
  'R2': 0.16743802929460794,
  'intercept': 4100.280860668483,
  'Mu_train': 0.9563824212553819,
  'sigma_train': 0.2042430739809072,
  'Mu_test': 0.9570020394289599,
  'sigma_test': 0.20285393451678185}}

# %%
ds4= {'method': 'sample','percent': '30%','gender_female': {'MAE': 279.0582596954936,
  'MSE': 429574.5118342138,
  'RMSE': 655.4193404487037,
  'R2': 0.1665981484332577,
  'intercept': 4729.485666497717,
  'Mu_train': 0.21225286086562428,
  'sigma_train': 0.40890362670022007,
  'Mu_test': 0.21242635395422615,
  'sigma_test': 0.4090278322720775},
 'gender_male': {'MAE': 279.0582596954936,
  'MSE': 429574.5118342138,
  'RMSE': 655.4193404487037,
  'R2': 0.1665981484332577,
  'intercept': 4729.485666497717,
  'Mu_train': 0.7278991049172898,
  'sigma_train': 0.4450423566960799,
  'Mu_test': 0.7278495354634036,
  'sigma_test': 0.4450701008174726},
 'gender_unknown': {'MAE': 279.0582596954936,
  'MSE': 429574.5118342138,
  'RMSE': 655.4193404487037,
  'R2': 0.1665981484332577,
  'intercept': 4729.485666497717,
  'Mu_train': 0.059848034217085885,
  'sigma_train': 0.23720549369407865,
  'Mu_test': 0.05972411058237027,
  'sigma_test': 0.2369766582294243},
 'dist': {'MAE': 299.59747846998687,
  'MSE': 436935.00529423996,
  'RMSE': 661.0105939349535,
  'R2': 0.15231832337604356,
  'intercept': 3572.9436394937843,
  'Mu_train': 0.7837813213842605,
  'sigma_train': 0.5429165773961713,
  'Mu_test': 0.7804512089419834,
  'sigma_test': 0.537760438548376},
 'hour': {'MAE': 279.0659588382967,
  'MSE': 429299.1421296683,
  'RMSE': 655.2092353818499,
  'R2': 0.16713238315927448,
  'intercept': 4219.4126145214905,
  'Mu_train': 13.636903750283254,
  'sigma_train': 5.153727813940737,
  'Mu_test': 13.608302175390891,
  'sigma_test': 5.155474772024395},
 'birthyear': {'MAE': 278.7432833881394,
  'MSE': 429185.3033413349,
  'RMSE': 655.1223575343273,
  'R2': 0.1673532376428707,
  'intercept': 3121.127307249477,
  'Mu_train': 1980.4391747394063,
  'sigma_train': 10.124151702822623,
  'Mu_test': 1980.3481475186948,
  'sigma_test': 10.051415006928934},
 'usertype_Customer': {'MAE': 289.9391385371448,
  'MSE': 454059.07349229633,
  'RMSE': 673.839056075185,
  'R2': 0.11909654287123794,
  'intercept': 2954.861685944684,
  'Mu_train': 0.06206449694085656,
  'sigma_train': 0.24127308443464474,
  'Mu_test': 0.06146612281894403,
  'sigma_test': 0.24018504448564174},
 'usertype_Subscriber': {'MAE': 289.9391385371448,
  'MSE': 454059.07349229633,
  'RMSE': 673.839056075185,
  'R2': 0.11909654287123794,
  'intercept': 2954.861685944684,
  'Mu_train': 0.9379355030591434,
  'sigma_train': 0.24127308443464474,
  'Mu_test': 0.938533877181056,
  'sigma_test': 0.24018504448564174}}

# %%
db1 = pd.DataFrame(ds1)
db2 = pd.DataFrame(ds2)
db3 = pd.DataFrame(ds3)
db4 = pd.DataFrame(ds4)

# %%
data3 = [db1, db2,db3,db4]
df3 = pd.concat(data3, ignore_index=False, sort=False)

# %%
df3
# Out:
#              method percent  gender_female    gender_male  gender_unknown  \
# MAE            drop     30%     279.217114     279.217114      279.217114
# MSE            drop     30%  420130.146237  420130.146237   420130.146237
# RMSE           drop     30%     648.174472     648.174472      648.174472
# R2             drop     30%       0.171754       0.171754        0.171754
# intercept      drop     30%    4139.212439    4139.212439     4139.212439
# Mu_train       drop     30%       0.212416       0.727479        0.060106
# sigma_train    drop     30%       0.409018       0.445258        0.237683
# Mu_test        drop     30%       0.212135       0.728260        0.059604
# sigma_test     drop     30%       0.408824       0.444861        0.236755
# MAE            mode     30%     278.869248     278.869248      278.869248
# MSE            mode     30%  429416.435250  429416.435250   429416.435250
# RMSE           mode     30%     655.298737     655.298737      655.298737
# ...

# %%
dg1= {'method': 'drop','percent': '40%','gender_female': {'MAE': 279.4612404888523,
  'MSE': 438417.80640484265,
  'RMSE': 662.131260706548,
  'R2': 0.1692674595756104,
  'intercept': 4374.104983318164,
  'Mu_train': 0.21284794552074543,
  'sigma_train': 0.4093222279717101,
  'Mu_test': 0.20955977811873008,
  'sigma_test': 0.4069992475948453},
 'gender_male': {'MAE': 279.4612404888523,
  'MSE': 438417.80640484265,
  'RMSE': 662.131260706548,
  'R2': 0.1692674595756104,
  'intercept': 4374.104983318164,
  'Mu_train': 0.7277866622604878,
  'sigma_train': 0.4451004443893195,
  'Mu_test': 0.7311695975451434,
  'sigma_test': 0.4433568054895338},
 'gender_unknown': {'MAE': 279.4612404888523,
  'MSE': 438417.80640484265,
  'RMSE': 662.131260706548,
  'R2': 0.1692674595756104,
  'intercept': 4374.104983318164,
  'Mu_train': 0.05936539221876678,
  'sigma_train': 0.2363080023050419,
  'Mu_test': 0.059270624336126516,
  'sigma_test': 0.23613329621755969},
 'dist': {'MAE': 279.4612404888523,
  'MSE': 438417.80640484265,
  'RMSE': 662.131260706548,
  'R2': 0.1692674595756104,
  'intercept': 4374.104983318164,
  'Mu_train': 0.784519042876338,
  'sigma_train': 0.5433215489710759,
  'Mu_test': 0.7821077790834796,
  'sigma_test': 0.5382734559736571},
 'hour': {'MAE': 279.4612404888523,
  'MSE': 438417.80640484265,
  'RMSE': 662.131260706548,
  'R2': 0.1692674595756104,
  'intercept': 4374.104983318164,
  'Mu_train': 13.628252261609003,
  'sigma_train': 5.154724252441185,
  'Mu_test': 13.616971556709547,
  'sigma_test': 5.167329435109753},
 'birthyear': {'MAE': 279.4612404888523,
  'MSE': 438417.80640484265,
  'RMSE': 662.131260706548,
  'R2': 0.1692674595756104,
  'intercept': 4374.104983318164,
  'Mu_train': 1980.4405667447584,
  'sigma_train': 10.110609980813715,
  'Mu_test': 1980.3983712970612,
  'sigma_test': 10.031232135554879},
 'usertype_Customer': {'MAE': 279.4612404888523,
  'MSE': 438417.80640484265,
  'RMSE': 662.131260706548,
  'R2': 0.1692674595756104,
  'intercept': 4374.104983318164,
  'Mu_train': 0.06189107689765666,
  'sigma_train': 0.24095832445310558,
  'Mu_test': 0.0605924701994571,
  'sigma_test': 0.23858408658656236},
 'usertype_Subscriber': {'MAE': 279.4612404888523,
  'MSE': 438417.80640484265,
  'RMSE': 662.131260706548,
  'R2': 0.1692674595756104,
  'intercept': 4374.104983318164,
  'Mu_train': 0.9381089231023434,
  'sigma_train': 0.24095832445310558,
  'Mu_test': 0.9394075298005429,
  'sigma_test': 0.23858408658656236}}

# %%
dg2= {'method': 'mode','percent': '40%','gender_female': {'MAE': 278.8510974551261,
  'MSE': 429346.1384727202,
  'RMSE': 655.2450980150254,
  'R2': 0.16704120726722949,
  'intercept': 4793.41261882389,
  'Mu_train': 0.12770861658735555,
  'sigma_train': 0.33376566669779967,
  'Mu_test': 0.1257364604577385,
  'sigma_test': 0.3315544598581087},
 'gender_male': {'MAE': 278.8510974551261,
  'MSE': 429346.1384727202,
  'RMSE': 655.2450980150254,
  'R2': 0.16704120726722949,
  'intercept': 4793.41261882389,
  'Mu_train': 0.8366721901200997,
  'sigma_train': 0.36966514610012585,
  'Mu_test': 0.8387009970541581,
  'sigma_test': 0.3678091224738874},
 'gender_unknown': {'MAE': 278.8510974551261,
  'MSE': 429346.1384727202,
  'RMSE': 655.2450980150254,
  'R2': 0.16704120726722949,
  'intercept': 4793.41261882389,
  'Mu_train': 0.03561919329254475,
  'sigma_train': 0.18533911617899435,
  'Mu_test': 0.03556254248810333,
  'sigma_test': 0.18519809344843596},
 'dist': {'MAE': 296.20309512189993,
  'MSE': 434616.4783781631,
  'RMSE': 659.254486809277,
  'R2': 0.15681641293102044,
  'intercept': 3680.0718574041125,
  'Mu_train': 0.7343306701722198,
  'sigma_train': 0.4253194888369341,
  'Mu_test': 0.7328843493190453,
  'sigma_test': 0.42127981290627237},
 'hour': {'MAE': 279.20329558185676,
  'MSE': 429386.653215278,
  'RMSE': 655.2760130016038,
  'R2': 0.16696260609203584,
  'intercept': 4205.656476380237,
  'Mu_train': 11.376947371402673,
  'sigma_train': 4.85234148349396,
  'Mu_test': 11.370198844323589,
  'sigma_test': 4.857250096736196},
 'birthyear': {'MAE': 278.7494864758002,
  'MSE': 429197.5546726838,
  'RMSE': 655.1317078822271,
  'R2': 0.16732946928150594,
  'intercept': 3105.821687216688,
  'Mu_train': 1975.8643319453886,
  'sigma_train': 9.630542523122637,
  'Mu_test': 1975.839055064582,
  'sigma_test': 9.56853919124617},
 'usertype_Customer': {'MAE': 287.42299445695636,
  'MSE': 448527.4029205961,
  'RMSE': 669.7218847556022,
  'R2': 0.12982833530703164,
  'intercept': 3276.450122031052,
  'Mu_train': 0.03713460231135282,
  'sigma_train': 0.1890919094568335,
  'Mu_test': 0.036355653750283254,
  'sigma_test': 0.18717482836279145},
 'usertype_Subscriber': {'MAE': 287.42299445695636,
  'MSE': 448527.4029205961,
  'RMSE': 669.7218847556022,
  'R2': 0.12982833530703164,
  'intercept': 3276.450122031052,
  'Mu_train': 0.9628653976886472,
  'sigma_train': 0.1890919094568335,
  'Mu_test': 0.9636443462497167,
  'sigma_test': 0.18717482836279148}}

# %%
dg3= {'method': 'mean','percent': '40%','dist': {'MAE': 295.01714558934503,
  'MSE': 434475.5535714506,
  'RMSE': 659.1475961963683,
  'R2': 0.15708981601153482,
  'intercept': 3689.3024862841976,
  'Mu_train': 0.9628653976886472,
  'sigma_train': 0.1890919094568335,
  'Mu_test': 0.9636443462497167,
  'sigma_test': 0.18717482836279148},
 'hour': {'MAE': 279.04212612166725,
  'MSE': 429308.5614859001,
  'RMSE': 655.2164233945148,
  'R2': 0.16711410900960366,
  'intercept': 4211.633042191547,
  'Mu_train': 0.9628653976886472,
  'sigma_train': 0.1890919094568335,
  'Mu_test': 0.9636443462497167,
  'sigma_test': 0.18717482836279148},
 'birthyear': {'MAE': 278.70703050458525,
  'MSE': 429092.73348184454,
  'RMSE': 655.0517029073694,
  'R2': 0.1675328290529129,
  'intercept': 4091.1097985525034,
  'Mu_train': 0.9628653976886472,
  'sigma_train': 0.1890919094568335,
  'Mu_test': 0.9636443462497167,
  'sigma_test': 0.18717482836279148}}

# %%
dg4= {'method': 'sample','percent': '40%','gender_female': {'MAE': 279.02172481453476,
  'MSE': 429593.4366547203,
  'RMSE': 655.4337774746739,
  'R2': 0.1665614330788403,
  'intercept': 4871.378731928526,
  'Mu_train': 0.21246530138227962,
  'sigma_train': 0.4090530399986609,
  'Mu_test': 0.20905563108996147,
  'sigma_test': 0.40663708150486894},
 'gender_male': {'MAE': 279.02172481453476,
  'MSE': 429593.4366547203,
  'RMSE': 655.4337774746739,
  'R2': 0.1665614330788403,
  'intercept': 4871.378731928526,
  'Mu_train': 0.728122167459778,
  'sigma_train': 0.4449280589364896,
  'Mu_test': 0.731645139360979,
  'sigma_test': 0.44310643209284317},
 'gender_unknown': {'MAE': 279.02172481453476,
  'MSE': 429593.4366547203,
  'RMSE': 655.4337774746739,
  'R2': 0.1665614330788403,
  'intercept': 4871.378731928526,
  'Mu_train': 0.05941253115794244,
  'sigma_train': 0.236395600979547,
  'Mu_test': 0.0592992295490596,
  'sigma_test': 0.2361855646958514},
 'dist': {'MAE': 304.74973278662077,
  'MSE': 438513.3431488057,
  'RMSE': 662.2034001338303,
  'R2': 0.1492562476379452,
  'intercept': 3408.273215877575,
  'Mu_train': 0.7842438993438707,
  'sigma_train': 0.5425786535634394,
  'Mu_test': 0.7815343796099026,
  'sigma_test': 0.5382712539807839},
 'hour': {'MAE': 279.29391360985386,
  'MSE': 429491.446087008,
  'RMSE': 655.3559689870903,
  'R2': 0.1667593012615004,
  'intercept': 4203.215344706076,
  'Mu_train': 13.62557358939497,
  'sigma_train': 5.153036605690152,
  'Mu_test': 13.614292997960572,
  'sigma_test': 5.169112637515383},
 'birthyear': {'MAE': 278.7221866950039,
  'MSE': 429186.45653095434,
  'RMSE': 655.1232376667418,
  'R2': 0.167351000381726,
  'intercept': 2774.4091890135037,
  'Mu_train': 1980.4438802968502,
  'sigma_train': 10.111066508115877,
  'Mu_test': 1980.391938590528,
  'sigma_test': 10.031821204392244},
 'usertype_Customer': {'MAE': 291.41022725867464,
  'MSE': 456953.79374104744,
  'RMSE': 675.9835750527134,
  'R2': 0.11348060163492923,
  'intercept': 2683.019032390123,
  'Mu_train': 0.061979520734194424,
  'sigma_train': 0.24111877901248938,
  'Mu_test': 0.06051722184455019,
  'sigma_test': 0.23844431831132637},
 'usertype_Subscriber': {'MAE': 291.41022725867464,
  'MSE': 456953.79374104744,
  'RMSE': 675.9835750527134,
  'R2': 0.11348060163492923,
  'intercept': 2683.019032390123,
  'Mu_train': 0.9380204792658056,
  'sigma_train': 0.24111877901248938,
  'Mu_test': 0.9394827781554498,
  'sigma_test': 0.23844431831132637}}

# %%
dc1 = pd.DataFrame(dg1)
dc2 = pd.DataFrame(dg2)
dc3 = pd.DataFrame(dg3)
dc4 = pd.DataFrame(dg4)

# %%
data4 = [dc1, dc2,dc3,dc4]
df4 = pd.concat(data4, ignore_index=False, sort=False)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, MAE to sigma_test
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   method               36 non-null     object
#  1   percent              36 non-null     object
#  2   gender_female        27 non-null     float64
#  3   gender_male          27 non-null     float64
#  4   gender_unknown       27 non-null     float64
#  5   dist                 36 non-null     float64
#  6   hour                 36 non-null     float64
#  7   birthyear            36 non-null     float64
#  8   usertype_Customer    27 non-null     float64
#  9   usertype_Subscriber  27 non-null     float64
# dtypes: float64(8), object(2)
# memory usage: 3.1+ KB

# %%
data5 = [df1, df2,df3,df4]
df = pd.concat(data5, ignore_index=False, sort=False)

# %%
df.to_csv("5_variable_univariate_results.csv")

# %%
data = pd.read_csv("5_variable_univariate_results.csv")

# %%
data
# Out:
#       Unnamed: 0  method percent  gender_female    gender_male  \
# 0            MAE    drop     10%     279.254225     279.254225
# 1            MSE    drop     10%  432806.139298  432806.139298
# 2           RMSE    drop     10%     657.880034     657.880034
# 3             R2    drop     10%       0.167214       0.167214
# 4      intercept    drop     10%    4330.683500    4330.683500
# ..           ...     ...     ...            ...            ...
# 139    intercept  sample     40%    4871.378732    4871.378732
# 140     Mu_train  sample     40%       0.212465       0.728122
# 141  sigma_train  sample     40%       0.409053       0.444928
# 142      Mu_test  sample     40%       0.209056       0.731645
# 143   sigma_test  sample     40%       0.406637       0.443106
#
#      gender_unknown           dist           hour      birthyear  \
# 0        279.254225     279.254225     279.254225     279.254225
# 1     432806.139298  432806.139298  432806.139298  432806.139298
# ...
