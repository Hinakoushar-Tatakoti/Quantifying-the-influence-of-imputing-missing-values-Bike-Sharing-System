# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
dp13 = {'method': 'multi_reg',"col": 2, 'percent': '20%',('start_lat', 'start_lon'): {'rmse': 2.236758181468611,
  'r2': 0.52690721525807},
 ('end_lat', 'end_lon'): {'rmse': 2.2366232683274214,
  'r2': 0.5269642840188354},
 ('hour', 'temp'): {'rmse': 2.236782222409824, 'r2': 0.5268970454891224},
 ('feelslike', 'dew'): {'rmse': 2.23599651205664, 'r2': 0.5272293591124402},
 ('snowdepth', 'winddir'): {'rmse': 2.235941755881793,
  'r2': 0.5272525137057207},
 ('sealevelpressure', 'visibility'): {'rmse': 2.235938327227267,
  'r2': 0.5272539635525797},
 ('solarradiation', 'birthyear'): {'rmse': 2.2371866180769304,
  'r2': 0.5267259621554308}}

# %%
dp23 = {'method': 'multi_reg',"col": 3, 'percent': '20%',('start_lat', 'start_lon', 'end_lat'): {'rmse': 2.236753339386766,
  'r2': 0.5269092635362642},
 ('end_lat', 'end_lon', 'hour'): {'rmse': 2.237871276723342,
  'r2': 0.5264362404647662},
 ('hour', 'temp', 'feelslike'): {'rmse': 2.2368682480393436,
  'r2': 0.5268606541393397},
 ('feelslike', 'dew', 'snowdepth'): {'rmse': 2.236284507260454,
  'r2': 0.5271075660374187},
 ('snowdepth', 'winddir', 'sealevelpressure'): {'rmse': 2.2359514264779206,
  'r2': 0.5272484243685234},
 ('sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2362137945866327, 'r2': 0.5271374718563235},
 ('solarradiation', 'birthyear', 'start_lat'): {'rmse': 2.2373087284116315,
  'r2': 0.5266742961675386}}

# %%
dp33 = {'method': 'multi_reg',"col": 4, 'percent': '20%',('start_lat', 'start_lon', 'end_lat', 'end_lon'): {'rmse': 2.2372395581017943,
  'r2': 0.5267035630979927},
 ('end_lat', 'end_lon', 'hour', 'temp'): {'rmse': 2.237940944591823,
  'r2': 0.5264067546836989},
 ('hour', 'temp', 'feelslike', 'dew'): {'rmse': 2.2368324403158644,
  'r2': 0.526875802020557},
 ('feelslike', 'dew', 'snowdepth', 'winddir'): {'rmse': 2.236324062243767,
  'r2': 0.5270908370231084},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.2359134735435466, 'r2': 0.5272644731583466},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'birthyear'): {'rmse': 2.2368778697493488, 'r2': 0.5268565837884169},
 ('solarradiation',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 2.237601272511671, 'r2': 0.526550506640258}}

# %%
dp43 = {'method': 'multi_reg',"col": 5, 'percent': '20%',('start_lat',
  'start_lon',
  'end_lat',
  'end_lon',
  'hour'): {'rmse': 2.238503482679494, 'r2': 0.5261686360481823},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike'): {'rmse': 2.238289734097597, 'r2': 0.5262591214527162},
 ('hour', 'temp', 'feelslike', 'dew', 'snowdepth'): {'rmse': 2.236867438684472,
  'r2': 0.526860996526573},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.236326563899253, 'r2': 0.52708977898641},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2362517125116566, 'r2': 0.527121435717073},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'birthyear',
  'start_lat'): {'rmse': 2.2369824989666283, 'r2': 0.5268123205018514},
 ('solarradiation',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse': 2.237652098153505, 'r2': 0.5265289982080243}}

# %%
dp53 = {'method': 'multi_reg',"col": 6, 'percent': '20%',('start_lat',
  'start_lon',
  'end_lat',
  'end_lon',
  'hour',
  'temp'): {'rmse': 2.238564953738388, 'r2': 0.526142612130124},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew'): {'rmse': 2.238350818356413, 'r2': 0.526233263758902},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir'): {'rmse': 2.2370180810633915, 'r2': 0.5267972670593556},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.2363200801498833, 'r2': 0.5270925211860082},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'birthyear'): {'rmse': 2.2366057108912445, 'r2': 0.5269717106265366},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 2.237746445112981, 'r2': 0.5264890710976513},
 ('solarradiation',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'hour'): {'rmse': 2.238784079661755, 'r2': 0.5260498388384692}}

# %%
dp63 = {'method': 'multi_reg',"col": 7, 'percent': '20%',('start_lat',
  'start_lon',
  'end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike'): {'rmse': 2.238938937245935, 'r2': 0.5259842699289713},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth'): {'rmse': 2.238299165981353, 'r2': 0.5262551288701267},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.2369975426034325, 'r2': 0.5268059561359885},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.23672306768847, 'r2': 0.5269220688491063},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'birthyear',
  'start_lat'): {'rmse': 2.236603085656157, 'r2': 0.5269728210678877},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse': 2.2380049592060582, 'r2': 0.526379660740427},
 ('solarradiation',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'hour'): {'rmse': 2.238784079661755, 'r2': 0.5260498388384692}}

# %%
dp73 = {'method': 'multi_reg',"col": 1, 'percent': '20%',('start_lat','start_lon','end_lat',
                     'end_lon','hour','temp', 'feelslike', 'dew','snowdepth',
                     'winddir','sealevelpressure','visibility','solarradiation','dist','birthyear'):
       {'rmse': 2.238784079661755, 'r2': 0.5260498388384692}
      }

# %%
d23 = pd.DataFrame(dp13)
d33 = pd.DataFrame(dp23)
d43 = pd.DataFrame(dp33)
d53 = pd.DataFrame(dp43)
d63 = pd.DataFrame(dp53)
d73 = pd.DataFrame(dp63)
d13 = pd.DataFrame(dp73)

# %%
dp14 = {'method': 'mice',"col": 2, 'percent': '20%',('start_lat', 'start_lon'): {'rmse': 2.238504279388437,
  'r2': 0.5261682987641393},
 ('end_lat', 'end_lon'): {'rmse': 2.2388006569048295,
  'r2': 0.5260428200141115},
 ('hour', 'temp'): {'rmse': 2.241735904765546, 'r2': 0.5247992132910315},
 ('feelslike', 'dew'): {'rmse': 2.2361228766085035, 'r2': 0.5271759215172073},
 ('snowdepth', 'winddir'): {'rmse': 2.236289833169297,
  'r2': 0.5271053135646347},
 ('sealevelpressure', 'visibility'): {'rmse': 2.2360137986437674,
  'r2': 0.527222049063053},
 ('solarradiation', 'birthyear'): {'rmse': 2.2400765171419,
  'r2': 0.525502463351315}}

# %%
dp24 = {'method': 'mice',"col": 3, 'percent': '20%',('start_lat', 'start_lon', 'end_lat'): {'rmse': 2.239338733826985,
  'r2': 0.5258149693866231},
 ('end_lat', 'end_lon', 'hour'): {'rmse': 2.2457860729146955,
  'r2': 0.523080561487957},
 ('hour', 'temp', 'feelslike'): {'rmse': 2.2438630276825378,
  'r2': 0.5238969749436202},
 ('feelslike', 'dew', 'snowdepth'): {'rmse': 2.2364239892555196,
  'r2': 0.5270485735103398},
 ('snowdepth', 'winddir', 'sealevelpressure'): {'rmse': 2.2363910066595345,
  'r2': 0.5270625235044983},
 ('sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2372695162370517, 'r2': 0.5266908875009106},
 ('solarradiation', 'birthyear', 'start_lat'): {'rmse': 2.2400657292780073,
  'r2': 0.5255070335545897}}

# %%
dp34 = {'method': 'mice',"col": 4, 'percent': '20%',('start_lat', 'start_lon', 'end_lat', 'end_lon'): {'rmse': 2.239657186305425,
  'r2': 0.5256800937351063},
 ('end_lat', 'end_lon', 'hour', 'temp'): {'rmse': 2.2463105052550283,
  'r2': 0.5228577965655288},
 ('hour', 'temp', 'feelslike', 'dew'): {'rmse': 2.243979192461473,
  'r2': 0.5238476779646335},
 ('feelslike', 'dew', 'snowdepth', 'winddir'): {'rmse': 2.236450479770461,
  'r2': 0.5270373691939028},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.2363192015194864, 'r2': 0.5270928927882739},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'birthyear'): {'rmse': 2.2398174198201506, 'r2': 0.525612222040382},
 ('solarradiation',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 2.242170673159134, 'r2': 0.5246148719359808}}

# %%
dp44 = {'method': 'mice',"col": 5, 'percent': '20%',('start_lat',
  'start_lon',
  'end_lat',
  'end_lon',
  'hour'): {'rmse': 2.24525973338791, 'r2': 0.5233040842348003},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike'): {'rmse': 2.2484393825730082, 'r2': 0.5219529719217019},
 ('hour', 'temp', 'feelslike', 'dew', 'snowdepth'): {'rmse': 2.243979104491034,
  'r2': 0.5238477152977141},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.2365405459812067, 'r2': 0.5269992741767158},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.2376298608731187, 'r2': 0.5265384086566947},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'birthyear',
  'start_lat'): {'rmse': 2.239979358440827, 'r2': 0.5255436231636608},
 ('solarradiation',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse': 2.242392688040208, 'r2': 0.5245207240646939}}

# %%
dp54 = {'method': 'mice',"col": 6, 'percent': '20%',('start_lat',
  'start_lon',
  'end_lat',
  'end_lon',
  'hour',
  'temp'): {'rmse': 2.2444289230807586, 'r2': 0.5236568012060494},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew'): {'rmse': 2.248214269314493, 'r2': 0.5220486910572649},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir'): {'rmse': 2.2443160467638705, 'r2': 0.5237047122922602},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility'): {'rmse': 2.236537665573059, 'r2': 0.5270004925174873},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'birthyear'): {'rmse': 2.23997315296416, 'r2': 0.5255462519592224},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'birthyear',
  'start_lat',
  'start_lon'): {'rmse': 2.2419093077562664, 'r2': 0.5247256948855963},
 ('solarradiation',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'hour'): {'rmse': 2.246977977423609, 'r2': 0.5225741968964766}}

# %%
dp64 = {'method': 'mice',"col": 7, 'percent': '20%',('start_lat',
  'start_lon',
  'end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike'): {'rmse': 2.246104366052351, 'r2': 0.5229453652254349},
 ('end_lat',
  'end_lon',
  'hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth'): {'rmse': 2.248336220343698, 'r2': 0.5219968381394471},
 ('hour',
  'temp',
  'feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure'): {'rmse': 2.243420398803492, 'r2': 0.5240847904746904},
 ('feelslike',
  'dew',
  'snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation'): {'rmse': 2.237835650341336, 'r2': 0.5264513183910824},
 ('snowdepth',
  'winddir',
  'sealevelpressure',
  'visibility',
  'solarradiation',
  'birthyear',
  'start_lat'): {'rmse': 2.2398454101406835, 'r2': 0.5256003654052726},
 ('sealevelpressure',
  'visibility',
  'solarradiation',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat'): {'rmse': 2.241926952915489, 'r2': 0.5247182134734252},
 ('solarradiation',
  'birthyear',
  'start_lat',
  'start_lon',
  'end_lat',
  'hour'): {'rmse': 2.2472637035635796, 'r2': 0.5224527700677607}}

# %%
dp74 = {'method': 'mice',"col": 1, 'percent': '20%',('start_lat','start_lon','end_lat',
                     'end_lon','hour','temp', 'feelslike', 'dew','snowdepth',
                     'winddir','sealevelpressure','visibility','solarradiation','dist','birthyear'):
       {'rmse': 2.246407948160509, 'r2': 0.5228163996785375}
      }

# %%
d24 = pd.DataFrame(dp14)
d34 = pd.DataFrame(dp24)
d44 = pd.DataFrame(dp34)
d54 = pd.DataFrame(dp44)
d64 = pd.DataFrame(dp54)
d74 = pd.DataFrame(dp64)
d14 = pd.DataFrame(dp74)

# %% [markdown]
# ### Full Data

# %%
cols = [ 'estimates','method','col', 'percent',('start_lat', 'start_lon'),('end_lat', 'end_lon'),
            ('hour', 'temp'), ('feelslike', 'dew'),('snowdepth', 'winddir'),
            ('sealevelpressure', 'visibility'),('solarradiation', 'birthyear')]
d = [['r2', 'full','0','20%',0.5272377063160185,0.5272377063160185,0.5272377063160185,0.5272377063160185,
                         0.5272377063160185,0.5272377063160185,0.5272377063160185],
    ['rmse', 'full','0','20%',2.2359767726747313,2.2359767726747313,2.2359767726747313,2.2359767726747313,
                        2.2359767726747313,2.2359767726747313,2.2359767726747313]]
data_full = pd.DataFrame(data=d, columns=cols)
data_full
# Out:
#   estimates method col percent  (start_lat, start_lon)  (end_lat, end_lon)  \
# 0        r2   full   0     20%                0.527238            0.527238
# 1      rmse   full   0     20%                2.235977            2.235977
#
#    (hour, temp)  (feelslike, dew)  (snowdepth, winddir)  \
# 0      0.527238          0.527238              0.527238
# 1      2.235977          2.235977              2.235977
#
#    (sealevelpressure, visibility)  (solarradiation, birthyear)
# 0                        0.527238                     0.527238
# 1                        2.235977                     2.235977

# %% [markdown]
# ## merge respective combination variables

# %%
data2 = [d13, d14]
df1= pd.concat(data2, ignore_index=False, sort=False)

data2 = [d23, d24]
df2 = pd.concat(data2, ignore_index=False, sort=False)

data3 = [d33,d34]
df3 = pd.concat(data3, ignore_index=False, sort=False)

data4 = [d43,d44]
df4 = pd.concat(data4, ignore_index=False, sort=False)

data5 = [d53,d54]
df5 = pd.concat(data5, ignore_index=False, sort=False)

data6 = [d63,d64]
df6 = pd.concat(data6, ignore_index=False, sort=False)

data7 = [d73,d74]
df7 = pd.concat(data7, ignore_index=False, sort=False)

# %% [markdown]
# ## Manupulate the dataframes

# %%
df2 = df2.rename_axis('estimates').reset_index()
df3 = df3.rename_axis('estimates').reset_index()
df4 = df4.rename_axis('estimates').reset_index()
df5 = df5.rename_axis('estimates').reset_index()
df6 = df6.rename_axis('estimates').reset_index()
df7 = df7.rename_axis('estimates').reset_index()
df1 = df1.rename_axis('estimates').reset_index()

# %%
data2 = [df2, data_full]
df2 = pd.concat(data2, ignore_index=False, sort=False)
df2.reset_index()
# Out:
#    index estimates     method col percent  (start_lat, start_lon)  \
# 0      0      rmse  multi_reg   2     20%                2.236758
# 1      1        r2  multi_reg   2     20%                0.526907
# 2      2      rmse       mice   2     20%                2.238504
# 3      3        r2       mice   2     20%                0.526168
# 4      0        r2       full   0     20%                0.527238
# 5      1      rmse       full   0     20%                2.235977
#
#    (end_lat, end_lon)  (hour, temp)  (feelslike, dew)  (snowdepth, winddir)  \
# 0            2.236623      2.236782          2.235997              2.235942
# 1            0.526964      0.526897          0.527229              0.527253
# 2            2.238801      2.241736          2.236123              2.236290
# 3            0.526043      0.524799          0.527176              0.527105
# 4            0.527238      0.527238          0.527238              0.527238
# ...

# %%
from matplotlib.backends.backend_pdf import PdfPages
def legend_without_duplicate_labels(figure):
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    figure.legend(by_label.values(), by_label.keys(),  bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ### Visulaization for all variables

# %%
columns = [('start_lat', 'start_lon'),             ('end_lat', 'end_lon'),
                         ('hour', 'temp'),               ('feelslike', 'dew'),
                 ('snowdepth', 'winddir'), ('sealevelpressure', 'visibility'),
          ('solarradiation', 'birthyear')]

columns2 =[('start_lat', 'start_lon'),             ('end_lat', 'end_lon'),
                         ('hour', 'temp'),               ('feelslike', 'dew'),
                 ('snowdepth', 'winddir'), ('sealevelpressure', 'visibility'),
          ('solarradiation', 'birthyear')],

columns3 = [('start_lat', 'start_lon', 'end_lat'),
                             ('end_lat', 'end_lon', 'hour'),
                              ('hour', 'temp', 'feelslike'),
                          ('feelslike', 'dew', 'snowdepth'),
               ('snowdepth', 'winddir', 'sealevelpressure'),
       ('sealevelpressure', 'visibility', 'solarradiation'),
               ('solarradiation', 'birthyear', 'start_lat')]
    

columns4 =[('start_lat', 'start_lon', 'end_lat', 'end_lon'),
                                  ('end_lat', 'end_lon', 'hour', 'temp'),
                                    ('hour', 'temp', 'feelslike', 'dew'),
                            ('feelslike', 'dew', 'snowdepth', 'winddir'),
              ('snowdepth', 'winddir', 'sealevelpressure', 'visibility'),
       ('sealevelpressure', 'visibility', 'solarradiation', 'birthyear'),
               ('solarradiation', 'birthyear', 'start_lat', 'start_lon')]

columns5 =[('start_lat', 'start_lon', 'end_lat', 'end_lon', 'hour'),
                                  ('end_lat', 'end_lon', 'hour', 'temp', 'feelslike'),
                                    ('hour', 'temp', 'feelslike', 'dew', 'snowdepth'),
                     ('feelslike', 'dew', 'snowdepth', 'winddir', 'sealevelpressure'),
         ('snowdepth', 'winddir', 'sealevelpressure', 'visibility', 'solarradiation'),
       ('sealevelpressure', 'visibility', 'solarradiation', 'birthyear', 'start_lat'),
                 ('solarradiation', 'birthyear', 'start_lat', 'start_lon', 'end_lat')]

columns6 =[('start_lat', 'start_lon', 'end_lat', 'end_lon', 'hour', 'temp'),
                                        ('end_lat', 'end_lon', 'hour', 'temp', 'feelslike', 'dew'),
                                      ('hour', 'temp', 'feelslike', 'dew', 'snowdepth', 'winddir'),
                    ('feelslike', 'dew', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility'),
         ('snowdepth', 'winddir', 'sealevelpressure', 'visibility', 'solarradiation', 'birthyear'),
       ('sealevelpressure', 'visibility', 'solarradiation', 'birthyear', 'start_lat', 'start_lon'),
                      ('solarradiation', 'birthyear', 'start_lat', 'start_lon', 'end_lat', 'hour')]
columns7 =[('start_lat', 'start_lon', 'end_lat', 'end_lon', 'hour', 'temp', 'feelslike'),
                                      ('end_lat', 'end_lon', 'hour', 'temp', 'feelslike', 'dew', 'snowdepth'),
                             ('hour', 'temp', 'feelslike', 'dew', 'snowdepth', 'winddir', 'sealevelpressure'),
             ('feelslike', 'dew', 'snowdepth', 'winddir', 'sealevelpressure', 'visibility', 'solarradiation'),
       ('snowdepth', 'winddir', 'sealevelpressure', 'visibility', 'solarradiation', 'birthyear', 'start_lat'),
       ('sealevelpressure', 'visibility', 'solarradiation', 'birthyear', 'start_lat', 'start_lon', 'end_lat'),
                                 ('solarradiation', 'birthyear', 'start_lat', 'start_lon', 'end_lat', 'hour')]
    
colors = ['#747FE3', '#8EE35D', '#E37346']
with PdfPages('Multiple_Regression_Vs_Mice_imputation.pdf') as pdf:
    for var in columns:
        i =0
        sns.set_style("whitegrid")
        sns.set_palette(sns.color_palette("Set1"))
        sns.set_context("notebook", 
                        font_scale=1.3, 
                        rc={"lines.linewidth": 1.0})
        plt.figure(figsize=(12,3))
        plt.subplot(1,2,1)
        r2 = sns.scatterplot(hue= 'method' , y=var, x='col', data=df2[df2['estimates'] == 'r2'])
        sns.scatterplot(hue= df3['method'] , y=df3[columns3[i]], x='col', data=df3[df3['estimates'] == 'r2'])
        sns.scatterplot(hue= df4['method'] , y=df4[columns4[i]], x='col', data=df4[df4['estimates'] == 'r2'])
        sns.scatterplot(hue= df5['method'] , y=df5[columns5[i]], x='col', data=df5[df5['estimates'] == 'r2'])
        sns.scatterplot(hue= df6['method'] , y=df6[columns6[i]], x='col', data=df6[df6['estimates'] == 'r2'])
        sns.scatterplot(hue= df7['method'] , y=df7[columns7[i]], x='col', data=df7[df7['estimates'] == 'r2'])
        plt.title(f"R2 plot of {var}", fontsize=12)
        plt.xlabel('column combinations', fontsize=10)
        plt.ylabel("R2 score", fontsize=10)
        # add labels here
        plt.gca().get_legend().remove()
        
        ## Plot for R2
        plt.subplot(1,2,2)
        rmse = sns.scatterplot(hue='method',y=var, x='col', data=df2[df2['estimates']=='rmse'])
        sns.scatterplot(hue= df3['method'] , y=df3[columns3[i]], x='col', data=df3[df3['estimates'] == 'rmse'])
        sns.scatterplot(hue= df4['method'] , y=df4[columns4[i]], x='col', data=df4[df4['estimates'] == 'rmse'])
        sns.scatterplot(hue= df5['method'] , y=df5[columns5[i]], x='col', data=df5[df5['estimates'] == 'rmse'])
        sns.scatterplot(hue= df6['method'] , y=df6[columns6[i]], x='col', data=df6[df6['estimates'] == 'rmse'])
        sns.scatterplot(hue= df7['method'] , y=df7[columns7[i]], x='col', data=df7[df7['estimates'] == 'rmse'])
        plt.title(f"RMSE plot of {var}", fontsize=12)
        plt.ylabel('RMSE error', fontsize=10)
        plt.xlabel('column combinations', fontsize=10)
        plt.gca().get_legend().remove()

#         handles, labels = plt.gca().get_legend_handles_labels()

#         l = plt.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        legend_without_duplicate_labels(plt)
        plt.tight_layout()    
        pdf.savefig()  # saves the current figure into a pdf page
        plt.close() 
        i = i+1
