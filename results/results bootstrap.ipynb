# %%
import pandas as pd

# %%
dp1 = {'method': 'drop','percent': '10%','gender': {'R2': [0.1692903070566928, 0.18287391667440567],
  'RMSE': [649.4322232919918, 683.6458268938354],
  'intercept': [3702.721568724243, 4859.1833670179185]},
 'dist': {'R2': [0.1692903070566928, 0.18287391667440567],
  'RMSE': [649.4322232919918, 683.6458268938354],
  'intercept': [3702.721568724243, 4859.1833670179185]},
 'hour': {'R2': [0.1692903070566928, 0.18287391667440567],
  'RMSE': [649.4322232919918, 683.6458268938354],
  'intercept': [3702.721568724243, 4859.1833670179185]},
 'birthyear': {'R2': [0.1692903070566928, 0.18287391667440567],
  'RMSE': [649.4322232919918, 683.6458268938354],
  'intercept': [3702.721568724243, 4859.1833670179185]},
 'usertype': {'R2': [0.1692903070566928, 0.18287391667440567],
  'RMSE': [649.4322232919918, 683.6458268938354],
  'intercept': [3702.721568724243, 4859.1833670179185]}}

# %%
dp2 = {'method': 'mode','percent': '10%','gender': {'R2': [0.16997660432429562, 0.1835356319143303],
  'RMSE': [649.8816105513088, 682.2198713448631],
  'intercept': [3843.377598410043, 4981.248931453127]},
 'dist': {'R2': [0.16762615966649053, 0.18079919850336795],
  'RMSE': [651.008253623839, 683.3143277562708],
  'intercept': [3558.304995363931, 4698.273353215009]},
 'hour': {'R2': [0.1700350649761721, 0.18345144505295674],
  'RMSE': [649.8888673399063, 682.2404490210199],
  'intercept': [3706.3446842892854, 4836.586634046061]},
 'birthyear': {'R2': [0.17024987025297977, 0.183650747144242],
  'RMSE': [649.764389445547, 682.1494081344799],
  'intercept': [3397.4268445384077, 4538.925440484303]},
 'usertype': {'R2': [0.15689657076436275, 0.17087599791601144],
  'RMSE': [655.2468635104944, 687.2619475365002],
  'intercept': [3432.090871497232, 4604.633226701961]}}

# %%
dp3 = {'method': 'mean','percent': '10%','gender': {'R2': [0.1700662638910192, 0.18357051996191937],
  'RMSE': [649.8484696300372, 682.1920598357341],
  'intercept': [3797.3718626481427, 4923.946610684054]},
 'dist': {'R2': [0.16778358892726325, 0.18086761886874342],
  'RMSE': [650.9444334981852, 683.2606155151748],
  'intercept': [3559.4347627576713, 4706.78902112447]},
 'hour': {'R2': [0.170165103621014, 0.1835192990876529],
  'RMSE': [649.8157238910101, 682.1865055773817],
  'intercept': [3712.7564578599354, 4846.451810941811]},
 'birthyear': {'R2': [0.170281513662499, 0.18374532332964283],
  'RMSE': [649.7480810186221, 682.1293325139047],
  'intercept': [3710.858051283004, 4951.740677792273]},
 'usertype': {'R2': [0.1576918683829046, 0.17160917330829317],
  'RMSE': [654.963145652195, 686.9468830945938],
  'intercept': [2989.2880572956933, 4173.116349938559]}}

# %%
dp4 = {'method': 'sample','percent': '10%','gender': {'R2': [0.1698543806696846, 0.18332535945308626],
  'RMSE': [649.9251616738643, 682.275451812396],
  'intercept': [3931.1548116314098, 5096.4652742285925]},
 'dist': {'R2': [0.16537963764702812, 0.17849683671605704],
  'RMSE': [651.9672195243456, 684.1042671968746],
  'intercept': [3444.6521142479487, 4598.230480736644]},
 'hour': {'R2': [0.17001266884351496, 0.18337376534128502],
  'RMSE': [649.8948303836703, 682.2323406450054],
  'intercept': [3703.991486917915, 4838.313142447543]},
 'birthyear': {'R2': [0.1702223209679128, 0.18367958755592245],
  'RMSE': [649.7698811628004, 682.1455282397708],
  'intercept': [3370.6060523439673, 4557.4314102041135]},
 'usertype': {'R2': [0.148283525129633, 0.16136721499136536],
  'RMSE': [659.0175933284797, 691.0306534521352],
  'intercept': [3142.625196729451, 4324.445531734245]}}

# %%
da1 = pd.DataFrame(dp1)
da2 = pd.DataFrame(dp2)
da3 = pd.DataFrame(dp3)
da4 = pd.DataFrame(dp4)

# %%
data1 = [da1, da2,da3,da4]
df1 = pd.concat(data1, ignore_index=False, sort=False)

# %%
df1
# Out:
#            method percent                                     gender  \
# R2           drop     10%  [0.1692903070566928, 0.18287391667440567]
# RMSE         drop     10%     [649.4322232919918, 683.6458268938354]
# intercept    drop     10%    [3702.721568724243, 4859.1833670179185]
# R2           mode     10%  [0.16997660432429562, 0.1835356319143303]
# RMSE         mode     10%     [649.8816105513088, 682.2198713448631]
# intercept    mode     10%     [3843.377598410043, 4981.248931453127]
# R2           mean     10%  [0.1700662638910192, 0.18357051996191937]
# RMSE         mean     10%     [649.8484696300372, 682.1920598357341]
# intercept    mean     10%    [3797.3718626481427, 4923.946610684054]
# R2         sample     10%  [0.1698543806696846, 0.18332535945308626]
# RMSE       sample     10%      [649.9251616738643, 682.275451812396]
# intercept  sample     10%   [3931.1548116314098, 5096.4652742285925]
#
#                                                  dist  \
# ...

# %%
dq1 = {'method': 'drop','percent': '20%','gender': {'R2': [0.16943407382491632, 0.18401755037351225],
  'RMSE': [649.3841484106034, 682.964131050179],
  'intercept': [3697.38996191378, 4870.295350546845]},
 'dist': {'R2': [0.16943407382491632, 0.18401755037351225],
  'RMSE': [649.3841484106034, 682.964131050179],
  'intercept': [3697.38996191378, 4870.295350546845]},
 'hour': {'R2': [0.16943407382491632, 0.18401755037351225],
  'RMSE': [649.3841484106034, 682.964131050179],
  'intercept': [3697.38996191378, 4870.295350546845]},
 'birthyear': {'R2': [0.16943407382491632, 0.18401755037351225],
  'RMSE': [649.3841484106034, 682.964131050179],
  'intercept': [3697.38996191378, 4870.295350546845]},
 'usertype': {'R2': [0.16943407382491632, 0.18401755037351225],
  'RMSE': [649.3841484106034, 682.964131050179],
  'intercept': [3697.38996191378, 4870.295350546845]}}

# %%
dq2 = {'method': 'mode','percent': '20%','gender': {'R2': [0.16973032735521126, 0.18328887417240441],
  'RMSE': [649.9661593370878, 682.3086117052005],
  'intercept': [3941.7687143969606, 5136.733952024837]},
 'dist': {'R2': [0.1650597668183234, 0.17807347049664235],
  'RMSE': [652.269048305782, 684.3071188015057],
  'intercept': [3430.0731945687094, 4544.887549308664]},
 'hour': {'R2': [0.16978808150000507, 0.1832118916726434],
  'RMSE': [649.9980485808713, 682.3219704229684],
  'intercept': [3694.4669898510856, 4824.266534073853]},
 'birthyear': {'R2': [0.17014831708532757, 0.18356607156988253],
  'RMSE': [649.7996569371485, 682.1833673320891],
  'intercept': [3047.6715971176936, 4143.338728569215]},
 'usertype': {'R2': [0.14569816237386468, 0.16030193995685388],
  'RMSE': [659.4080615971518, 692.6142244694461],
  'intercept': [3133.2711707980457, 4329.958767812104]}}

# %%
dq3 = {'method': 'mean','percent': '20%','gender': {'R2': [0.16989156190454985, 0.1833820125698682],
  'RMSE': [649.9049452488719, 682.2505426871476],
  'intercept': [3886.849201527024, 5071.303123311012]},
 'dist': {'R2': [0.16531885539751906, 0.17834603185987358],
  'RMSE': [652.1672695298977, 684.2169623184814],
  'intercept': [3433.16790862123, 4563.125048317238]},
 'hour': {'R2': [0.17000242512746255, 0.18335979779103656],
  'RMSE': [649.887471087138, 682.2235822377604],
  'intercept': [3702.1897027026453, 4834.145737227833]},
 'birthyear': {'R2': [0.17020072103125516, 0.18368555034055645],
  'RMSE': [649.7712867693974, 682.1602130928009],
  'intercept': [3549.819881578735, 4882.331160855227]},
 'usertype': {'R2': [0.14696456062111757, 0.16142359826544306],
  'RMSE': [658.9794378929798, 692.0545938809929],
  'intercept': [2715.711674710732, 3912.724502066233]}}

# %%
dq4 = {'method': 'sample','percent': '20%','gender': {'R2': [0.16963604782064934, 0.18305882195796896],
  'RMSE': [650.0546877990944, 682.3727173396347],
  'intercept': [4015.042044231823, 5226.601329635349]},
 'dist': {'R2': [0.16143660547137462, 0.17453452371209505],
  'RMSE': [653.7993057997849, 685.6542025352117],
  'intercept': [3236.8255879664525, 4360.930960177421]},
 'hour': {'R2': [0.1697306488068781, 0.18307582462188177],
  'RMSE': [650.0647525689808, 682.3269033940499],
  'intercept': [3684.2392817929895, 4817.60609230933]},
 'birthyear': {'R2': [0.17016139605304664, 0.18363719440102882],
  'RMSE': [649.7784402303014, 682.160494429482],
  'intercept': [3126.730810437811, 4295.344199071417]},
 'usertype': {'R2': [0.1324154670257659, 0.14525794900721967],
  'RMSE': [664.9092796507261, 698.0500296423436],
  'intercept': [2774.058005883161, 3939.267016260167]}}

# %%
db1 = pd.DataFrame(dq1)
db2 = pd.DataFrame(dq2)
db3 = pd.DataFrame(dq3)
db4 = pd.DataFrame(dq4)

# %%
data2 = [db1, db2,db3,db4]
df2 = pd.concat(data2, ignore_index=False, sort=False)

# %%
df2
# Out:
#            method percent                                      gender  \
# R2           drop     20%  [0.16943407382491632, 0.18401755037351225]
# RMSE         drop     20%       [649.3841484106034, 682.964131050179]
# intercept    drop     20%       [3697.38996191378, 4870.295350546845]
# R2           mode     20%  [0.16973032735521126, 0.18328887417240441]
# RMSE         mode     20%      [649.9661593370878, 682.3086117052005]
# intercept    mode     20%     [3941.7687143969606, 5136.733952024837]
# R2           mean     20%   [0.16989156190454985, 0.1833820125698682]
# RMSE         mean     20%      [649.9049452488719, 682.2505426871476]
# intercept    mean     20%      [3886.849201527024, 5071.303123311012]
# R2         sample     20%  [0.16963604782064934, 0.18305882195796896]
# RMSE       sample     20%      [650.0546877990944, 682.3727173396347]
# intercept  sample     20%      [4015.042044231823, 5226.601329635349]
#
#                                                  dist  \
# ...

# %%
dr1 = {'method': 'drop','percent': '30%','gender': {'R2': [0.17027847551248348, 0.18588588915925847],
  'RMSE': [651.1930436503169, 687.4213614773985],
  'intercept': [3442.1923463760604, 4858.746632123913]},
 'dist': {'R2': [0.17027847551248348, 0.18588588915925847],
  'RMSE': [651.1930436503169, 687.4213614773985],
  'intercept': [3442.1923463760604, 4858.746632123913]},
 'hour': {'R2': [0.17027847551248348, 0.18588588915925847],
  'RMSE': [651.1930436503169, 687.4213614773985],
  'intercept': [3442.1923463760604, 4858.746632123913]},
 'birthyear': {'R2': [0.17027847551248348, 0.18588588915925847],
  'RMSE': [651.1930436503169, 687.4213614773985],
  'intercept': [3442.1923463760604, 4858.746632123913]},
 'usertype': {'R2': [0.17027847551248348, 0.18588588915925847],
  'RMSE': [651.1930436503169, 687.4213614773985],
  'intercept': [3442.1923463760604, 4858.746632123913]}}

# %%
dr2 = {'method': 'mode','percent': '30%','gender': {'R2': [0.16948671457369874, 0.18315528677655357],
  'RMSE': [650.039544027035, 682.3413824741604],
  'intercept': [3952.6025169830027, 5193.349654425764]},
 'dist': {'R2': [0.16215710650658666, 0.17513979523209539],
  'RMSE': [653.419984255818, 685.3838738129667],
  'intercept': [3271.22334004212, 4395.419361195757]},
 'hour': {'R2': [0.16971061636973578, 0.18318692609141957],
  'RMSE': [650.0375570143433, 682.3338056689058],
  'intercept': [3683.4251399814348, 4813.615340846018]},
 'birthyear': {'R2': [0.16999827843669152, 0.18343939659903696],
  'RMSE': [649.8421910291186, 682.2337119731031],
  'intercept': [2483.4696082320625, 3598.298809583811]},
 'usertype': {'R2': [0.13695173300382452, 0.1508715616000464],
  'RMSE': [663.0242692664726, 696.4180504500068],
  'intercept': [2904.456667780773, 4121.242701706049]}}

# %%
dr3 = {'method': 'mean','percent': '30%','gender': {'R2': [0.1696499996565437, 0.18321673414152612],
  'RMSE': [649.9773680175595, 682.304614110603],
  'intercept': [3886.4350570184297, 5132.057118764554]},
 'dist': {'R2': [0.16249555975340202, 0.17533773570603622],
  'RMSE': [653.2986594976559, 685.2764362197564],
  'intercept': [3280.495591019094, 4399.658763647251]},
 'hour': {'R2': [0.16993946940949106, 0.18329487707226272],
  'RMSE': [649.9145406243812, 682.2561031947929],
  'intercept': [3683.142429779408, 4817.313096140191]},
 'birthyear': {'R2': [0.17008785166170587, 0.18360839943341656],
  'RMSE': [649.7942684570487, 682.1731350222277],
  'intercept': [3463.830077076648, 4827.239023228878]},
 'usertype': {'R2': [0.1384267532238745, 0.15209264223389451],
  'RMSE': [662.5476553284448, 695.8474731135385],
  'intercept': [2512.772205881981, 3712.0955080118965]}}

# %%
dr4 = {'method': 'sample','percent': '30%','gender': {'R2': [0.16919905790204676, 0.1826797666015309],
  'RMSE': [650.2069516025169, 682.5137713422105],
  'intercept': [4128.493524077371, 5376.421720617557]},
 'dist': {'R2': [0.15761101587638798, 0.17022436215906783],
  'RMSE': [655.4337064017885, 687.3741034288978],
  'intercept': [3028.466203983856, 4121.852654760087]},
 'hour': {'R2': [0.16968842201072198, 0.18295193666771514],
  'RMSE': [650.0568054301013, 682.372299749865],
  'intercept': [3677.489630740998, 4810.190489413755]},
 'birthyear': {'R2': [0.16996440700846982, 0.1834617553890609],
  'RMSE': [649.8478843106484, 682.2068316379654],
  'intercept': [2498.366344798944, 3716.5799342012883]},
 'usertype': {'R2': [0.11950140076877447, 0.13177373899652223],
  'RMSE': [670.4128514173087, 703.1189583773973],
  'intercept': [2380.6799265021723, 3559.308188143546]}}

# %%
dc1 = pd.DataFrame(dr1)
dc2 = pd.DataFrame(dr2)
dc3 = pd.DataFrame(dr3)
dc4 = pd.DataFrame(dr4)

# %%
data3 = [dc1, dc2,dc3,dc4]
df3 = pd.concat(data3, ignore_index=False, sort=False)

# %%
df3
# Out:
#            method percent                                      gender  \
# R2           drop     30%  [0.17027847551248348, 0.18588588915925847]
# RMSE         drop     30%      [651.1930436503169, 687.4213614773985]
# intercept    drop     30%     [3442.1923463760604, 4858.746632123913]
# R2           mode     30%  [0.16948671457369874, 0.18315528677655357]
# RMSE         mode     30%       [650.039544027035, 682.3413824741604]
# intercept    mode     30%     [3952.6025169830027, 5193.349654425764]
# R2           mean     30%   [0.1696499996565437, 0.18321673414152612]
# RMSE         mean     30%       [649.9773680175595, 682.304614110603]
# intercept    mean     30%     [3886.4350570184297, 5132.057118764554]
# R2         sample     30%   [0.16919905790204676, 0.1826797666015309]
# RMSE       sample     30%      [650.2069516025169, 682.5137713422105]
# intercept  sample     30%      [4128.493524077371, 5376.421720617557]
#
#                                                  dist  \
# ...

# %%
ds1 = {'method': 'drop','percent': '40%','gender': {'R2': [0.17070005001673177, 0.18883285533829136],
  'RMSE': [637.4296545949003, 678.9399170761751],
  'intercept': [3575.5575296016805, 5048.507650087573]},
 'dist': {'R2': [0.17070005001673177, 0.18883285533829136],
  'RMSE': [637.4296545949003, 678.9399170761751],
  'intercept': [3575.5575296016805, 5048.507650087573]},
 'hour': {'R2': [0.17070005001673177, 0.18883285533829136],
  'RMSE': [637.4296545949003, 678.9399170761751],
  'intercept': [3575.5575296016805, 5048.507650087573]},
 'birthyear': {'R2': [0.17070005001673177, 0.18883285533829136],
  'RMSE': [637.4296545949003, 678.9399170761751],
  'intercept': [3575.5575296016805, 5048.507650087573]},
 'usertype': {'R2': [0.17070005001673177, 0.18883285533829136],
  'RMSE': [637.4296545949003, 678.9399170761751],
  'intercept': [3575.5575296016805, 5048.507650087573]}}

# %%
ds2 = {'method': 'mode','percent': '40%','gender': {'R2': [0.1691901707830331, 0.18268786822947397],
  'RMSE': [650.3096123914648, 682.4723436188491],
  'intercept': [4246.649786411869, 5441.475044045594]},
 'dist': {'R2': [0.15971824289895858, 0.17251226806889364],
  'RMSE': [654.6101303227972, 686.4351136596181],
  'intercept': [3140.304414545859, 4263.276954002484]},
 'hour': {'R2': [0.1695786625147525, 0.1829356446988254],
  'RMSE': [650.1245977606015, 682.406456539414],
  'intercept': [3659.7524913858038, 4788.559955700806]},
 'birthyear': {'R2': [0.16995932295772187, 0.18343271663254868],
  'RMSE': [649.8529710066634, 682.2553338591882],
  'intercept': [2569.35466440465, 3694.690059488141]},
 'usertype': {'R2': [0.12627457333828868, 0.13916408555302634],
  'RMSE': [667.6028374404362, 700.1695416177811],
  'intercept': [2692.94202213028, 3856.411125982192]}}

# %%
ds3 = {'method': 'mean','percent': '40%','gender': {'R2': [0.16932342642439624, 0.18283653949113005],
  'RMSE': [650.2380467056266, 682.4107080998679],
  'intercept': [4188.770314082245, 5393.805352169436]},
 'dist': {'R2': [0.16014091543405917, 0.17279389876065615],
  'RMSE': [654.4354545796571, 686.2589578756648],
  'intercept': [3154.576991128764, 4274.898557640832]},
 'hour': {'R2': [0.16987076249976513, 0.18323849052122865],
  'RMSE': [649.9560598906785, 682.2892272510344],
  'intercept': [3668.200100106171, 4799.399342079559]},
 'birthyear': {'R2': [0.17005467742579844, 0.18355200763873408],
  'RMSE': [649.8349338797207, 682.2145637160384],
  'intercept': [3233.7256964463904, 4874.683261514452]},
 'usertype': {'R2': [0.12791666008157482, 0.1405500850312903],
  'RMSE': [667.0458486397224, 699.5111528985966],
  'intercept': [2312.378825536682, 3480.560871646423]}}

# %%
ds4 = {'method': 'sample','percent': '40%','gender': {'R2': [0.1688924821131353, 0.182357363047148],
  'RMSE': [650.3980369070466, 682.5836784616381],
  'intercept': [4299.783870135632, 5495.734954410102]},
 'dist': {'R2': [0.154345250929054, 0.1667660375123784],
  'RMSE': [656.8689521063238, 688.6997553671138],
  'intercept': [2847.238950887484, 3984.6087903016437]},
 'hour': {'R2': [0.1695262336908932, 0.18293273862221326],
  'RMSE': [650.1262959677279, 682.4106777541976],
  'intercept': [3656.8296513073724, 4789.90178462845]},
 'birthyear': {'R2': [0.1699509771022386, 0.18344233009223648],
  'RMSE': [649.8742326858828, 682.2454080645925],
  'intercept': [2157.1548229558257, 3390.0733604630973]},
 'usertype': {'R2': [0.10791181341097794, 0.11883382971134493],
  'RMSE': [674.9495941204361, 707.7867090214263],
  'intercept': [2074.800842981768, 3286.513438181037]}}

# %%
dd1 = pd.DataFrame(ds1)
dd2 = pd.DataFrame(ds2)
dd3 = pd.DataFrame(ds3)
dd4 = pd.DataFrame(ds4)

# %%
data4= [dd1, dd2,dd3,dd4]
df4 = pd.concat(data4, ignore_index=False, sort=False)

# %%
df4
# Out:
#            method percent                                      gender  \
# R2           drop     40%  [0.17070005001673177, 0.18883285533829136]
# RMSE         drop     40%      [637.4296545949003, 678.9399170761751]
# intercept    drop     40%     [3575.5575296016805, 5048.507650087573]
# R2           mode     40%   [0.1691901707830331, 0.18268786822947397]
# RMSE         mode     40%      [650.3096123914648, 682.4723436188491]
# intercept    mode     40%      [4246.649786411869, 5441.475044045594]
# R2           mean     40%  [0.16932342642439624, 0.18283653949113005]
# RMSE         mean     40%      [650.2380467056266, 682.4107080998679]
# intercept    mean     40%      [4188.770314082245, 5393.805352169436]
# R2         sample     40%     [0.1688924821131353, 0.182357363047148]
# RMSE       sample     40%      [650.3980369070466, 682.5836784616381]
# intercept  sample     40%      [4299.783870135632, 5495.734954410102]
#
#                                                  dist  \
# ...

# %%
data5= [df1, df2,df3,df4]
df = pd.concat(data5, ignore_index=False, sort=False)

# %%
df.to_csv("boot_strap_results.csv")

# %%
data = pd.read_csv("boot_strap_results.csv")

# %%
data
# Out:
#    Unnamed: 0  method percent                                      gender  \
# 0          R2    drop     10%   [0.1692903070566928, 0.18287391667440567]
# 1        RMSE    drop     10%      [649.4322232919918, 683.6458268938354]
# 2   intercept    drop     10%     [3702.721568724243, 4859.1833670179185]
# 3          R2    mode     10%   [0.16997660432429562, 0.1835356319143303]
# 4        RMSE    mode     10%      [649.8816105513088, 682.2198713448631]
# 5   intercept    mode     10%      [3843.377598410043, 4981.248931453127]
# 6          R2    mean     10%   [0.1700662638910192, 0.18357051996191937]
# 7        RMSE    mean     10%      [649.8484696300372, 682.1920598357341]
# 8   intercept    mean     10%     [3797.3718626481427, 4923.946610684054]
# 9          R2  sample     10%   [0.1698543806696846, 0.18332535945308626]
# 10       RMSE  sample     10%       [649.9251616738643, 682.275451812396]
# 11  intercept  sample     10%    [3931.1548116314098, 5096.4652742285925]
# ...
